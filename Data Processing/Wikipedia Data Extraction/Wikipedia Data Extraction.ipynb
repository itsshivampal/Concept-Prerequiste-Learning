# %%
import pandas as pd
import wikipedia
import json
import random

# %% [markdown]
# # Following are functions for extracting data

# %%
df = pd.read_csv("required_data/keyword_list.csv", encoding="utf-8")

x1 = df[["keyword"]]
x2 = df[["abbreviation"]]
index_length = df.shape[0]

# %%
relevant_topics = []
topics_abbr = []

for i in range(index_length):
    relevant_topics.append(x1.iloc[i].values[0])
    topics_abbr.append(x2.iloc[i].values[0])

# %%
for i in range(len(relevant_topics)):
    print(relevant_topics[i], " ", topics_abbr[i])
# Out:
# acceptance criterion   nan
# activation function   nan
# active constraint   nan
# adaboost   nan
# adaline   nan
# adaptive rejection sampling   nan
# assumed density ﬁltering   nan
# akaike information criterion   aic
# akaike information criterion   nan
# ancestral sampling   nan
# annular ﬂow   nan
# autoregressive model   ar model
# arc   nan
# automatic relevance determination   ard
# autoregressive moving average   arma
# assumed density ﬁltering   nan
# autoassociative networks   nan
# automatic relevance determination   nan
# autoregressive hidden markov model   nan
# autoregressive model   nan
# autoregressive moving average   nan
# back-tracking   nan
# backgammon   nan
# backpropagation   nan
# bagging   nan
# basis function   nan
# batch training   nan
# baum-welch algorithm   nan
# bayes’ theorem   nan
# bayes   nan
# bayesian analysis   nan
# bayesian information criterion   nan
# bayesian model comparison   nan
# bayesian network   nan
# bayesian probability   nan
# belief propagation   nan
# bernoulli distribution   nan
# bernoulli   nan
# beta distribution   nan
# beta recursion   nan
# between-class covariance   nan
# bias   nan
# bias parameter   nan
# bias-variance trade-off   nan
# bayesian information criterion   bic
# binary entropy   nan
# binomial distribution   nan
# biological sequence   nan
# bipartite graph   nan
# bits   nan
# blind source separation   nan
# blocked path   nan
# boltzmann distribution   nan
# boltzmann   nan
# boolean logic   nan
# boosting   nan
# bootstrap   nan
# bootstrap ﬁlter   nan
# box constraints   nan
# box-muller method   nan
# calculus of variations   nan
# canonical correlation analysis   nan
# canonical link function   nan
# classiﬁcation and regression trees   cart
# cauchy distribution   nan
# causality   nan
# canonical correlation analysis   cca
# central differences   nan
# central limit theorem   nan
# chain graph   nan
# chaining   nan
# chapman-kolmogorov equations   nan
# child node   nan
# cholesky decomposition   nan
# chunking   nan
# circular normal   nan
# classical probability   nan
# classiﬁcation   nan
# classiﬁcation and regression trees   nan
# clique   nan
# clustering   nan
# clutter problem   nan
# co-parents   nan
# code-book vectors   nan
# combining models   nan
# committee   nan
# complete data set   nan
# completing the square   nan
# computational learning theory   nan
# concave function   nan
# concentration parameter   nan
# condensation algorithm   nan
# conditional entropy   nan
# conditional expectation   nan
# conditional independence   nan
# conditional mixture model   nan
# conditional probability   nan
# conjugate prior   nan
# convex duality   nan
# convex function   nan
# convolutional neural network   nan
# correlation matrix   nan
# cost function   nan
# covariance   nan
# covariance matrix   nan
# cox’s axioms   nan
# credit assignment   nan
# cross-entropy error function   nan
# cross-validation   nan
# cumulative distribution function   nan
# curse of dimensionality   nan
# curve ﬁtting   nan
# directed acyclic graph   dag
# dagsvm   nan
# data augmentation   nan
# data compression   nan
# decision boundary   nan
# decision region   nan
# decision surface   nan
# decision theory   nan
# decision tree   nan
# decomposition methods   nan
# degrees of freedom   nan
# degrees-of-freedom parameter   nan
# density estimation   nan
# density network   nan
# dependency map   nan
# descendant node   nan
# design matrix   nan
# differential entropy   nan
# digamma function   nan
# directed acyclic graph   nan
# directed cycle   nan
# directed factorization   nan
# dirichlet distribution   nan
# dirichlet   nan
# discriminant function   nan
# discriminative model   nan
# distortion measure   nan
# distributive law of multiplication   nan
# dna   nan
# document retrieval   nan
# dual representation   nan
# dual-energy gamma densitometry   nan
# dynamic programming   nan
# dynamical system   nan
# early stopping   nan
# expectation conditional maximization   ecm
# edge   nan
# effective number of observations   nan
# effective number of parameters   nan
# elliptical k-means   nan
# expectation maximization   em
# emission probability   nan
# empirical bayes   nan
# energy function   nan
# entropy   nan
# expectation propagation   ep
# equality constraint   nan
# equivalent kernel   nan
# erf function   nan
# error backpropagation   nan
# error function   nan
# error-correcting output codes   nan
# euler   nan
# euler-lagrange equations   nan
# evidence approximation   nan
# evidence function   nan
# expectation   nan
# expectation conditional maximization   nan
# expectation maximization   nan
# expectation propagation   nan
# expectation step   nan
# explaining away   nan
# exploitation   nan
# exploration   nan
# exponential distribution   nan
# exponential family   nan
# extensive variables   nan
# face detection   nan
# face tracking   nan
# factor analysis   nan
# factor graph   nan
# factor loading   nan
# factorial hidden markov model   nan
# factorized distribution   nan
# feature extraction   nan
# feature map   nan
# feature space   nan
# fisher information matrix   nan
# fisher kernel   nan
# fisher’s linear discriminant   nan
# forward kinematics   nan
# forward problem   nan
# forward propagation   nan
# forward-backward algorithm   nan
# fractional belief propagation   nan
# frequentist probability   nan
# fuel system   nan
# function interpolation   nan
# functional   nan
# gamma densitometry   nan
# gamma distribution   nan
# gamma function   nan
# gating function   nan
# gauss   nan
# gaussian   nan
# gaussian kernel   nan
# gaussian process   nan
# gaussian random ﬁeld   nan
# gaussian-gamma distribution   nan
# gaussian-wishart distribution   nan
# generalization   nan
# generalized linear model   nan
# generalized maximum likelihood   nan
# generative model   nan
# generative topographic mapping   nan
# geodesic distance   nan
# gibbs sampling   nan
# gibbs   nan
# gini index   nan
# global minimum   nan
# gradient descent   nan
# gram matrix   nan
# graph-cut algorithm   nan
# graphical model   nan
# green’s function   nan
# generative topographic mapping   gtm
# hamilton   nan
# hamiltonian dynamics   nan
# hamiltonian function   nan
# hammersley-clifford theorem   nan
# handwriting recognition   nan
# handwritten digit   nan
# head-to-head path   nan
# head-to-tail path   nan
# heaviside step function   nan
# hellinger distance   nan
# hessian matrix   nan
# heteroscedastic   nan
# hidden markov model   nan
# hidden unit   nan
# hidden variable   nan
# hierarchical bayesian model   nan
# hierarchical mixture of experts   nan
# hinge error function   nan
# hinton diagram   nan
# histogram density estimation   nan
# hierarchical mixture of experts   hme
# hold-out set   nan
# homogeneous ﬂow   nan
# homogeneous kernel   nan
# homogeneous markov chain   nan
# hooke’s law   nan
# hybrid monte carlo   nan
# hyperparameter   nan
# hyperprior   nan
# independent identically distributed   i.i.d.
# independent component analysis   ica
# iterated conditional modes   icm
# id3   nan
# identiﬁability   nan
# image de-noising   nan
# importance sampling   nan
# importance weights   nan
# improper prior   nan
# imputation step   nan
# imputation-posterior algorithm   nan
# inactive constraint   nan
# incomplete data set   nan
# independence map   nan
# independent component analysis   nan
# independent factor analysis   nan
# independent identically distributed   nan
# independent variables   nan
# independent   nan
# induced factorization   nan
# inequality constraint   nan
# inference   nan
# information criterion   nan
# information geometry   nan
# information theory   nan
# input-output hidden markov model   nan
# intensive variables   nan
# intrinsic dimensionality   nan
# invariance   nan
# inverse gamma distribution   nan
# inverse kinematics   nan
# inverse problem   nan
# inverse wishart distribution   nan
# Imputation posterior algorithm   ip algorithm
# iterative reweighted least squares   irls
# ising model   nan
# isomap   nan
# isometric feature map   nan
# iterated conditional modes   nan
# iterative reweighted least squares   nan
# jacobian matrix   nan
# jensen’s inequality   nan
# join tree   nan
# junction tree algorithm   nan
# k nearest neighbours   nan
# k-means clustering algorithm   nan
# k-medoids algorithm   nan
# kalman ﬁlter   nan
# kalman gain matrix   nan
# kalman smoother   nan
# karhunen-lo`eve transform   nan
# karush-kuhn-tucker conditions   nan
# kernel density estimator   nan
# kernel function   nan
# kernel pca   nan
# kernel regression   nan
# kernel substitution   nan
# kernel trick   nan
# kinetic energy   nan
# karush-kuhn-tucker conditions   kkt
# kullback-leibler divergence   kl divergence
# kriging   nan
# kullback-leibler divergence   nan
# lagrange multiplier   nan
# lagrange   nan
# lagrangian   nan
# laminar ﬂow   nan
# laplace approximation   nan
# laplace   nan
# large margin   nan
# lasso   nan
# latent class analysis   nan
# latent trait model   nan
# latent variable   nan
# lattice diagram   nan
# lds   nan
# leapfrog discretization   nan
# learning   nan
# learning rate parameter   nan
# least-mean-squares algorithm   nan
# leave-one-out   nan
# likelihood function   nan
# likelihood weighted sampling   nan
# linear discriminant   nan
# linear dynamical system   nan
# linear independence   nan
# linear regression   nan
# linear smoother   nan
# linear-gaussian model   nan
# linearly separable   nan
# link   nan
# link function   nan
# liouville’s theorem   nan
# locally linear embedding   lle
# lms algorithm   nan
# local minimum   nan
# local receptive ﬁeld   nan
# locally linear embedding   nan
# location parameter   nan
# log odds   nan
# logic sampling   nan
# logistic regression   nan
# logistic sigmoid   nan
# logit function   nan
# loopy belief propagation   nan
# loss function   nan
# loss matrix   nan
# lossless data compression   nan
# lossy data compression   nan
# lower bound   nan
# machine learning   nan
# macrostate   nan
# mahalanobis distance   nan
# manifold   nan
# map   nan
# margin   nan
# marginal likelihood   nan
# marginal probability   nan
# markov blanket   nan
# markov boundary   nan
# markov chain   nan
# markov chain monte carlo   nan
# markov model   nan
# markov network   nan
# markov random ﬁeld   nan
# max-sum algorithm   nan
# maximal clique   nan
# maximal spanning tree   nan
# maximization step   nan
# maximum likelihood   nan
# maximum margin   nan
# maximum posterior   nan
# markov chain monte carlo   mcmc
# mixture density network   mdn
# multidimensional scaling   mds
# mean   nan
# mean ﬁeld theory   nan
# mean value theorem   nan
# measure theory   nan
# memory-based methods   nan
# message passing   nan
# metropolis algorithm   nan
# metropolis-hastings algorithm   nan
# microstate   nan
# minimum risk   nan
# minkowski loss   nan
# missing at random   nan
# missing data   nan
# mixing coefﬁcient   nan
# mixture component   nan
# mixture density network   nan
# mixture distribution   nan
# mixture model   nan
# mixture of experts   nan
# mixture of gaussians   nan
# multilayer perceptron   mlp
# mnist data   nan
# model comparison   nan
# model evidence   nan
# model selection   nan
# moment matching   nan
# momentum variable   nan
# monte carlo em algorithm   nan
# monte carlo sampling   nan
# moore-penrose pseudo-inverse   nan
# moralization   nan
# markov random ﬁeld   mrf
# multidimensional scaling   nan
# multilayer perceptron   nan
# multimodality   nan
# multinomial distribution   nan
# multiplicity   nan
# mutual information   nan
# nadaraya-watson   nan
# naive bayes model   nan
# nats   nan
# natural language modelling   nan
# natural parameters   nan
# nearest-neighbour methods   nan
# neural network   nan
# newton-raphson   nan
# node   nan
# noiseless coding theorem   nan
# nonidentiﬁability   nan
# noninformative prior   nan
# nonparametric methods   nan
# normal distribution   nan
# normal equations   nan
# normal-gamma distribution   nan
# normal-wishart distribution   nan
# normalized exponential   nan
# novelty detection   nan
# ν-svm   nan
# object recognition   nan
# observed variable   nan
# occam factor   nan
# oil ﬂow data   nan
# old faithful data   nan
# on-line learning   nan
# one-versus-one classiﬁer   nan
# one-versus-the-rest classiﬁer   nan
# ordered over-relaxation   nan
# ornstein-uhlenbeck process   nan
# orthogonal least squares   nan
# outlier   nan
# outliers   nan
# over-ﬁtting   nan
# over-relaxation   nan
# pac learning   nan
# pac-bayesian framework   nan
# parameter shrinkage   nan
# parent node   nan
# particle ﬁlter   nan
# partition function   nan
# parzen estimator   nan
# parzen window   nan
# pattern recognition   nan
# principal component analysis   pca
# pending message   nan
# perceptron   nan
# perceptron criterion   nan
# perfect map   nan
# periodic variable   nan
# phase space   nan
# photon noise   nan
# plate   nan
# polynomial curve ﬁtting   nan
# polytree   nan
# position variable   nan
# positive deﬁnite covariance   nan
# positive deﬁnite matrix   nan
# positive semideﬁnite covariance   nan
# positive semideﬁnite matrix   nan
# posterior probability   nan
# posterior step   nan
# potential energy   nan
# potential function   nan
# power ep   nan
# power method   nan
# precision matrix   nan
# precision parameter   nan
# predictive distribution   nan
# preprocessing   nan
# principal component analysis   nan
# principal curve   nan
# principal subspace   nan
# principal surface   nan
# prior   nan
# probabilistic graphical model   nan
# probabilistic pca   nan
# probability   nan
# probably approximately correct   nan
# probit function   nan
# probit regression   nan
# product rule of probability   nan
# proposal distribution   nan
# protected conjugate gradients   nan
# protein sequence   nan
# pseudo-inverse   nan
# pseudo-random numbers   nan
# quadratic discriminant   nan
# quality parameter   nan
# radial basis function   nan
# rauch-tung-striebel equations   nan
# regression   nan
# regression function   nan
# regularization   nan
# regularized least squares   nan
# reinforcement learning   nan
# reject option   nan
# rejection sampling   nan
# relative entropy   nan
# relevance vector   nan
# relevance vector machine   nan
# responsibility   nan
# ridge regression   nan
# root-mean-square error   rms error
# robbins-monro algorithm   nan
# robot arm   nan
# robustness   nan
# root node   nan
# root-mean-square error   nan
# rosenblatt   nan
# rotation invariance   nan
# rauch-tung-striebel equations   rts equations
# running intersection property   nan
# relevance vector machine   rvm
# sample mean   nan
# sample variance   nan
# sampling-importance-resampling   nan
# scale invariance   nan
# scale parameter   nan
# scaling factor   nan
# schwarz criterion   nan
# self-organizing map   nan
# sequential data   nan
# sequential estimation   nan
# sequential gradient descent   nan
# sequential learning   nan
# sequential minimal optimization   nan
# serial message passing schedule   nan
# shannon   nan
# shared parameters   nan
# shrinkage   nan
# shur complement   nan
# sigmoid   nan
# simplex   nan
# single-class support vector machine   nan
# singular value decomposition   nan
# sinusoidal data   nan
# sampling-importance-resampling   sir
# skip-layer connection   nan
# slack variable   nan
# slice sampling   nan
# sequential minimal optimization   smo
# smoother matrix   nan
# smoothing parameter   nan
# soft margin   nan
# soft weight sharing   nan
# softmax function   nan
# self-organizing map   som
# sparsity   nan
# sparsity parameter   nan
# spectrogram   nan
# speech recognition   nan
# sphereing   nan
# spline functions   nan
# standard deviation   nan
# standardizing   nan
# state space model   nan
# stationary kernel   nan
# statistical bias   nan
# statistical independence   nan
# statistical learning theory   nan
# steepest descent   nan
# stirling’s approximation   nan
# stochastic   nan
# stochastic em   nan
# stochastic gradient descent   nan
# stochastic process   nan
# stratiﬁed ﬂow   nan
# student’s t-distribution   nan
# subsampling   nan
# sufﬁcient statistics   nan
# sum rule of probability   nan
# sum-of-squares error   nan
# sum-product algorithm   nan
# supervised learning   nan
# support vector   nan
# support vector machine   nan
# survival of the ﬁttest   nan
# singular value decomposition   svd
# support vector machine   svm
# switching hidden markov model   nan
# switching state space model   nan
# synthetic data sets   nan
# tail-to-tail path   nan
# tangent distance   nan
# tangent propagation   nan
# tapped delay line   nan
# target vector   nan
# test set   nan
# threshold parameter   nan
# tied parameters   nan
# tikhonov regularization   nan
# time warping   nan
# tomography   nan
# training   nan
# training set   nan
# transition probability   nan
# translation invariance   nan
# tree-reweighted message passing   nan
# treewidth   nan
# trellis diagram   nan
# triangulated graph   nan
# type 2 maximum likelihood   nan
# undetermined multiplier   nan
# undirected graph   nan
# uniform distribution   nan
# uniform sampling   nan
# uniquenesses   nan
# unobserved variable   nan
# unsupervised learning   nan
# utility function   nan
# validation set   nan
# vapnik-chervonenkis dimension   nan
# variance   nan
# variational inference   nan
# vapnik-chervonenkis dimension   vc dimension
# soft   nan
# between-class covariance   nan
# within-class covariance   nan
# partitioned covariance matrix   nan
# conditional entropy   nan
# differential entropy   nan
# relative entropy   nan
# functional derivative   nan
# conditional gaussian   nan
# gaussian marginal   nan
# gaussian mixture   nan
# directed graphical model   nan
# undirected graphical model   nan
# autoregressive hidden markov model   nan
# factorial hidden markov model   nan
# input-output hidden markov model   nan
# left-to-right hidden markov model   nan
# gaussian kernel function   nan
# fisher linear discriminant   nan
# variational linear regression   nan
# bayesian logistic regression   nan
# multiclass logistic regression   nan
# margin error   nan
# soft margin   nan
# homogeneous markov chain   nan
# message passing schedule   nan
# variational message passing   nan
# conditional mixture model   nan
# convolutional neural network   nan
# perceptron convergence theorem   nan
# perceptron hardware   nan
# conjugate prior   nan
# consistent gaussian prior   nan
# improper prior   nan
# noninformative prior   nan
# bayesian probability   nan
# probability density   nan
# probability mass function   nan
# prior probability   nan
# probability sum rule   nan
# probability theory   nan
# tikhonov regularization   nan
# hierarchical bayesian analysis   nan
# model averaging bayesian analysis   nan
# mixture model bernoulli distribution   nan
# diagonal covariance matrix   nan
# isotropic covariance matrix   nan
# positive deﬁnite covariance matrix   nan
# gaussian mixture expectation maximization   nan
# generalized expectation maximization   nan
# sampling methods expectation maximization   nan
# mixture model factor analysis   nan
# maximum likelihood gaussian   nan
# sequential estimation gaussian   nan
# sufﬁcient statistics gaussian   nan
# wrapped gaussian   nan
# directional curvature generative topographic mapping   nan
# magniﬁcation factor generative topographic mapping   nan
# blocking gibbs sampling   nan
# bipartite graphical model   nan
# factorization graphical model   nan
# fully connected graphical model   nan
# inference graphical model   nan
# tree graphical model   nan
# treewidth graphical model   nan
# triangulated graphical model   nan
# diagonal approximation hessian matrix   nan
# exact evaluation hessian matrix   nan
# fast multiplication hessian matrix   nan
# ﬁnite differences hessian matrix   nan
# inverse hessian matrix   nan
# outer product approximation hessian matrix   nan
# forward-backward algorithm hidden markov model   nan
# maximum likelihood hidden markov model   nan
# scaling factor hidden markov model   nan
# sum-product algorithm hidden markov model   nan
# switching hidden markov model   nan
# variational inference hidden markov model   nan
# extended kalman ﬁlter   nan
# fisher kernel function   nan
# homogeneous kernel function   nan
# nonvectorial inputs kernel function   nan
# stationary kernel function   nan
# inference linear dynamical system   nan
# em linear regression   nan
# mixture model linear regression   nan
# mixture model logistic regression   nan
# ﬁrst order markov chain   nan
# second order markov chain   nan
# homogeneous markov model   nan
# gaussian mixture maximum likelihood   nan
# singularities maximum likelihood   nan
# type 2 maximum likelihood   nan
# pending message message passing   nan
# linear regression mixture model   nan
# logistic regression mixture model   nan
# symmetries mixture model   nan
# regularization neural network   nan
# relation to gaussian process neural network   nan
# bayesian principal component analysis   nan
# em algorithm principal component analysis   nan
# gibbs sampling principal component analysis   nan
# mixture distribution principal component analysis   nan
# physical analogy principal component analysis   nan
# classical probability   nan
# frequentist probability   nan
# product rule probability   nan
# switching state space model   nan
# for hidden markov model sum-product algorithm   nan
# for regression support vector machine   nan
# multiclass support vector machine   nan
# for gaussian mixture variational inference   nan
# for hidden markov model variational inference   nan
# local variational inference   nan
# vector quantization vapnik-chervonenkis dimension   nan
# vertex vapnik-chervonenkis dimension   nan
# visualization vapnik-chervonenkis dimension   nan
# viterbi algorithm vapnik-chervonenkis dimension   nan
# von mises distribution vapnik-chervonenkis dimension   nan
# wavelets vapnik-chervonenkis dimension   nan
# weak learner vapnik-chervonenkis dimension   nan
# weight decay vapnik-chervonenkis dimension   nan
# weight parameter vapnik-chervonenkis dimension   nan
# weight sharing vapnik-chervonenkis dimension   nan
# weight vector soft   nan
# weight-space symmetry soft   nan
# weighted least squares soft   nan
# well-determined parameters soft   nan
# whitening soft   nan
# wishart distribution soft   nan
# within-class covariance soft   nan
# woodbury identity soft   nan
# wrapped distribution soft   nan
# yellowstone national park soft   nan

# %%
def contain_section(line):
    line = line.strip()
    if len(line) > 4:
        if line[0] == "=" and line[1] == "=" and line[-2] == "=" and line[-1] == "=":
            return True
        else:
            return False

def wiki_section_extract(content):
    lines = content.split("\n")
    sections = ""
    for line in lines:
        if contain_section(line):
            sections += line[3:-3] + "\n"
    return sections.strip()

def keyword_data(topic = "", abbr = "", wiki_title = "", wiki_summary = "",
                 wiki_content = "", wiki_html = "", wiki_links = "", wiki_sections = ""):
    data = {
        'topic': topic,
        "abbreviation": abbr,
        "wiki_title": wiki_title,
        "wiki_summary": wiki_summary,
        "wiki_content": wiki_content,
        "wiki_html": wiki_html,
        "wiki_links": wiki_links,
        "wiki_sections": wiki_sections
    }
    return data


def extract_data(topic, abbr = ""):
    wiki_title = ""
    wiki_summary = ""
    wiki_content = ""
    wiki_html = ""
    wiki_links = ""
    wiki_sections = ""
    try:
        wiki = wikipedia.search(topic)[0]        
        try:
            wiki_data = wikipedia.page(wiki)
            wiki_title = wiki_data.title
            wiki_summary = wiki_data.summary
            wiki_content = wiki_data.content
            wiki_html = wiki_data.html()
            wiki_links = wiki_data.links
            wiki_sections = wiki_section_extract(wiki_content)

        except wikipedia.exceptions.DisambiguationError as e:
            print("blank")
        except wikipedia.exceptions.PageError as e:
            print("blank")

    except IndexError:
        print("blank")
    
    
    data = keyword_data(topic, abbr, wiki_title, wiki_summary,
                        wiki_content, wiki_html, wiki_links, wiki_sections)

    return data

# %%
list_len = len(relevant_topics)
all_keyword_data = {}

# %%
complete = 330
for i in range(list_len - complete):
    i += complete
    data = extract_data(relevant_topics[i], topics_abbr[i])
    all_keyword_data[i] = data
    print(i)
# Out:
# 330
# 331
# /home/shivam/anaconda3/lib/python3.7/site-packages/wikipedia/wikipedia.py:389: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 389 of the file /home/shivam/anaconda3/lib/python3.7/site-packages/wikipedia/wikipedia.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   lis = BeautifulSoup(html).find_all('li')
# blank
# 332
# 333
# 334
# 335
# 336
# 337
# 338
# 339
# 340
# 341
# 342
# 343
# 344
# 345
# 346
# blank
# 347
# 348
# 349
# 350
# 351
# 352
# 353
# 354
# 355
# 356
# 357
# 358
# 359
# 360
# 361
# 362
# 363
# 364
# 365
# 366
# 367
# 368
# 369
# 370
# 371
# blank
# 372
# 373
# 374
# 375
# 376
# 377
# 378
# 379
# 380
# 381
# 382
# 383
# 384
# 385
# 386
# 387
# 388
# 389
# 390
# 391
# 392
# 393
# 394
# 395
# 396
# 397
# 398
# 399
# 400
# 401
# 402
# 403
# 404
# 405
# 406
# 407
# 408
# 409
# 410
# 411
# 412
# 413
# 414
# 415
# 416
# 417
# 418
# 419
# 420
# 421
# 422
# 423
# 424
# 425
# 426
# 427
# blank
# 428
# 429
# 430
# 431
# blank
# 432
# 433
# 434
# 435
# 436
# 437
# blank
# 438
# 439
# 440
# 441
# 442
# 443
# 444
# 445
# 446
# 447
# 448
# 449
# 450
# 451
# 452
# 453
# 454
# 455
# 456
# 457
# 458
# 459
# 460
# 461
# 462
# 463
# 464
# 465
# 466
# 467
# 468
# 469
# 470
# 471
# 472
# 473
# 474
# 475
# 476
# 477
# 478
# 479
# 480
# 481
# blank
# 482
# 483
# 484
# 485
# 486
# 487
# 488
# 489
# 490
# 491
# 492
# blank
# 493
# 494
# 495
# 496
# 497
# 498
# blank
# 499
# 500
# 501
# 502
# 503
# 504
# 505
# blank
# 506
# 507
# 508
# 509
# 510
# 511
# 512
# 513
# 514
# 515
# 516
# 517
# 518
# 519
# 520
# 521
# 522
# blank
# 523
# 524
# 525
# 526
# 527
# 528
# 529
# 530
# blank
# 531
# 532
# 533
# 534
# 535
# 536
# 537
# 538
# 539
# 540
# 541
# 542
# 543
# 544
# 545
# 546
# 547
# 548
# 549
# 550
# 551
# 552
# 553
# 554
# 555
# 556
# 557
# blank
# 558
# 559
# blank
# 560
# blank
# 561
# 562
# 563
# 564
# 565
# 566
# 567
# 568
# 569
# 570
# 571
# 572
# 573
# 574
# 575
# 576
# 577
# 578
# 579
# 580
# 581
# 582
# 583
# 584
# 585
# 586
# 587
# 588
# 589
# 590
# 591
# 592
# 593
# 594
# 595
# 596
# 597
# 598
# blank
# 599
# 600
# blank
# 601
# 602
# 603
# 604
# 605
# 606
# 607
# 608
# 609
# 610
# 611
# 612
# 613
# 614
# 615
# 616
# blank
# 617
# 618
# 619
# 620
# 621
# 622
# 623
# 624
# 625
# 626
# 627
# 628
# 629
# 630
# 631
# 632
# 633
# 634
# blank
# 635
# 636
# 637
# 638
# 639
# 640
# 641
# 642
# 643
# 644
# 645
# blank
# 646
# 647
# 648
# 649
# 650
# 651
# 652
# 653
# 654
# 655
# 656
# 657
# 658
# 659
# 660
# 661
# 662
# 663
# 664
# 665
# 666
# 667
# 668
# 669
# 670
# 671
# 672
# 673
# 674
# 675
# 676
# 677
# 678
# 679
# 680
# 681
# 682
# 683
# 684
# blank
# 685
# 686
# 687
# 688
# 689
# 690
# 691
# 692
# 693
# 694
# 695
# 696
# 697
# 698
# 699
# 700
# 701
# blank
# 702
# blank
# 703
# 704
# 705
# 706
# 707
# 708
# 709
# 710
# 711
# blank
# 712
# 713
# 714
# 715
# 716
# 717
# 718
# 719
# 720
# 721
# 722
# 723
# 724
# 725
# 726
# blank
# 727
# 728
# 729
# 730
# 731
# 732
# 733
# 734
# 735
# 736
# 737
# 738
# 739
# 740
# 741
# 742
# 743
# 744
# 745
# 746
# 747
# 748
# 749
# 750
# 751
# 752
# 753
# 754
# 755
# 756
# 757
# 758
# 759
# 760
# 761
# 762
# 763
# 764
# 765
# 766
# blank
# 767
# 768
# 769
# 770
# 771
# 772
# 773
# 774
# 775
# 776
# 777
# 778
# 779

# %%
extracted_data = all_keyword_data

# %%
print(len(all_keyword_data))
# Out:
# 780

# %%
missing_index = 70

# %%
all_keyword_data[missing_index] = extract_data(relevant_topics[missing_index], topics_abbr[missing_index])

# %% [markdown]
# ## Saving data in JSON Format

# %%
with open('output_data/keyterms_wiki_data.json', 'w') as file:
    json.dump(all_keyword_data, file)

# %% [markdown]
# ## Saving data in CSV format

# %%
df = pd.DataFrame(columns=['topic', 'abbreviation', 'wiki_title', 'wiki_summary', 'wiki_content', 'wiki_html', 'wiki_links', 'wiki_sections'])

for i in range(len(all_keyword_data)):
    df = df.append(all_keyword_data[i], ignore_index=True)

df.to_csv("output_data/keyterms_wiki_data.csv")
