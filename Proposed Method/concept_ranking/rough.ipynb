# %%
import pandas as pd
import collections

# %%
book_data = "../output_files/physics_normalized_content.csv"
concept_data = "../output_files/concept_final_indexing.csv"

# %%
def read_concept_data(file_name):
	df = pd.read_csv(file_name, encoding = "utf-8")
	req_data = {}
	for i in range(df.shape[0]):
		concept = df[["concept"]].iloc[i].values[0]
		func_type = df[["type"]].iloc[i].values[0]
		if func_type != 0: title_match_index = df[["index"]].iloc[i].values[0]
		else: title_match_index = ""

		req_data[i] = {
			"concept": concept,
			"func_type": func_type,
			"title_match_index": title_match_index,
			"content_match_index": [],
			"freq_content_match": []
		}
	return req_data

def read_book_data(file_name):
	df = pd.read_csv(file_name, encoding = "utf-8")
	req_data = {}
	for i in range(df.shape[0]):
		section = df[["section"]].iloc[i].values[0]
		if df[["tagged_content"]].iloc[i].isna().values[0]:
			content = ""
		else:
			content = df[["tagged_content"]].iloc[i].values[0]
		req_data[i] = {
			"section": section,
			"content": content
		}
	return req_data

# %%
def get_concept_from_content(data):
    for i in range(len(data)):
        content = data[i]["content"]
        concepts = []

        c1 = content.split("<b>")
        for j in range(1, len(c1)):
            concept = c1[j].split("</b>")[0]
            concepts.append(concept)

        data[i]["concepts"] = concepts
        print(concepts)
    return data


def concepts_collections(concepts):
	counter = collections.Counter(concepts)
	concept_list = list(counter.keys())
	freq_list = list(counter.values())
	return (concept_list, freq_list)


def get_concept_content_matching(concept_data, book_data):
	for i in range(len(book_data)):
		concepts = book_data[i]["concepts"]
		concept_list, freq_list = concepts_collections(concepts)
		for j in range(len(concept_list)):
			concept = concept_list[j]
			for k in range(len(concept_data)):
				if concept_data[k]["concept"] == concept:
					section = book_data[i]["section"]
					concept_data[k]["content_match_index"].append(section)
					concept_data[k]["freq_content_match"].append(freq_list[j])
	return concept_data

# %%
def sort_concept_data(concept_data):
	for i in range(len(concept_data)):
		index = concept_data[i]["content_match_index"]
		concept_data[i]["content_match_index"] = "|".join(index)

		freq = concept_data[i]["freq_content_match"]
		concept_data[i]["freq_content_match"] = "|".join(freq)
	return concept_data



def save_concept_data(concept_data, output_file):
	columns = ["concept", "type", "title_match_index", "content_match_index", "freq_content_match"]
	df = pd.DataFrame(columns = columns)
	for i in range(len(concept_data)):
		df = df.append(data[i], ignore_index = True)
	df.to_csv(output_file)
	return True

# %%
book_data = read_book_data(book_data)
concept_index_data = read_concept_data(concept_data)

# %%
book_data = get_concept_from_content(book_data)
# Out:
# ['Physics', 'Physics', 'Work (physics)', 'Physics', 'Field (physics)', 'Physics', 'Physics', 'Physics', 'Wave', 'Wave', 'Energy level', 'Physics']
# []
# ['Metre', 'Metre', 'Length', 'Physical quantity', 'Temperature', 'Distance', 'Physical quantity', 'Physical quantity', 'Length', 'Temperature', 'Distance', 'Physical quantity']
# []
# ['Physical quantity']
# ['Metre', 'Kilogram', 'Force', 'Work (physics)', 'Physics', 'Speed', 'Light', 'Energy', 'Physics']
# ['Metre', 'Metre', 'Hertz', 'Hertz']
# ['Work (physics)', 'Kilogram', 'Metre', 'Kilogram', 'Metre', 'Joule', 'Metre']
# []
# []
# ['Speed']
# ['Work (physics)', 'Work (physics)', 'Speed', 'Light', 'Speed', 'Light', 'Speed', 'Light']
# []
# ['Kilogram', 'Kilogram', 'Kilogram', 'Kilogram', 'Power (physics)']
# ['Work (physics)', 'Physical quantity']
# ['Metre', 'Metre']
# ['Speed', 'Temperature', 'Speed', 'Temperature', 'Temperature', 'Temperature', 'Temperature']
# ['Mass', 'Mass', 'Kilogram', 'Mass', 'Kilogram', 'Mass', 'Kilogram', 'Kilogram']
# []
# ['Position (vector)', 'Displacement (vector)', 'Speed', 'Velocity', 'Position (vector)', 'Velocity', 'Position (vector)', 'Displacement (vector)', 'Speed', 'Velocity', 'Motion', 'Motion', 'Motion']
# ['Motion', 'Position (vector)', 'Position (vector)', 'Position (vector)', 'Direction (geometry)']
# ['Frame of reference', 'Frame of reference', 'Direction (geometry)', 'Frame of reference', 'Frame of reference', 'Direction (geometry)', 'Frame of reference', 'Frame of reference', 'Position (vector)', 'Direction (geometry)', 'Position (vector)', 'Frame of reference']
# ['Position (vector)', 'Position (vector)', 'Position (vector)', 'Position (vector)', 'Position (vector)', 'Position (vector)', 'Length', 'Position (vector)', 'Direction (geometry)', 'Position (vector)', 'Direction (geometry)', 'Direction (geometry)', 'Direction (geometry)', 'Position (vector)', 'Direction (geometry)', 'Direction (geometry)', 'Direction (geometry)', 'Position (vector)']
# ['Displacement (vector)', 'Displacement (vector)', 'Position (vector)', 'Displacement (vector)', 'Position (vector)', 'Position (vector)', 'Position (vector)', 'Displacement (vector)', 'Direction (geometry)', 'Euclidean vector', 'Position (vector)', 'Position (vector)', 'Displacement (vector)', 'Physics', 'Displacement (vector)', 'Physics', 'Displacement (vector)', 'Position (vector)', 'Distance', 'Distance', 'Distance', 'Distance', 'Direction (geometry)', 'Scalar (mathematics)', 'Displacement (vector)', 'Distance', 'Displacement (vector)', 'Direction (geometry)', 'Euclidean vector', 'Distance', 'Distance', 'Displacement (vector)', 'Displacement (vector)', 'Position (vector)', 'Position (vector)', 'Distance', 'Displacement (vector)', 'Direction (geometry)', 'Position (vector)', 'Displacement (vector)', 'Distance', 'Position (vector)']
# ['Displacement (vector)', 'Displacement (vector)', 'Direction (geometry)', 'Direction (geometry)', 'Position (vector)', 'Frame of reference', 'Position (vector)', 'Direction (geometry)', 'Position (vector)', 'Direction (geometry)', 'Displacement (vector)', 'Distance', 'Direction (geometry)', 'Displacement (vector)']
# ['Euclidean vector', 'Scalar (mathematics)', 'Euclidean vector', 'Physical quantity', 'Direction (geometry)', 'Scalar (mathematics)', 'Physical quantity']
# ['Velocity', 'Velocity', 'Position (vector)', 'Velocity', 'Velocity', 'Velocity', 'Velocity', 'Velocity', 'Displacement (vector)', 'Velocity', 'Position (vector)', 'Position (vector)', 'Displacement (vector)', 'Displacement (vector)', 'Euclidean vector', 'Scalar (mathematics)', 'Velocity', 'Euclidean vector', 'Velocity', 'Displacement (vector)', 'Velocity', 'Position (vector)', 'Position (vector)', 'Velocity', 'Motion', 'Velocity', 'Displacement (vector)', 'Motion', 'Motion', 'Velocity', 'Velocity', 'Speed', 'Distance', 'Distance', 'Scalar (mathematics)', 'Speed', 'Scalar (mathematics)', 'Speed', 'Speed', 'Velocity', 'Direction (geometry)']
# ['Speed', 'Velocity', 'Speed', 'Position (vector)', 'Scalar (mathematics)', 'Direction (geometry)', 'Position (vector)', 'Velocity', 'Position (vector)', 'Euclidean vector', 'Direction (geometry)', 'Position (vector)', 'Velocity', 'Speed']
# ['Velocity', 'Velocity', 'Velocity', 'Velocity', 'Velocity', 'Euclidean vector', 'Euclidean vector', 'Motion', 'Motion', 'Direction (geometry)', 'Velocity', 'Position (vector)', 'Acceleration', 'Velocity', 'Speed', 'Velocity', 'Position (vector)', 'Speed', 'Position (vector)', 'Direction (geometry)', 'Velocity', 'Speed', 'Direction (geometry)', 'Velocity', 'Position (vector)', 'Acceleration', 'Velocity', 'Position (vector)', 'Work (physics)', 'Direction (geometry)', 'Motion', 'Velocity', 'Position (vector)', 'Velocity']
# ['Motion', 'Displacement (vector)', 'Distance', 'Velocity', 'Speed', 'Motion', 'Motion', 'Velocity', 'Motion', 'Motion']
# ['Motion', 'Position (vector)', 'Position (vector)', 'Metre', 'Metre', 'Metre', 'Position (vector)', 'Displacement (vector)', 'Position (vector)', 'Velocity', 'Displacement (vector)', 'Velocity', 'Position (vector)', 'Velocity', 'Position (vector)', 'Metre', 'Position (vector)', 'Metre', 'Velocity', 'Position (vector)', 'Velocity', 'Velocity', 'Velocity', 'Position (vector)', 'Velocity']
# ['Motion', 'Velocity', 'Motion', 'Position (vector)', 'Velocity', 'Velocity', 'Metre', 'Position (vector)', 'Position (vector)', 'Position (vector)', 'Velocity', 'Velocity', 'Motion', 'Velocity', 'Velocity', 'Motion', 'Velocity', 'Motion', 'Velocity', 'Velocity', 'Velocity', 'Velocity', 'Motion', 'Velocity']
# ['Motion', 'Velocity', 'Velocity', 'Distance', 'Distance', 'Motion', 'Motion', 'Velocity', 'Velocity', 'Displacement (vector)', 'Velocity', 'Position (vector)', 'Velocity', 'Velocity', 'Motion', 'Position (vector)', 'Velocity', 'Motion', 'Position (vector)', 'Direction (geometry)', 'Velocity', 'Position (vector)', 'Speed', 'Motion', 'Motion']
# []
# ['Motion', 'Motion', 'Motion', 'Motion', 'Motion', 'Work (physics)', 'Motion', 'Distance', 'Velocity', 'Force', 'Friction', 'Force', "Newton's laws of motion"]
# []
# ['Speed', 'Distance', 'Work (physics)']
# []
# ['Force', 'Mass', 'Kilogram', 'Gravity', 'Force', 'Gravity', 'Work (physics)', 'Planet']
# ['Mass', 'Kilogram', 'Kilogram', 'Mass', 'Mass', 'Mass', 'Kilogram', 'Planet', 'Scalar (mathematics)', 'Force', 'Planet', 'Euclidean vector']
# []
# ['Field (physics)', 'Mass', 'Force', 'Gravitational field', 'Mass', 'Force']
# ['Free fall', 'Motion', 'Gravitational field', 'Force', 'Free fall', 'Motion', 'Gravitational field', 'Free fall', 'Motion', 'Gravitational field', 'Force', 'Friction', 'Motion', 'Gravity', 'Mass', 'Mass', 'Friction', 'Friction', 'Electrical ', 'Electrical resistance and conductance', 'Motion']
# ['Potential energy', 'Energy', 'Position (vector)', 'Potential energy', 'Potential energy', 'Potential energy', 'Electric potential energy', 'Potential energy', 'Potential energy', 'Potential energy', 'Energy', 'Position (vector)', 'Potential energy', 'Energy', 'Position (vector)', 'Potential energy', 'Potential energy', 'Potential energy', 'Potential energy', 'Potential energy', 'Potential energy', 'Joule', 'Mass', 'Kilogram', 'Mass', 'Kilogram', 'Force', 'Gravity', 'Potential energy', 'Potential energy', 'Potential energy', 'Potential energy', 'Potential energy', 'Potential energy', 'Potential energy', 'Potential energy']
# ['Energy', 'Energy', 'Energy', 'Motion', 'Energy', 'Energy', 'Motion', 'Energy', 'Energy', 'Energy', 'Kinetic energy', 'Velocity', 'Mass', 'Kilogram', 'Energy', 'Kilogram', 'Energy', 'Kilogram', 'Velocity', 'Velocity', 'Energy', 'Energy', 'Velocity', 'Energy']
# ['Energy', 'Joule', 'Energy']
# ['Mechanical energy', 'Potential energy', 'Energy', 'Mechanical energy', 'Potential energy', 'Energy', 'Kinetic energy', 'Mechanical energy']
# ['Energy level', 'Energy', 'Energy', 'Energy', 'Energy', 'Energy', 'Potential energy', 'Energy', 'Potential energy', 'Energy', 'Mechanical energy', 'Force', 'Mechanical energy', 'Mechanical energy', 'Mechanical energy', 'Mechanical energy', 'Mechanical energy', 'Mechanical energy', 'Potential energy', 'Energy', 'Energy', 'Mechanical energy', 'Gravitational field', 'Gravity', 'Force', 'Electrical ', 'Electrical resistance and conductance', 'Mechanical energy', 'Velocity', 'Free fall', 'Velocity', 'Mass', 'Energy', 'Velocity', 'Energy', 'Potential energy', 'Friction', 'Mechanical energy', 'Friction', 'Mechanical energy', 'Mechanical energy', 'Work (physics)', 'Friction', 'Work (physics)', 'Friction', 'Mechanical energy', 'Force', 'Force', 'Force', 'Friction', 'Force', 'Electrical ', 'Electrical resistance and conductance', 'Tension (physics)', 'Force', 'Force', 'Force', 'Gravity', 'Force', 'Mechanical energy']
# ['Mechanical energy', 'Friction', 'Kinetic energy', 'Motion', 'Kinetic energy', 'Motion', 'Mechanical energy', 'Velocity', 'Potential energy', 'Potential energy', 'Energy', 'Potential energy', 'Energy', 'Potential energy', 'Energy', 'Energy', 'Potential energy', 'Potential energy', 'Energy', 'Potential energy', 'Energy', 'Potential energy', 'Energy']
# ['Potential energy', 'Potential energy', 'Distance', 'Metre', 'Energy', 'Energy', 'Energy', 'Distance', 'Mechanical energy', 'Mechanical energy', 'Motion', 'Potential energy', 'Energy']
# []
# ['Wave', 'Wave', 'Wave', 'Wave', 'Wave', 'Wave', 'Energy']
# ['Wave', 'Wave', 'Wave', 'Wave', 'Wave', 'Sound', 'Wave', 'Wave', 'Wave', 'Wave', 'Position (vector)', 'Wave']
# []
# ['Amplitude', 'Displacement (vector)', 'Position (vector)', 'Length', 'Amplitude', 'Amplitude', 'Displacement (vector)', 'Length', 'Amplitude']
# ['Speed', 'Speed', 'Distance', 'Speed', 'Distance', 'Speed', 'Distance', 'Speed', 'Speed', 'Amplitude', 'Length']
# ['Motion', 'Motion', 'Motion', 'Motion', 'Motion']
# ['Motion', 'Motion', 'Motion', 'Motion', 'Motion', 'Position (vector)', 'Velocity']
# ['Motion', 'Motion', 'Direction (geometry)', 'Motion']
# ['Reflection (physics)', 'Reflection (physics)', 'Speed', 'Length', 'Speed', 'Length', 'Speed', 'Length', 'Speed', 'Length', 'Reflection (physics)']
# []
# ['Reflection (physics)']
# ['Reflection (physics)', 'Reflection (physics)', 'Physics']
# ['Direction (geometry)', 'Amplitude', 'Amplitude', 'Amplitude', 'Amplitude', 'Amplitude', 'Amplitude', 'Amplitude', 'Amplitude']
# []
# ['Wave', 'Wave', 'Wave', 'Wave', 'Wave', 'Wave']
# ['Wave', 'Wave', 'Wave', 'Wave', 'Wave', 'Wave', 'Direction (geometry)', 'Wave', 'Wave', 'Wave', 'Wave', 'Direction (geometry)', 'Wave', 'Wave', 'Wave', 'Displacement (vector)', 'Position (vector)', 'Displacement (vector)', 'Wave', 'Motion', 'Motion', 'Motion', 'Wave']
# ['Wave', 'Crest (physics)', 'Crest (physics)', 'Crest (physics)', 'Crest (physics)', 'Wave', 'Crest (physics)', 'Wave', 'Displacement (vector)', 'Wave', 'Crest (physics)', 'Displacement (vector)']
# ['Wave', 'Amplitude', 'Wavelength', 'Length', 'Amplitude', 'Amplitude', 'Displacement (vector)', 'Position (vector)', 'Amplitude', 'Distance', 'Position (vector)', 'Distance', 'Crest (physics)', 'Position (vector)', 'Distance', 'Amplitude', 'Wave', 'Wave', 'Position (vector)', 'Amplitude', 'Wave', 'Amplitude', 'Metre', 'Wavelength', 'Distance', 'Distance', 'Distance', 'Crest (physics)', 'Crest (physics)', 'Distance', 'Distance', 'Crest (physics)', 'Distance', 'Wavelength', 'Wave', 'Wavelength', 'Wavelength', 'Metre']
# ['Distance', 'Wave', 'Crest (physics)', 'Wavelength', 'Wavelength', 'Distance', 'Wavelength', 'Wave', 'Wavelength', 'Wave', 'Distance', 'Wavelength']
# ['Wave', 'Crest (physics)', 'Wave', 'Crest (physics)', 'Frequency', 'Wave', 'Frequency', 'Crest (physics)', 'Frequency', 'Frequency']
# ['Speed', 'Speed', 'Distance', 'Distance', 'Wavelength', 'Wave', 'Wavelength', 'Distance', 'Speed', 'Wave', 'Distance', 'Wave']
# ['Motion', 'Motion', 'Motion', 'Motion', 'Wave', 'Wave', 'Wave', 'Motion', 'Wave', 'Position (vector)', 'Wave', 'Velocity', 'Motion graphs and derivatives', 'Velocity', 'Motion graphs and derivatives', 'Velocity', 'Motion graphs and derivatives', 'Motion', 'Motion', 'Work (physics)']
# []
# ['Reflection (physics)', 'Wave', 'Wave', 'Reflection (physics)', 'Reflection (physics)', 'Wave', 'Crest (physics)']
# ['Wave', 'Reflection (physics)', 'Wave', 'Reflection (physics)']
# ['Reflection (physics)', 'Wave', 'Wave', 'Wave', 'Direction (geometry)', 'Wave', 'Frequency', 'Wavelength', 'Standing wave', 'Standing wave', 'Standing wave', 'Reflection (physics)', 'Wave', 'Wave', 'Wave', 'Amplitude', 'Reflection (physics)', 'Wave', 'Wave', 'Wave', 'Wave', 'Wave', 'Reflection (physics)', 'Wave', 'Wave', 'Wave', 'Wave', 'Wave', 'Wave', 'Wave', 'Wave', 'Wave', 'Wave', 'Wave', 'Position (vector)', 'Crest (physics)', 'Motion', 'Reflection (physics)', 'Amplitude', 'Standing wave', 'Standing wave', 'Wave', 'Standing wave', 'Motion', 'Standing wave', 'Amplitude', 'Motion', 'Standing wave', 'Wavelength', 'Standing wave', 'Standing wave']
# ['Wave', 'Displacement (vector)', 'Standing wave', 'Wave', 'Wave', 'Wave', 'Displacement (vector)', 'Standing wave', 'Wave', 'Wave', 'Displacement (vector)', 'Standing wave', 'Wave', 'Wave', 'Wave', 'Displacement (vector)', 'Standing wave', 'Wave', 'Distance', 'Distance', 'Crest (physics)', 'Wave', 'Standing wave', 'Distance', 'Work (physics)', 'Wavelength', 'Distance', 'Distance', 'Wavelength', 'Wavelength']
# ['Wave', 'Sound', 'Wave', 'Wave', 'Standing wave', 'Wavelength', 'Standing wave', 'Standing wave', 'Wavelength', 'Standing wave', 'Standing wave', 'Frequency', 'Wavelength', 'Wavelength', 'Standing wave', 'Standing wave', 'Length', 'Wavelength', 'Work (physics)', 'Wavelength', 'Distance', 'Distance', 'Wavelength', 'Force', 'Distance', 'Distance', 'Wavelength', 'Wavelength', 'Distance', 'Wavelength', 'Wavelength', 'Wavelength', 'Wavelength', 'Work (physics)', 'Wavelength', 'Length', 'Distance', 'Wavelength', 'Distance', 'Distance', 'Wavelength', 'Length', 'Length', 'Wavelength', 'Wavelength', 'Wavelength', 'Distance', 'Wavelength', 'Wavelength', 'Wavelength', 'Length', 'Distance', 'Length', 'Distance', 'Distance', 'Wavelength', 'Distance', 'Length', 'Wavelength']
# ['Wave', 'Wave', 'Motion', 'Wave', 'Motion', 'Wavelength', 'Amplitude', 'Frequency', 'Wave', 'Motion', 'Wave', 'Wave', 'Crest (physics)', 'Crest (physics)', 'Wave', 'Wave', 'Wave', 'Crest (physics)', 'Amplitude', 'Wave', 'Amplitude', 'Wave', 'Interference (wave propagation)', 'Crest (physics)', 'Crest (physics)', 'Crest (physics)', 'Crest (physics)']
# []
# ['Light', 'Hardness', 'Light', 'Light', 'Light', 'Light', 'Light', 'Ray (optics)', 'Light', 'Wave', 'Light', 'Ray (optics)', 'Crest (physics)', 'Wave', 'Light', 'Ray (optics)', 'Light', 'Geometrical optics', 'Light', 'Ray (optics)', 'Telescope', 'Optical microscope', 'Light', 'Geometrical optics', 'Light', 'Ray (optics)', 'Light', 'Ray (optics)', 'Work (physics)', 'Distance', 'Reflection (physics)', 'Geometrical optics', 'Geometrical optics']
# ['Physics', 'Light', 'Ray (optics)', 'Direction (geometry)', 'Light', 'Light', 'Ray (optics)', 'Light', 'Light', 'Ray (optics)', 'Light', 'Light', 'Light', 'Reflection (physics)', 'Light', 'Reflection (physics)', 'Light', 'Light', 'Light', 'Ray (optics)', 'Light', 'Ray (optics)', 'Light', 'Light', 'Ray (optics)', 'Light']
# ['Light', 'Light']
# ['Ray (optics)', 'Light', 'Ray (optics)', 'Light', 'Ray (optics)', 'Ray (optics)']
# ['Reflection (physics)', 'Light', 'Ray (optics)', 'Mirror image', 'Light', 'Ray (optics)']
# ['Wave', 'Reflection (physics)', 'Wave', 'Sound', 'Wave', 'Light', 'Wave', 'Wave', 'Reflection (physics)', 'Light', 'Ray (optics)', 'Ray (optics)', 'Light', 'Ray (optics)', 'Reflection (physics)', 'Ray (optics)', 'Ray (optics)', 'Reflection (physics)', 'Angle of incidence', 'Ray (optics)', 'Reflection (physics)', 'Reflection (physics)', 'Ray (optics)', 'Ray (optics)', 'Light', 'Reflection (physics)', 'Reflection (physics)', 'Ray (optics)', 'Ray (optics)']
# ['Specular reflection', 'Angle of incidence', 'Reflection (physics)', 'Reflection (physics)', 'Ray (optics)', 'Specular reflection', 'Specular reflection', 'Angle of incidence', 'Reflection (physics)', 'Angle of incidence', 'Reflection (physics)', 'Wave', 'Wave', 'Reflection (physics)', 'Angle of incidence', 'Reflection (physics)', 'Light', 'Reflection (physics)', 'Ray (optics)', 'Ray (optics)', 'Angle of incidence', 'Reflection (physics)', 'Specular reflection', 'Light', 'Ray (optics)', 'Reflection (physics)', 'Reflection (physics)', 'Angle of incidence']
# ['Specular reflection', 'Ray (optics)', 'Reflection (physics)', 'Ray (optics)', 'Reflection (physics)', 'Specular reflection', 'Reflection (physics)', 'Light', 'Ray (optics)', 'Reflection (physics)', 'Light', 'Ray (optics)', 'Reflection (physics)', 'Specular reflection', 'Reflection (physics)', 'Specular reflection', 'Reflection (physics)', 'Ray (optics)', 'Reflection (physics)', 'Ray (optics)', 'Reflection (physics)', 'Ray (optics)', 'Specular reflection', 'Reflection (physics)', 'Reflection (physics)', 'Ray (optics)', 'Reflection (physics)', 'Ray (optics)', 'Reflection (physics)', 'Ray (optics)', 'Angle of incidence', 'Specular reflection', 'Reflection (physics)', 'Reflection (physics)', 'Light', 'Ray (optics)', 'Reflection (physics)', 'Reflection (physics)', 'Reflection (physics)', 'Light']
# ['Light', 'Reflection (physics)', 'Light', 'Wave', 'Speed', 'Light', 'Light', 'Speed', 'Light', 'Light', 'Ray (optics)', 'Refraction', 'Refraction', 'Light', 'Geometrical optics', 'Refraction', 'Refraction', 'Light', 'Light', 'Speed', 'Light', 'Geometrical optics', 'Refraction', 'Refraction', 'Reflection (physics)', 'Refraction', 'Refraction', 'Ray (optics)', 'Light', 'Geometrical optics', 'Geometrical optics', 'Light', 'Refraction', 'Light', 'Geometrical optics', 'Geometrical optics', 'Light', 'Refraction', 'Light', 'Refraction']
# ['Light', 'Speed', 'Light', 'Light', 'Refraction', 'Light', 'Refraction', 'Speed', 'Light', 'Speed', 'Refraction', 'Light', 'Refraction', 'Refraction', 'Speed', 'Light', 'Speed', 'Speed', 'Light', 'Speed', 'Light', 'Refraction', 'Refraction', 'Speed', 'Light', 'Speed', 'Light', 'Refraction', 'Speed', 'Light', 'Speed', 'Light', 'Refraction', 'Speed', 'Light', 'Speed', 'Light', 'Speed', 'Light', 'Refraction', 'Speed', 'Light', 'Light', 'Refraction', 'Light']
# ['Refraction', 'Refraction', 'Refraction', 'Angle of incidence', 'Refraction', 'Light', "Snell's law", 'Refraction', 'Light', 'Wavelength', "Snell's law", 'Refraction', 'Refraction', 'Angle of incidence', 'Refraction', 'Angle of incidence', 'Refraction', 'Refraction', 'Light', 'Ray (optics)', 'Angle of incidence', 'Refraction', 'Ray (optics)', 'Refraction', "Snell's law", 'Angle of incidence', 'Refraction', 'Light', 'Ray (optics)', "Snell's law", 'Angle of incidence', 'Refraction', 'Light', 'Ray (optics)', 'Refraction', 'Light', 'Ray (optics)', 'Ray (optics)', 'Refraction', 'Refraction', 'Ray (optics)', 'Ray (optics)', 'Refraction', 'Refraction', 'Ray (optics)', 'Ray (optics)', 'Angle of incidence', 'Light', 'Ray (optics)', 'Refraction', 'Ray (optics)', 'Refraction']
# ['Light', 'Ray (optics)', 'Refraction', 'Light', 'Ray (optics)', 'Ray (optics)', 'Refraction', "Snell's law", 'Light', 'Ray (optics)', 'Refraction']
# ['Reflection (physics)', 'Plane mirror', 'Plane mirror', 'Curved mirror', 'Curved mirror', 'Reflection (physics)']
# ['Light', 'Physics', 'Ray (optics)', 'Reflection (physics)', 'Ray (optics)', 'Light', 'Light', 'Reflection (physics)', 'Light', 'Light', 'Light', 'Light', 'Reflection (physics)', 'Work (physics)', 'Light', 'Ray (optics)', 'Light', 'Reflection (physics)', 'Real image', 'Light', 'Ray (optics)', 'Real image', 'Virtual image', 'Light', 'Ray (optics)', 'Light', 'Ray (optics)', 'Virtual image', 'Real image', 'Light', 'Ray (optics)', 'Virtual image', 'Distance', 'Distance', 'Distance', 'Distance']
# ['Distance', 'Virtual image', 'Light', 'Light', 'Light', 'Light', 'Virtual image', 'Virtual image', 'Light']
# ['Ray (optics)', 'Plane mirror', 'Ray (optics)', 'Ray (optics)', 'Ray (optics)', 'Specular reflection', 'Ray (optics)', 'Plane mirror', 'Ray (optics)', 'Plane mirror', 'Ray (optics)', 'Ray (optics)', 'Length', 'Ray (optics)', 'Plane mirror', 'Ray (optics)', 'Position (vector)', 'Plane mirror', 'Distance', 'Reflection (physics)', 'Ray (optics)', 'Ray (optics)', 'Light', 'Specular reflection', 'Light', 'Ray (optics)', 'Ray (optics)', 'Angle of incidence', 'Ray (optics)', 'Specular reflection', 'Ray (optics)', 'Reflection (physics)', 'Ray (optics)', 'Direction (geometry)', 'Ray (optics)', 'Light', 'Ray (optics)', 'Ray (optics)', 'Reflection (physics)', 'Angle of incidence', 'Ray (optics)', 'Ray (optics)', 'Virtual image', 'Light']
# ['Curved mirror', 'Curved mirror', 'Curved mirror', 'Curved mirror']
# ['Curved mirror', 'Curved mirror', 'Curved mirror', 'Plane mirror', 'Light', 'Reflection (physics)', 'Curved mirror', 'Plane mirror', 'Ray (optics)', 'Work (physics)', 'Distance', 'Distance', 'Length', 'Length', 'Position (vector)', 'Ray (optics)', 'Ray (optics)', 'Reflection (physics)', 'Position (vector)', 'Ray (optics)', 'Curved mirror', 'Ray (optics)', 'Ray (optics)', 'Reflection (physics)', 'Specular reflection', 'Reflection (physics)', 'Ray (optics)', 'Curved mirror', 'Plane mirror', 'Real image', 'Real image']
# ['Curved mirror', 'Curved mirror', 'Curved mirror', 'Plane mirror', 'Curved mirror', 'Curved mirror', 'Length', 'Curved mirror', 'Geometrical optics', 'Curved mirror', 'Specular reflection', 'Light', 'Curved mirror', 'Curved mirror', 'Ray (optics)', 'Ray (optics)', 'Reflection (physics)', 'Specular reflection', 'Reflection (physics)', 'Ray (optics)', 'Reflection (physics)', 'Ray (optics)', 'Curved mirror', 'Curved mirror', 'Curved mirror', 'Curved mirror', 'Light', 'Ray (optics)', 'Curved mirror']
# ['Geometrical optics', 'Magnification', 'Plane mirror', 'Magnification', 'Magnification', 'Magnification']
# []
# ['Angle of incidence', 'Refraction', 'Refraction', 'Ray (optics)', 'Angle of incidence', 'Angle of incidence', 'Reflection (physics)', 'Light', 'Angle of incidence', 'Refraction', 'Ray (optics)', 'Reflection (physics)', 'Reflection (physics)', 'Reflection (physics)', 'Light', 'Geometrical optics', 'Geometrical optics', 'Angle of incidence', 'Reflection (physics)', 'Reflection (physics)', 'Light', 'Reflection (physics)', 'Angle of incidence', "Snell's law", "Snell's law", 'Refraction', 'Refraction', 'Angle of incidence', 'Refraction', 'Reflection (physics)', 'Angle of incidence', 'Refraction', "Snell's law", 'Reflection (physics)', 'Ray (optics)']
# ['Reflection (physics)', 'Power (physics)', 'Light', 'Reflection (physics)', 'Geometrical optics', 'Geometrical optics', 'Plasticity (physics)', 'Light', 'Geometrical optics', 'Geometrical optics', 'Geometrical optics', 'Light', 'Geometrical optics', 'Reflection (physics)', 'Refraction', 'Reflection (physics)', 'Light', 'Angle of incidence', 'Light', 'Light', 'Length', 'Geometrical optics', 'Geometrical optics', 'Distance', 'Geometrical optics', 'Laser', 'Light', 'Angle of incidence', 'Laser', 'Speed', 'Light', 'Distance', 'Geometrical optics', 'Geometrical optics', 'Geometrical optics', 'Light', 'Geometrical optics']
# []
# ['Magnet', 'Force', 'Magnet', 'Magnet', 'Field (physics)', 'Physics', 'Force', 'Magnet', 'Force', 'Magnet', 'Field (physics)', 'Magnet', 'Magnet']
# ['Magnet', 'Field (physics)', 'Magnet', 'Force', 'Electron', 'Magnet', 'Field (physics)', 'Field (physics)', 'Direction (geometry)', 'Magnet', 'Field (physics)', 'Plasticity (physics)', 'Direction (geometry)', 'Magnet', 'Field (physics)', 'Electron', 'Direction (geometry)', 'Plasticity (physics)', 'Magnet', 'Magnet', 'Field (physics)', 'Magnet', 'Field (physics)', 'Magnet', 'Field (physics)', 'Electron', 'Electric field', 'Magnet', 'Magnet', 'Field (physics)', 'Magnet', 'Direction (geometry)', 'Magnet', 'Field (physics)', 'Magnet', 'Field (physics)', 'Magnet', 'Magnet', 'Magnet', 'Magnet', 'Field (physics)', 'Magnet', 'Field (physics)', 'Direction (geometry)']
# []
# ['Magnet', 'Direction (geometry)', 'Magnet', 'Magnet', 'Magnet', 'Magnet', 'Magnet', 'Field (physics)', 'Electric field', 'Position (vector)', 'Electric charge', 'Magnet', 'Magnet', 'Magnet', 'Field (physics)', 'Electric charge', 'Electric charge', 'Electron']
# ['Magnet', 'Magnet']
# ['Magnet', 'Field (physics)', 'Magnet', 'Field (physics)', 'Magnet', 'Field (physics)', 'Magnet', 'Magnet', 'Field (physics)', 'Field (physics)', 'Magnet', 'Field (physics)', 'Field (physics)', 'Field (physics)', 'Field (physics)', 'Strength of materials', 'Magnet', 'Field (physics)', 'Magnet', 'Field (physics)', 'Field (physics)', 'Direction (geometry)', 'Field (physics)', 'Magnet', 'Field (physics)', 'Magnet', 'Magnet', 'Field (physics)', 'Magnet', 'Magnet', 'Field (physics)', 'Direction (geometry)', 'Magnet', 'Field (physics)', 'Compass', 'Compass', 'Direction (geometry)', 'Field (physics)', 'Magnet', 'Magnet', 'Field (physics)', 'Magnet', 'Magnet', 'Field (physics)', 'Magnet', 'Magnet', 'Magnet', 'Field (physics)', 'Magnet', 'Field (physics)', 'Magnet', 'Magnet', 'Field (physics)', 'Magnet', 'Field (physics)', 'Magnet', 'Field (physics)', 'Magnet']
# ['Compass', 'Direction (geometry)', 'Magnet', 'Field (physics)', 'Compass', 'Direction (geometry)', 'Magnet', 'Field (physics)', 'Direction (geometry)', 'Field (physics)', 'Direction (geometry)', 'Compass', 'Compass', 'Direction (geometry)', 'Work (physics)', 'Magnet', 'Field (physics)', 'Magnet', 'Compass', 'Magnet', 'Field (physics)', 'Direction (geometry)', 'Direction (geometry)', 'Compass', 'Magnet', 'Field (physics)']
# ['Magnet', 'Field (physics)', 'Magnet', 'Field (physics)', 'Magnet', 'Magnet', 'Magnet', 'Field (physics)', 'Electric current', 'Magnet', 'Field (physics)', 'Direction (geometry)', 'Magnet', 'Direction (geometry)', 'Magnet', 'Compass', 'Magnet', 'Magnet', 'Magnet', 'Field (physics)', 'Compass', 'Magnet', 'Magnet', 'Direction (geometry)', 'Magnet', 'Field (physics)', 'Direction (geometry)', 'Magnet', 'Magnet', 'Field (physics)', 'Electric charge', 'Electric charge', 'Electric charge', 'Electron', 'Magnet', 'Field (physics)', 'Collision', 'Light']
# []
# ['Electrostatics', 'Electric charge']
# ['Electric charge', 'Electric charge', 'Position (vector)', 'Electric charge', 'Electric charge', 'Position (vector)', 'Electric charge', 'Electric charge', 'Position (vector)', 'Electric charge', 'Electric charge', 'Electric charge', 'Electric charge', 'Position (vector)', 'Electric charge', 'Electric charge', 'Position (vector)', 'Electric charge', 'Electric charge', 'Electric charge', 'Position (vector)', 'Electric charge', 'Electric charge', 'Electric charge', 'Position (vector)', 'Electric charge', 'Position (vector)', 'Electric charge', 'Electric charge', 'Electric charge', 'Electric charge']
# ['Electric charge', 'Coulomb', 'Coulomb', 'Electric charge', 'Electric charge', 'Electrostatics', 'Work (physics)', 'Electric charge', 'Coulomb', 'Coulomb']
# ['Electric charge', 'Position (vector)', 'Electric charge', 'Electric charge', 'Electric charge', 'Electric charge', 'Energy', 'Electric charge', 'Electric charge', 'Position (vector)', 'Electric charge', 'Plasticity (physics)', 'Position (vector)', 'Electric charge', 'Electric charge', 'Position (vector)', 'Electric charge', 'Electric charge', 'Electric charge', 'Position (vector)', 'Electric charge', 'Electric charge', 'Electric charge', 'Electric charge', 'Electric charge', 'Position (vector)', 'Electric charge', 'Position (vector)', 'Electric charge', 'Electric charge', 'Electric charge', 'Position (vector)', 'Electric charge', 'Electric charge', 'Electric charge', 'Position (vector)', 'Electric charge', 'Electric charge', 'Electric charge', 'Position (vector)', 'Electric charge']
# ['Force', 'Electric charge', 'Electrostatics', 'Force', 'Electrostatics', 'Force', 'Electric charge', 'Electric charge', 'Electric charge', 'Electric charge', 'Force', 'Force', 'Force', 'Force', 'Electric charge', 'Electrostatics', 'Force', 'Force', 'Force', 'Distance', 'Electric charge', 'Distance', 'Electric charge', 'Electrostatics', 'Force', 'Electrostatics', 'Force', 'Electric charge', 'Electric charge', 'Electrical conductor', 'Force', 'Electric charge', 'Electrical conductor', 'Electric charge', 'Electric charge', 'Electric charge', 'Electrical conductor', 'Electric charge', 'Electric charge', 'Electric charge', 'Insulator (electricity)', 'Electric charge', 'Insulator (electricity)', 'Electron']
# ['Electric charge', 'Position (vector)', 'Electric charge', 'Electron', 'Electric charge', 'Position (vector)', 'Electric charge', 'Electric charge', 'Electric charge', 'Electric charge', 'Electron', 'Electron', 'Electrical conductor', 'Electric charge', 'Electron', 'Plasticity (physics)', 'Electron', 'Insulator (electricity)', 'Electric charge', 'Insulator (electricity)', 'Electric charge', 'Electric charge', 'Electrical conductor', 'Electric charge', 'Electrical conductor', 'Electric charge', 'Electrical conductor', 'Electrical conductor', 'Electric charge', 'Electric charge', 'Electron', 'Electric charge', 'Electric charge', 'Electron', 'Electron', 'Electric charge', 'Electron', 'Insulator (electricity)', 'Electron', 'Electric charge']
# ['Electroscope', 'Electric charge', 'Electroscope', 'Electroscope', 'Electroscope', 'Electric charge', 'Electric charge', 'Position (vector)', 'Electric charge', 'Electroscope', 'Electric charge', 'Position (vector)', 'Electrical conductor', 'Electric charge', 'Electric charge', 'Position (vector)', 'Electric charge', 'Electric charge', 'Electroscope', 'Position (vector)', 'Electric charge', 'Electric charge', 'Position (vector)', 'Electric charge', 'Force', 'Electric charge', 'Electric charge', 'Electric charge', 'Electroscope', 'Electric charge', 'Electric charge', 'Electroscope', 'Electric charge', 'Electric charge', 'Electric charge', 'Electric charge', 'Electric charge', 'Electroscope', 'Electric charge', 'Electric charge']
# []
# ['Electrical conductor', 'Electron', 'Insulator (electricity)', 'Insulator (electricity)', 'Electric charge', 'Force', 'Insulator (electricity)', 'Position (vector)', 'Electric charge', 'Insulator (electricity)', 'Electron', 'Position (vector)', 'Optical microscope', 'Light', 'Force', 'Electric charge', 'Electric charge', 'Electric charge', 'Position (vector)', 'Electric charge', 'Electric charge', 'Position (vector)', 'Electric charge', 'Electric charge']
# []
# ['Power (physics)', 'Work (physics)', 'Light', 'Work (physics)', 'Power (physics)', 'Physics']
# ['Light', 'Electric charge', 'Energy', 'Electric charge', 'Electric charge', 'Electron', 'Power (physics)', 'Energy']
# ['Light', 'Voltmeter', 'Ammeter', 'Physics', 'Physics', 'Physics', 'Work (physics)', 'Physics', 'Light', 'Plasticity (physics)', 'Physics', 'Light', 'Plasticity (physics)', 'Work (physics)', 'Physics', 'Series and parallel circuits', 'Series and parallel circuits', 'Series and parallel circuits', 'Electric charge', 'Series and parallel circuits', 'Series and parallel circuits', 'Electric charge']
# []
# ['Electric charge', 'Electric charge', 'Force', 'Electric charge', 'Work (physics)', 'Electric charge', 'Force', 'Electric charge', 'Work (physics)', 'Force', 'Electric charge', 'Electric current', 'Position (vector)', 'Electric charge', 'Potential energy', 'Force', 'Force', 'Gravity', 'Position (vector)', 'Potential energy', 'Work (physics)', 'Electric charge', 'Potential energy', 'Potential energy', 'Voltage', 'Potential energy', 'Voltage', 'Voltage', 'Voltage', 'Electric potential', 'Electric potential energy', 'Electric charge', 'Voltage', 'Joule', 'Coulomb', 'Work (physics)', 'Electric charge', 'Electric potential', 'Voltage']
# ['Potential energy', 'Voltage', 'Voltage', 'Voltage', 'Voltage', 'Voltage', 'Voltage', 'Voltage', 'Potential energy', 'Voltage']
# ['Voltage', 'Voltage', 'Voltage', 'Distance', 'Gravity', 'Distance', 'Distance', 'Voltage', 'Voltage', 'Work (physics)', 'Electric charge', 'Potential energy', 'Voltage', 'Voltage']
# ['Voltage', 'Potential energy', 'Work (physics)', 'Electric charge', 'Electrical ', 'Electrical resistance and conductance', 'Electric charge', 'Work (physics)', 'Work (physics)', 'Voltage', 'Electrical ', 'Electrical resistance and conductance', 'Voltage', 'Electrical ', 'Electrical resistance and conductance', 'Ohm', 'Voltage', 'Electrical ', 'Electrical resistance and conductance', 'Voltage', 'Electrical ', 'Electrical resistance and conductance', 'Voltage', 'Voltage', 'Potential energy', 'Electrical ', 'Electrical resistance and conductance', 'Voltage', 'Electrical ', 'Electrical resistance and conductance', 'Voltage', 'Electrical ', 'Electrical resistance and conductance', 'Voltage', 'Electrical ', 'Electrical resistance and conductance', 'Voltage', 'Electrical ', 'Electrical resistance and conductance']
# ['Voltage', 'Force', 'Electromotive force', 'Potential energy', 'Electric charge', 'Potential energy', 'Potential energy', 'Voltage', 'Voltage', 'Voltage', 'Electromotive force', 'Electromotive force']
# []
# ['Electric charge', 'Electric charge', 'Electric current', 'Electric current', 'Electric charge', 'Electric current', 'Electric charge', 'Electric charge', 'Electric charge', 'Electric charge', 'Electric charge', 'Electric charge', 'Electric charge']
# ['Electric charge', 'Electric charge', 'Electric current', 'Electric current', 'Electric current', 'Electric charge', 'Electric current', 'Coulomb', 'Electric charge', 'Electric current', 'Direction (geometry)', 'Electric charge', 'Position (vector)']
# ['Series and parallel circuits', 'Electric charge', 'Direction (geometry)', 'Electric charge', 'Electric charge', 'Direction (geometry)', 'Direction (geometry)', 'Electric charge', 'Electric charge', 'Position (vector)', 'Direction (geometry)', 'Electron', 'Electric charge', 'Electric charge', 'Electron', 'Direction (geometry)', 'Electron', 'Position (vector)', 'Electric current', 'Voltage', 'Electric current', 'Electric current', 'Electric current']
# ['Electric current', 'Electric current', 'Electric charge', 'Electric charge', 'Electric charge', 'Electrical ', 'Electrical resistance and conductance', 'Electric charge']
# []
# ['Electric charge', 'Electrical conductor', 'Optical microscope', 'Electron', 'Electrical conductor', 'Collision', 'Electrical conductor', 'Collision', 'Energy', 'Electron', 'Energy', 'Electrical ', 'Electrical resistance and conductance', 'Energy', 'Electrical conductor', 'Electric charge', 'Electrical ', 'Electrical resistance and conductance', 'Electrical ', 'Electrical resistance and conductance', 'Electric charge', 'Electrical ', 'Electrical resistance and conductance', 'Ohm', 'Ohm', 'Electrical conductor', 'Electrical ', 'Electrical resistance and conductance', 'Electrical ', 'Electrical resistance and conductance', 'Light', 'Electrical ', 'Electrical resistance and conductance', 'Electrical ', 'Electrical resistance and conductance', 'Electron', 'Energy', 'Energy', 'Light', 'Electric current', 'Electrical ', 'Electrical resistance and conductance', 'Energy', 'Energy', 'Light', 'Electrical conductor', 'Electrical ', 'Electrical resistance and conductance', 'Temperature', 'Potential energy', 'Potential energy', 'Energy', 'Power (physics)', 'Electron', 'Electrical ', 'Electrical resistance and conductance', 'Electric charge', 'Energy', 'Light', 'Potential energy', 'Energy']
# ['Electrical ', 'Electrical resistance and conductance', 'Electric current', 'Electrical ', 'Electrical resistance and conductance', 'Electric current', 'Electric current', 'Electric current', 'Series and parallel circuits', 'Electric current', 'Series and parallel circuits', 'Electrical ', 'Electrical resistance and conductance', 'Ammeter', 'Electric current', 'Electric current', 'Electrical ', 'Electrical resistance and conductance', 'Ammeter', 'Electric current', 'Electric charge', 'Electrical ', 'Electrical resistance and conductance', 'Electric current', 'Electric current']
# ['Light', 'Metre', 'Electric current', 'Ammeter', 'Voltage', 'Voltmeter', 'Voltmeter', 'Ammeter', 'Ohmmeter']
# ['Voltmeter', 'Voltage', 'Voltmeter', 'Metre', 'Voltage', 'Voltmeter', 'Voltmeter', 'Voltmeter', 'Voltmeter', 'Voltmeter', 'Voltage', 'Voltage']
# ['Ammeter', 'Electric current', 'Electric current', 'Ammeter']
# ['Ohmmeter', 'Electrical ', 'Electrical resistance and conductance', 'Ohmmeter', 'Ammeter', 'Ohmmeter', 'Work (physics)', 'Voltage', 'Electric current', 'Electric current', 'Electrical ', 'Electrical resistance and conductance', 'Ohm', 'Ohmmeter', 'Electrical ', 'Electrical resistance and conductance', 'Power (physics)', 'Voltage', 'Electric current', 'Electrical ', 'Electrical resistance and conductance', 'Ohmmeter', 'Voltage', 'Voltage', 'Ohmmeter', 'Ohmmeter']
# ['Metre', 'Ammeter', 'Electrical ', 'Electrical resistance and conductance', 'Electric charge', 'Voltmeter', 'Electrical ', 'Electrical resistance and conductance', 'Electric charge']
# []
# ['Euclidean vector', 'Euclidean vector', 'Physics', 'Euclidean vector', 'Physics', 'Euclidean vector', 'Physics', 'Physics', 'Physics', 'Euclidean vector', 'Physics', 'Euclidean vector']
# ['Scalar (mathematics)', 'Scalar (mathematics)', 'Scalar (mathematics)', 'Scalar (mathematics)', 'Euclidean vector', 'Scalar (mathematics)', 'Direction (geometry)', 'Euclidean vector', 'Scalar (mathematics)', 'Direction (geometry)', 'Physics', 'Scalar (mathematics)', 'Euclidean vector', 'Euclidean vector', 'Euclidean vector', 'Direction (geometry)', 'Euclidean vector', 'Euclidean vector', 'Velocity', 'Direction (geometry)', 'Speed', 'Direction (geometry)', 'Direction (geometry)', 'Euclidean vector', 'Velocity']
# ['Euclidean vector', 'Scalar (mathematics)']
# ['Euclidean vector', 'Euclidean vector', 'Euclidean vector', 'Velocity', 'Force', 'Direction (geometry)', 'Euclidean vector', 'Euclidean vector', 'Euclidean vector']
# ['Euclidean vector', 'Direction (geometry)', 'Direction (geometry)', 'Euclidean vector']
# ['Euclidean vector', 'Euclidean vector', 'Direction (geometry)', 'Direction (geometry)', 'Euclidean vector']
# ['Direction (geometry)', 'Direction (geometry)']
# ['Compass', 'Euclidean vector', 'Compass', 'Direction (geometry)', 'Euclidean vector', 'Euclidean vector', 'Direction (geometry)', 'Euclidean vector', 'Euclidean vector', 'Direction (geometry)', 'Euclidean vector']
# ['Direction (geometry)', 'Direction (geometry)', 'Euclidean vector', 'Direction (geometry)']
# ['Euclidean vector', 'Direction (geometry)', 'Length', 'Euclidean vector', 'Force', 'Direction (geometry)', 'Compass', 'Euclidean vector', 'Length', 'Euclidean vector', 'Euclidean vector', 'Euclidean vector']
# ['Euclidean vector', 'Euclidean vector', 'Displacement (vector)', 'Euclidean vector', 'Displacement (vector)', 'Displacement (vector)', 'Distance', 'Direction (geometry)', 'Displacement (vector)', 'Euclidean vector', 'Force', 'Velocity', 'Euclidean vector']
# ['Euclidean vector', 'Direction (geometry)', 'Direction (geometry)', 'Direction (geometry)', 'Displacement (vector)', 'Euclidean vector', 'Displacement (vector)', 'Euclidean vector', 'Direction (geometry)', 'Displacement (vector)', 'Euclidean vector', 'Direction (geometry)', 'Euclidean vector', 'Euclidean vector', 'Euclidean vector', 'Euclidean vector', 'Euclidean vector', 'Euclidean vector', 'Euclidean vector', 'Euclidean vector', 'Euclidean vector', 'Euclidean vector', 'Displacement (vector)', 'Euclidean vector', 'Euclidean vector', 'Euclidean vector', 'Euclidean vector', 'Euclidean vector', 'Euclidean vector', 'Euclidean vector', 'Displacement (vector)', 'Direction (geometry)', 'Displacement (vector)', 'Euclidean vector', 'Length', 'Euclidean vector', 'Direction (geometry)', 'Direction (geometry)', 'Displacement (vector)', 'Euclidean vector', 'Euclidean vector', 'Direction (geometry)', 'Euclidean vector', 'Displacement (vector)', 'Direction (geometry)', 'Euclidean vector', 'Displacement (vector)', 'Euclidean vector', 'Force', 'Force', 'Euclidean vector']
# ['Euclidean vector', 'Work (physics)', 'Displacement (vector)', 'Length', 'Euclidean vector', 'Euclidean vector', 'Euclidean vector', 'Direction (geometry)', 'Euclidean vector', 'Euclidean vector', 'Direction (geometry)', 'Position (vector)', 'Direction (geometry)', 'Position (vector)', 'Euclidean vector', 'Direction (geometry)', 'Position (vector)', 'Euclidean vector', 'Euclidean vector', 'Direction (geometry)']
# ['Euclidean vector', 'Scalar (mathematics)', 'Euclidean vector', 'Work (physics)']
# ['Euclidean vector', 'Euclidean vector', 'Euclidean vector']
# ['Euclidean vector', 'Euclidean vector', 'Displacement (vector)', 'Euclidean vector', 'Euclidean vector', 'Euclidean vector', 'Direction (geometry)', 'Euclidean vector', 'Direction (geometry)', 'Length', 'Direction (geometry)', 'Euclidean vector', 'Euclidean vector', 'Direction (geometry)', 'Length', 'Euclidean vector', 'Euclidean vector', 'Euclidean vector', 'Euclidean vector', 'Euclidean vector', 'Length', 'Direction (geometry)', 'Euclidean vector', 'Direction (geometry)', 'Euclidean vector', 'Length', 'Direction (geometry)', 'Euclidean vector', 'Length', 'Direction (geometry)', 'Euclidean vector', 'Euclidean vector', 'Length', 'Direction (geometry)', 'Euclidean vector', 'Force']
# ['Euclidean vector', 'Euclidean vector', 'Direction (geometry)', 'Euclidean vector', 'Position (vector)', 'Direction (geometry)', 'Displacement (vector)', 'Direction (geometry)', 'Position (vector)', 'Direction (geometry)', 'Displacement (vector)', 'Euclidean vector', 'Direction (geometry)', 'Position (vector)', 'Position (vector)', 'Direction (geometry)', 'Direction (geometry)', 'Displacement (vector)', 'Direction (geometry)', 'Motion', 'Euclidean vector']
# ['Euclidean vector', 'Euclidean vector', 'Euclidean vector', 'Euclidean vector', 'Euclidean vector', 'Euclidean vector', 'Euclidean vector', 'Euclidean vector', 'Euclidean vector', 'Euclidean vector', 'Euclidean vector', 'Euclidean vector', 'Euclidean vector', 'Euclidean vector', 'Euclidean vector', 'Euclidean vector', 'Euclidean vector', 'Euclidean vector']
# ['Euclidean vector', 'Euclidean vector', 'Euclidean vector', 'Euclidean vector', 'Euclidean vector', 'Euclidean vector', 'Euclidean vector', 'Euclidean vector']
# []
# ['Motion', 'Motion', 'Force', 'Motion', 'Force', 'Force', 'Motion', 'Force', 'Force', 'Gravity']
# []
# ['Force', 'Force', 'Direction (geometry)', 'Force', 'Force', 'Force', 'Force', 'Force', 'Force', 'Force', 'Force', 'Force', 'Force', 'Force', 'Gravity', 'Force', 'Electron', 'Force', 'Magnet', 'Magnet', 'Force', 'Force', 'Force', 'Euclidean vector', 'Direction (geometry)', 'Force', "Newton's law of universal gravitation", 'Force', 'Force', 'Force', 'Euclidean vector', 'Force', 'Force', 'Force', 'Force', 'Force']
# ['Physics', 'Force', 'Force', 'Force', 'Physics', 'Force', 'Force', 'Force', 'Force', 'Force', 'Force', 'Gravity', 'Force', 'Mass', 'Mass', 'Mass', 'Force', 'Force', 'Force', 'Force', 'Magnet', 'Force', 'Work (physics)', 'Electrostatics', 'Force', 'Electric charge', 'Electrostatics', 'Force', 'Coulomb', 'Force', 'Gravity', 'Gravity', 'Power (physics)', 'Electrostatics', 'Force', 'Gravity', 'Mass', 'Force', 'Force', 'Electric charge', 'Magnet', 'Force', 'Magnet', 'Force', 'Force', 'Electric charge', 'Electric charge', 'Coulomb', 'Magnet', 'Force', 'Magnet', 'Magnet', 'Friction', 'Force', 'Friction', 'Friction', 'Friction', 'Force', 'Friction', 'Force', 'Force', 'Force', 'Displacement (vector)', 'Force', 'Force', 'Force', 'Force', 'Force', 'Force']
# ['Force', 'Physics', 'Force', 'Force', 'Force', 'Force', 'Force', 'Friction', 'Direction (geometry)', 'Motion', 'Force', 'Gravity', 'Force', 'Force', 'Force', 'Force', 'Force', 'Force', 'Force', 'Friction', 'Direction (geometry)', 'Motion', 'Force', 'Force', 'Force', 'Force', 'Force', 'Gravity', 'Force']
# ['Force', 'Force', 'Force', 'Direction (geometry)', 'Direction (geometry)', 'Force', 'Length', 'Force', 'Force', 'Length', 'Force', 'Force', 'Force', 'Force', 'Direction (geometry)', 'Force']
# ['Force', 'Free body diagram']
# ['Force', 'Free body diagram', 'Length', 'Euclidean vector', 'Direction (geometry)', 'Direction (geometry)', 'Euclidean vector', 'Euclidean vector', 'Force', 'Force', 'Force', 'Free body diagram', 'Force', 'Free body diagram', 'Force', 'Direction (geometry)', 'Length', 'Force', 'Force', 'Motion', 'Direction (geometry)', 'Frame of reference', 'Euclidean vector', 'Direction (geometry)', 'Position (vector)', 'Direction (geometry)', 'Force', 'Direction (geometry)', 'Position (vector)', 'Position (vector)', 'Direction (geometry)', 'Work (physics)', 'Force', 'Force', 'Force', 'Force', 'Euclidean vector', 'Force', 'Euclidean vector']
# ['Motion', 'Force', 'Force']
# ['Force', 'Force', 'Speed', 'Direction (geometry)', 'Motion', 'Motion', 'Velocity', 'Force', 'Field (physics)', "Newton's laws of motion", 'Force', 'Friction', 'Friction', 'Distance', 'Electrical ', 'Electrical resistance and conductance', 'Friction', 'Friction', 'Force', 'Velocity', 'Direction (geometry)', 'Force', 'Direction (geometry)', 'Force']
# ['Kilogram', 'Force', 'Friction', 'Force', 'Force', 'Friction', 'Force', 'Hardness', 'Friction', 'Force', 'Friction', 'Force', 'Friction', 'Force', 'Mass', 'Kilogram', 'Motion', 'Mass', 'Force', 'Mass', 'Mass', 'Force', 'Force', 'Force', 'Motion', 'Force', 'Direction (geometry)', 'Force', 'Force', 'Mass', 'Force', 'Gravity', 'Gravity', 'Force', 'Force', 'Gravity', 'Friction', 'Force', 'Friction', 'Force', 'Force', 'Gravity', 'Force', 'Force', 'Gravity', 'Direction (geometry)', 'Force', 'Force', 'Force', 'Force', 'Direction (geometry)', 'Direction (geometry)', 'Work (physics)', 'Force', 'Gravity', 'Motion', 'Force', 'Motion', 'Force', 'Kilogram', 'Motion', 'Kilogram', 'Force', 'Force', 'Force', 'Force', 'Force', 'Gravity', 'Force', 'Force', 'Direction (geometry)', 'Motion', 'Force', 'Force', 'Gravity', 'Force', 'Direction (geometry)', 'Position (vector)', 'Position (vector)', 'Force', 'Gravity', 'Velocity', 'Velocity', 'Force', 'Force', 'Force', 'Force', 'Force', 'Force', 'Force', 'Force', 'Position (vector)', 'Force', 'Force', 'Force', 'Gravity', 'Force', 'Force', 'Force', 'Gravity', 'Free fall', 'Motion', 'Force', 'Gravity', 'Force', 'Force', 'Gravity', 'Work (physics)']
# ['Motion', 'Force', 'Force', 'Sound', 'Force', 'Force', 'Force', 'Force', 'Direction (geometry)', 'Force', 'Force', 'Force', 'Force', 'Force', 'Motion', 'Force', 'Force', 'Direction (geometry)', 'Work (physics)']
# ['Tension (physics)', 'Tension (physics)', 'Force', 'Tension (physics)', 'Force', 'Force', 'Force', 'Tension (physics)', 'Friction', 'Force', 'Force', 'Physics', 'Force', 'Force', 'Force', 'Distance', 'Magnet', 'Force', 'Electrostatics', 'Force', 'Force', 'Force', 'Force', 'Force', 'Force', 'Force', 'Kilogram', 'Force', 'Force', 'Force', 'Direction (geometry)', 'Force', 'Force', 'Gravity', 'Force', 'Force', 'Force', 'Direction (geometry)', 'Force', 'Direction (geometry)', 'Direction (geometry)', 'Force', 'Gravity', 'Force', 'Force', 'Force', 'Force', 'Velocity', 'Velocity', 'Friction', 'Force', 'Friction', 'Force', 'Friction', 'Force', 'Friction', 'Force', 'Friction', 'Force', 'Force', 'Force', 'Friction', 'Force', 'Motion', 'Force', 'Direction (geometry)', 'Friction', 'Force', 'Friction', 'Force', 'Friction', 'Force', 'Force', 'Friction', 'Force', 'Force', 'Force', 'Friction', 'Force', 'Friction', 'Force', 'Friction', 'Friction', 'Force', 'Force', 'Friction', 'Friction', 'Force', 'Friction', 'Friction', 'Force', 'Friction', 'Friction', 'Velocity', 'Friction', 'Friction', 'Friction', 'Force', 'Direction (geometry)', 'Position (vector)', 'Friction', 'Friction', 'Friction', 'Friction', 'Friction']
# ['Force', 'Velocity', 'Force', 'Force', 'Velocity', 'Force', 'Force', 'Force', 'Force', 'Force', 'Force', 'Force', 'Force', 'Force', 'Force', 'Force', 'Direction (geometry)', 'Force', 'Force', 'Force', 'Direction (geometry)', 'Force', 'Euclidean vector', 'Direction (geometry)', 'Free body diagram', 'Free body diagram', 'Force', 'Direction (geometry)', 'Force', 'Force', 'Direction (geometry)', 'Tension (physics)', 'Force', 'Mass', 'Force', 'Force', 'Force', 'Euclidean vector']
# ...
# []
# ['Capacitor', 'Electric current', 'Frequency', 'Capacitor', 'Frequency', 'Frequency', 'Capacitance', 'Capacitor', 'Frequency', 'Frequency', 'Frequency', 'Capacitance', 'Capacitor', 'Frequency', 'Frequency', 'Capacitor', 'Frequency', 'Frequency', 'Sound', 'Frequency', 'Frequency', 'Sound', 'Frequency', 'Frequency', 'Frequency', 'Frequency', 'Frequency', 'Frequency', 'Frequency', 'Frequency', 'Frequency', 'Sound', 'Frequency', 'Frequency', 'Sound', 'Frequency', 'Capacitor', 'Frequency']
# ['Capacitor', 'Electric current', 'Electric current', 'Voltage', 'Electric current', 'Voltage', 'Electric current', 'Electric current', 'Voltage', 'Voltage', 'Capacitor', 'Electric current', 'Electric current', 'Voltage', 'Capacitor', 'Voltage', 'Frequency', 'Frequency', 'Capacitor', 'Voltage', 'Voltage', 'Electric current', 'Voltage', 'Capacitor', 'Voltage', 'Electric current', 'Electric current', 'Capacitor', 'Frequency', 'Position (vector)', 'Capacitance', 'Frequency', 'Resonance (particle physics)', 'Frequency', 'Frequency', 'Electric current', 'Voltage', 'Frequency', 'Frequency', 'Resonance (particle physics)', 'Resonance (particle physics)', 'Voltage', 'Electric current', 'Power (physics)', 'Frequency', 'Resonance (particle physics)', 'Frequency', 'Frequency', 'Electric current', 'Frequency', 'Frequency', 'Resonance (particle physics)', 'Frequency', 'Frequency', 'Capacitance', 'Capacitor', 'Resonance (particle physics)', 'Frequency']
# ['Capacitor', 'Physics', 'Voltage', 'Electric current']
# ['Electron', 'Electric current', 'Direction (geometry)', 'Electrical ', 'Electrical resistance and conductance', 'Electric current', 'Electric current', 'Position (vector)', 'Electron', 'Position (vector)', 'Electron', 'Electron', 'Electron', 'Electron', 'Electron', 'Electron', 'Electron', 'Electron', 'Position (vector)', 'Electric charge', 'Electric charge', 'Electron', 'Electron', 'Electric charge', 'Electric charge', 'Electron', 'Electron', 'Electrical ', 'Electrical resistance and conductance', 'Electrical ', 'Electrical resistance and conductance', 'Electron', 'Electric charge', 'Electron', 'Electron', 'Electric current', 'Electron', 'Electric current', 'Electric charge', 'Electron', 'Electron', 'Electrical ', 'Electrical resistance and conductance', 'Electrical ', 'Electrical resistance and conductance', 'Electron', 'Electric charge', 'Voltage', 'Voltage']
# ['Light', 'Electric charge', 'Direction (geometry)', 'Voltage', 'Force', 'Electric current', 'Direction (geometry)', 'Light', 'Light', 'Voltage', 'Light', 'Color', 'Electromagnetic spectrum', 'Light', 'Emission spectrum', 'Wavelength', 'Light', 'Color', 'Light', 'Light', 'Frequency', 'Light', 'Color', 'Light', 'Light', 'Field (physics)', 'Field (physics)', 'Light', 'Geometrical optics', 'Color', 'Work (physics)', 'Light', 'Light', 'Length', 'Light', 'Light', 'Power (physics)', 'Light', 'Color', 'Light', 'Light', 'Color', 'Light', 'Light', 'Color', 'Color', 'Color', 'Light', 'Light', 'Light', 'Light', 'Light']
# ['Direction (geometry)', 'Electric current', 'Electron', 'Electric current', 'Electric current', 'Electric current', 'Power (physics)', 'Electric current', 'Work (physics)', 'Field (physics)', 'Field (physics)', 'Electric current', 'Electron', 'Electric current', 'Electron', 'Electron', 'Electron', 'Electric current', 'Electron', 'Electric current', 'Electron', 'Electric current', 'Electron', 'Electric current', 'Electron', 'Electric current', 'Work (physics)', 'Electron', 'Electron', 'Electron', 'Insulator (electricity)', 'Electric current', 'Position (vector)', 'Voltage', 'Electron', 'Electron', 'Electron', 'Electron', 'Electron', 'Electron', 'Electric current', 'Direction (geometry)', 'Electron', 'Electric current', 'Electric current', 'Work (physics)', 'Electric current', 'Electric current', 'Electric charge', 'Electron', 'Electric current', 'Force', 'Physics', 'Field (physics)', 'Electric current', 'Field (physics)', 'Work (physics)', 'Voltage', 'Electric current', 'Electric current', 'Electric current', 'Field (physics)', 'Electric current', 'Electron', 'Electron', 'Position (vector)', 'Electron', 'Electron', 'Voltage', 'Electric current', 'Voltage', 'Voltage', 'Electron', 'Voltage', 'Electric current', 'Electron', 'Electrical ', 'Electrical resistance and conductance', 'Electron', 'Electrical ', 'Electrical resistance and conductance', 'Electron', 'Electron', 'Voltage', 'Electric current', 'Position (vector)', 'Voltage', 'Voltage', 'Voltage', 'Voltage', 'Field (physics)', 'Voltage', 'Electric current']
# ['Voltage', 'Field (physics)', 'Voltage', 'Voltage', 'Voltage', 'Power (physics)', 'Power (physics)', 'Electron', 'Power (physics)', 'Voltage', 'Voltage', 'Voltage', 'Voltage', 'Voltage', 'Position (vector)', 'Position (vector)', 'Voltage', 'Voltage', 'Electrical ', 'Electrical resistance and conductance', 'Electric current', 'Voltage', 'Voltage', 'Work (physics)']
# ['Electron', 'Electron', 'Electron', 'Geometrical optics', 'Wave', 'Voltage', 'Voltage', 'Voltage', 'Voltage', 'Voltage', 'Voltage', 'Voltage', 'Motion', 'Optical microscope']
# ['Electron', 'Temperature', 'Temperature', 'Work (physics)', 'Light', 'Light', 'Light', 'Light', 'Voltage', 'Voltage', 'Light', 'Light', 'Light', 'Light', 'Light', 'Work (physics)']
# []
# ['Power (physics)', 'Power (physics)', 'Power (physics)', 'Work (physics)', 'Power (physics)', 'Power (physics)', 'Power (physics)', 'Power (physics)', 'Power (physics)', 'Voltage', 'Electron', 'Electron', 'Work (physics)']
# ['Wave', 'Electric charge', 'Electric charge', 'Electric charge', 'Electric charge']
# ['Electric charge', 'Power (physics)', 'Work (physics)', 'Power (physics)']
# []
# ['Electromagnetic radiation', 'Electromagnetic radiation', 'Wave', 'Magnet', 'Direction (geometry)', 'Electromagnetic radiation', 'Frequency', 'Wave', 'Frequency', 'Wave', 'Light', 'Ray (optics)']
# ['Light', 'Electromagnetic radiation', 'Wave', 'Light', 'Light', 'Wave', 'Light', 'Energy', 'Light', 'Light', 'Wave', 'Wave', 'Light', 'Energy level', 'Light', 'Light', 'Light', 'Photoelectric effect']
# ['Electric charge', 'Wave', 'Electric field', 'Magnet', 'Field (physics)', 'Magnet', 'Field (physics)', 'Electric field', 'Wave', 'Wave', 'Sound', 'Wave', 'Wave', 'Electric field', 'Magnet', 'Field (physics)', 'Electric field', 'Wave', 'Field (physics)', 'Speed']
# ['Field (physics)', 'Light', 'Light', 'Light', 'Physics', 'Light', 'Electromagnetic radiation', 'Light', 'Electromagnetic radiation', 'Reflection (physics)', 'Physics', 'Electromagnetic spectrum', 'Light', 'Color', 'Electromagnetic spectrum', 'Wavelength', 'Electromagnetic radiation', 'Wavelength', 'Wavelength', 'Wavelength', 'Wavelength', 'Wavelength', 'Wavelength', 'Wavelength', 'Wave', 'Wave', 'Wavelength', 'Ray (optics)', 'Wave', 'Wavelength', 'Light', 'Wavelength']
# ['Electromagnetic radiation', 'Energy', 'Energy', 'Wavelength', 'Electromagnetic radiation', 'Physics', 'Energy', 'Energy', 'Joule', 'Speed', 'Light', 'Frequency', 'Hertz', 'Hertz', 'Wavelength', 'Metre']
# ['Electromagnetic radiation', 'Light', 'Light', 'Reflection (physics)', 'Light', 'Energy', 'Light', 'Energy', 'Energy', 'Electromagnetic radiation', 'Energy', 'Energy', 'Electromagnetic radiation', 'Ray (optics)', 'Energy']
# ['Frequency', 'Light', 'Speed', 'Light', 'Pigment', 'Ray (optics)', 'Ray (optics)', 'Ray (optics)']
# ['Light', 'Work (physics)', 'Wave', 'Light', 'Reflection (physics)', 'Plasticity (physics)', 'Plasticity (physics)', 'Light', 'Light', 'Light', 'Light']
# []
# ['Energy', 'Interference (wave propagation)', 'Electromagnetic radiation', 'Wave']
# []
# ['Light', 'Wave', 'Light', 'Wave', 'Geometrical optics', 'Light', 'Electromagnetic radiation', 'Wave', 'Wave', 'Light', 'Light', 'Diffraction', 'Light', 'Electromagnetic radiation', 'Light', 'Light', 'Light', 'Wave']
# []
# ['Electron', 'Energy level', 'Electron', 'Energy', 'Energy level', 'Electron', 'Electron', 'Energy level', 'Energy', 'Energy level', 'Energy', 'Light', 'Wavelength', 'Light', 'Light', 'Wavelength', 'Energy', 'Electron', 'Energy', 'Energy', 'Electron', 'Energy', 'Energy']
# ['Light', 'Light', 'Strength of materials', 'Light', 'Scattering', 'Direction (geometry)', 'Wavelength', 'Light', 'Energy', 'Energy', 'Energy', 'Electron', 'Electron', 'Energy level', 'Electron', 'Energy level', 'Light', 'Reflection (physics)', 'Geometrical optics', 'Ray (optics)', 'Light', 'Reflection (physics)', 'Refraction', 'Light', 'Ray (optics)', 'Optical microscope', 'Reflection (physics)', 'Refraction', 'Ray (optics)', 'Light', 'Scattering', 'Light', 'Energy level', 'Energy', 'Light', 'Reflection (physics)', 'Light', 'Wavelength', 'Reflection (physics)', 'Wavelength', 'Wavelength', 'Light', 'Wavelength', 'Color', 'Color', 'Light', 'Color', 'Reflection (physics)', 'Light', 'Wavelength', 'Reflection (physics)', 'Wavelength', 'Light', 'Reflection (physics)', 'Light', 'Direction (geometry)', 'Specular reflection', 'Geometrical optics', 'Reflection (physics)', 'Light', 'Direction (geometry)', 'Electron', 'Electron', 'Electron', 'Reflection (physics)', 'Energy', 'Light', 'Wavelength', 'Light', 'Plasticity (physics)', 'Energy level', 'Wavelength', 'Energy', 'Energy level', 'Wavelength', 'Light', 'Energy', 'Energy level']
# ['Light', 'Wavelength', 'Wavelength', 'Light', 'Wavelength', 'Light', 'Scattering', 'Light', 'Scattering', 'Wavelength', 'Wavelength', 'Light', 'Scattering', 'Color', 'Light', 'Scattering', 'Light', 'Direction (geometry)', 'Wavelength', 'Scattering', 'Direction (geometry)', 'Light', 'Scattering', 'Light', 'Scattering', 'Color', 'Scattering']
# ['Hertz', 'Light', 'Electron', 'Photoelectric effect', 'Light', 'Electron', 'Photoelectric effect', 'Photoelectric effect', 'Electron', 'Light', 'Light', 'Wave', 'Light', 'Electron', 'Energy', 'Light', 'Light', 'Energy', 'Electron', 'Electron', 'Light', 'Light', 'Energy', 'Electron', 'Wave', 'Energy', 'Electron', 'Color', 'Light', 'Wavelength', 'Frequency', 'Energy', 'Energy', 'Electron', 'Work (physics)', 'Energy', 'Energy', 'Electron', 'Energy', 'Energy', 'Electron', 'Work (physics)', 'Light', 'Wavelength', 'Light', 'Electron', 'Energy', 'Light', 'Wave', 'Photoelectric effect', 'Light', 'Energy', 'Electron', 'Electron', 'Energy', 'Photoelectric effect', 'Hertz', 'Electron', 'Photoelectric effect', 'Photoelectric effect', 'Light', 'Light', 'Wave', 'Wave', 'Diffraction', 'Light', 'Photoelectric effect', 'Light', 'Light', 'Wave', 'Light', 'Diffraction', 'Light', 'Wave', 'Photoelectric effect']
# ['Electron', 'Energy', 'Electron', 'Energy', 'Energy', 'Energy level', 'Electron', 'Energy level', 'Energy', 'Work (physics)', 'Energy', 'Electron', 'Photoelectric effect', 'Work (physics)', 'Work (physics)', 'Electron', 'Work (physics)', 'Electrical conductor', 'Electron', 'Electrical ', 'Electrical resistance and conductance', 'Electric current', 'Work (physics)', 'Electron', 'Energy', 'Electron', 'Voltage', 'Energy', 'Electron', 'Energy', 'Energy', 'Electron']
# ['Photoelectric effect', 'Electron', 'Reflection (physics)', 'Scattering', 'Electric current', 'Work (physics)', 'Electric current', 'Electric current']
# []
# ['Electron', 'Energy', 'Energy level', 'Energy level', 'Temperature', 'Color', 'Light', 'Temperature', 'Light', 'Color', 'Wavelength', 'Voltage', 'Electrical conductor', 'Electric current', 'Electric current', 'Energy', 'Voltage', 'Energy', 'Electron', 'Electron', 'Electric current', 'Electron', 'Energy level', 'Electron', 'Electromagnetic radiation', 'Light', 'Wavelength', 'Emission spectrum', 'Wavelength', 'Color', 'Light', 'Emission spectrum', 'Wavelength', 'Energy', 'Electron', 'Energy level', 'Electron', 'Energy level', 'Energy level', 'Energy', 'Energy', 'Energy', 'Energy level', 'Frequency', 'Energy', 'Frequency', 'Wavelength', 'Color', 'Color', 'Electron', 'Energy level', 'Electron', 'Energy level', 'Energy level', 'Energy', 'Energy', 'Energy level', 'Electron', 'Energy', 'Light', 'Electromagnetic radiation', 'Energy level', 'Emission spectrum']
# ['Energy', 'Electron', 'Energy level', 'Electron', 'Energy level', 'Energy level', 'Energy', 'Scattering', 'Energy', 'Absorption spectroscopy', 'Absorption spectroscopy', 'Light', 'Light', 'Wavelength', 'Light', 'Absorption spectroscopy', 'Energy level', 'Wavelength', 'Absorption spectroscopy', 'Emission spectrum', 'Emission spectrum', 'Absorption spectroscopy', 'Emission spectrum', 'Emission spectrum', 'Energy level']
# ['Wavelength', 'Frequency', 'Light', 'Color', 'Light', 'Wavelength', 'Color', 'Light', 'Energy', 'Light', 'Frequency', 'Wavelength', 'Light', 'Energy']
# ['Light', 'Light', 'Wavelength', 'Velocity', 'Doppler effect', 'Frequency', 'Wavelength', 'Sound', 'Wave', 'Sound', 'Electromagnetic radiation', 'Light', 'Wavelength', 'Light', 'Wavelength', 'Light', 'Doppler effect', 'Motion', 'Light', 'Velocity', 'Emission spectrum', 'Wavelength', 'Frequency', 'Position (vector)', 'Velocity', 'Light', 'Wavelength', 'Wavelength', 'Wavelength', 'Energy level', 'Wavelength', 'Wavelength', 'Direction (geometry)', 'Temperature', 'Temperature']
# ['Laser', 'Light', 'Laser', 'Wavelength', 'Frequency', 'Amplitude', 'Wavelength', 'Color', 'Light', 'Color', 'Light', 'Light', 'Wavelength', 'Light', 'Wavelength', 'Laser', 'Light', 'Direction (geometry)', 'Laser', 'Distance', 'Energy', 'Energy', 'Laser', 'Laser', 'Light', 'Laser', 'Energy level', 'Laser', 'Laser', 'Light', 'Laser', 'Light', 'Emission spectrum', 'Emission spectrum', 'Emission spectrum', 'Emission spectrum', 'Electron', 'Energy level', 'Energy', 'Energy', 'Energy level', 'Emission spectrum', 'Emission spectrum', 'Electron', 'Energy level', 'Energy level', 'Energy', 'Energy', 'Emission spectrum', 'Electron', 'Electron', 'Energy level', 'Emission spectrum', 'Emission spectrum', 'Energy', 'Energy', 'Electron', 'Electron', 'Energy level', 'Emission spectrum', 'Emission spectrum', 'Energy', 'Emission spectrum', 'Emission spectrum']
# ['Laser', 'Work (physics)', 'Emission spectrum', 'Laser', 'Emission spectrum', 'Electron', 'Electron', 'Electron', 'Energy level', 'Energy', 'Electron', 'Laser', 'Light', 'Emission spectrum', 'Energy', 'Laser', 'Energy', 'Energy', 'Laser', 'Emission spectrum', 'Laser', 'Emission spectrum', 'Laser', 'Laser', 'Geometrical optics', 'Laser', 'Strength of materials', 'Electron', 'Electron', 'Electron', 'Emission spectrum', 'Electron', 'Energy level', 'Electron', 'Emission spectrum', 'Electron', 'Energy', 'Laser', 'Laser', 'Light', 'Energy', 'Laser', 'Laser', 'Wavelength', 'Laser', 'Laser', 'Laser', 'Laser', 'Laser', 'Wavelength', 'Laser', 'Light', 'Work (physics)', 'Laser', 'Laser', 'Laser']
# ['Laser', 'Work (physics)', 'Laser', 'Laser', 'Laser', 'Laser', 'Laser', 'Laser', 'Laser', 'Laser', 'Energy level', 'Laser', 'Laser', 'Laser', 'Geometrical optics', 'Laser', 'Laser', 'Laser', 'Energy', 'Laser', 'Electron', 'Laser', 'Laser', 'Emission spectrum', 'Electron', 'Energy', 'Energy', 'Energy level', 'Laser', 'Laser', 'Laser', 'Laser', 'Energy', 'Laser', 'Emission spectrum', 'Emission spectrum', 'Laser', 'Laser', 'Laser', 'Electron', 'Emission spectrum', 'Electron', 'Laser', 'Laser', 'Geometrical optics', 'Laser', 'Laser', 'Laser', 'Curved mirror', 'Reflection (physics)', 'Light', 'Reflection (physics)', 'Emission spectrum', 'Laser', 'Laser', 'Direction (geometry)', 'Geometrical optics', 'Laser', 'Laser', 'Frequency', 'Laser', 'Light', 'Distance', 'Light', 'Frequency', 'Reflection (physics)', 'Light', 'Frequency', 'Physics', 'Length', 'Wavelength', 'Sound', 'Frequency', 'Light', 'Laser', 'Geometrical optics', 'Work (physics)', 'Energy level', 'Physics']

# %%
concept_data = get_concept_content_matching(concept_index_data, book_data)

# %%
print(concept_data[0])
# Out:
# {'concept': 'Crystallinity', 'func_type': 0, 'title_match_index': '', 'content_match_index': ['13.3.1', '20.2', '22.4.2', '27.3.1'], 'freq_content_match': [3, 1, 1, 1]}

# %%
concept_data = sort_concept_data(concept_data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-f0521765e5e2> in <module>
# ----> 1 concept_data = sort_concept_data(concept_data)
#
# <ipython-input-5-f78e0acabbbe> in sort_concept_data(concept_data)
#       5
#       6                 freq = concept_data[i]["freq_content_match"]
# ----> 7                 concept_data[i]["freq_content_match"] = "|".join(freq)
#       8         return concept_data
#       9
#
# TypeError: sequence item 0: expected str instance, int found
