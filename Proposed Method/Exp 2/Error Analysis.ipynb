# %%
import pandas as pd

# %%
df = pd.read_csv("data/test_data_pred.csv")
df_prereq = pd.read_csv("data/first_prereq_pairs.csv")

# %%
df_prereq.set_index("concept", inplace = True)

# %%
upper_limit = 0.9
lower_limit = 0.1

# %%
required_df = pd.DataFrame(columns = ["topic_a", "topic_b", "relation", "tfidf_score", "wiki_tfidf_score", "score"])

for i in range(df.shape[0]):
    topic_a = df["topic_a"].iloc[i]
    topic_b = df["topic_b"].iloc[i]
#     print(topic_a, topic_b)
    score = df_prereq.at[topic_a, topic_b]
    df.at[i, "score"] = score
    ground_truth = df["relation"].iloc[i]
    tfidf_score = df["tfidf_score"].iloc[i]
    wiki_tfidf_score = df["wiki_tfidf_score"].iloc[i]
    if ground_truth == 1 and tfidf_score == 0:
        required_df = required_df.append(df.iloc[i])

# %%
required_df.reset_index(inplace = True)
required_df = required_df[["topic_a", "topic_b", "relation", "tfidf_score", "wiki_tfidf_score", "score"]]

# %%
required_df
# Out:
#                                   topic_a                          topic_b  \
# 0                  Gravitational constant                            Force
# 1                 Insulator (electricity)                 Electric current
# 2                     Equations of motion                            Force
# 3   Electrical resistance and conductance                          Voltage
# 4                       Mechanical energy                   Kinetic energy
# 5            Series and parallel circuits                 Electric current
# 6         Interference (wave propagation)                        Frequency
# 7                      Fatigue (material)        Deformation (engineering)
# 8                   Displacement (vector)                           Motion
# 9                             Capacitance                  Electric charge
# 10                         Work (physics)            Displacement (vector)
# 11              Electric potential energy                 Potential energy
# 12                       Potential energy                           Energy
# 13                           Acceleration                            Force
# 14  Electrical resistance and conductance                        Ohm's law
# 15        Interference (wave propagation)                       Wavelength
# 16                         Work (physics)                 Euclidean vector
# 17              Huygens–Fresnel principle                        Amplitude
# 18                    Electromotive force                 Electric current
# 19                            Snell's law                       Refraction
# 20                 Gravitational constant                          Gravity
# 21                       Refractive index                             Wave
# 22                           Normal force                    Contact force
# 23                         Electric field                    Coulomb's law
# 24                     Electric potential                    Coulomb's law
# 25                Newton's laws of motion                            Force
# 26                      Projectile motion                            Force
# 27                     Geometrical optics                     Ray (optics)
# 28                       Refractive index               Angle of incidence
# 29                         Work (physics)                           Energy
# 30                                  Hertz                        Frequency
# 31                      Emission spectrum                   Magnetic field
# 32           Series and parallel circuits                        Ohm's law
# 33                              Stiffness                            Force
# 34                      Projectile motion                     Acceleration
# 35              Electric potential energy                   Electric field
# 36                      Emission spectrum                    Coulomb's law
# 37                          Standing wave  Interference (wave propagation)
# 38                   Plasticity (physics)        Deformation (engineering)
# 39                               Hardness             Plasticity (physics)
# 40                               Hardness            Strength of materials
#
#     relation  tfidf_score  wiki_tfidf_score     score
# 0        1.0          0.0               0.0  0.000000
# 1        1.0          0.0               0.0  0.041029
# 2        1.0          0.0               0.0  0.114953
# 3        1.0          0.0               0.0  0.206104
# 4        1.0          0.0               0.0  0.122615
# 5        1.0          0.0               0.0  0.178421
# 6        1.0          0.0               0.0  0.104910
# 7        1.0          0.0               0.0  0.230816
# 8        1.0          0.0               0.0  0.037855
# 9        1.0          0.0               0.0  0.194981
# 10       1.0          0.0               0.0  0.210576
# 11       1.0          0.0               0.0  0.185779
# 12       1.0          0.0               0.0  0.138049
# 13       1.0          0.0               0.0  0.108718
# 14       1.0          0.0               0.0  0.000000
# 15       1.0          0.0               0.0  0.104910
# 16       1.0          0.0               0.0  0.064241
# 17       1.0          0.0               0.0  0.177099
# 18       1.0          0.0               0.0  0.199946
# 19       1.0          0.0               0.0  1.060494
# 20       1.0          0.0               0.0  0.000000
# 21       1.0          0.0               0.0  0.146853
# 22       1.0          0.0               0.0  0.000000
# 23       1.0          0.0               0.0  0.000000
# 24       1.0          0.0               0.0  0.000000
# 25       1.0          0.0               0.0  0.582921
# 26       1.0          0.0               0.0  0.108718
# 27       1.0          0.0               0.0  0.501367
# 28       1.0          0.0               0.0  0.162242
# 29       1.0          0.0               0.0  0.041939
# 30       1.0          0.0               0.0  0.000000
# 31       1.0          0.0               0.0  0.000000
# 32       1.0          0.0               0.0  0.000000
# 33       1.0          0.0               0.0  0.000000
# 34       1.0          0.0               0.0  0.017446
# 35       1.0          0.0               0.0  0.232666
# 36       1.0          0.0               0.0  0.000000
# 37       1.0          0.0               0.0  0.000000
# 38       1.0          0.0               0.0  0.158686
# 39       1.0          0.0               0.0  0.000000
# 40       1.0          0.0               0.0  0.000000

# %% [markdown]
# 1. Problem with Data Normalisation, e.g., "Gravitational Constant" and "Gravity", "Magnetism"  and "Magnet"
# 2. We didn't get content for few conceptes in ToC, e.g., "Hardness", "Stiffness", "Hertz"
# 3. Ranking issue
# 4. Some ambiguous Rleationships
#     - Row - 4, 34
# 5. TFIDF value decreases while finding Implicit Relations
