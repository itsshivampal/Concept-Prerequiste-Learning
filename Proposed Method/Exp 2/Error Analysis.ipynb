# %%
import pandas as pd

# %%
df = pd.read_csv("data/test_data_pred.csv")
df_prereq = pd.read_csv("data/first_prereq_pairs.csv")

# %%
df_prereq.set_index("concept", inplace = True)

# %%
upper_limit = 0.9
lower_limit = 0.1

# %%
required_df = pd.DataFrame(columns = ["topic_a", "topic_b", "relation", "tfidf_score", "wiki_tfidf_score", "score"])

for i in range(df.shape[0]):
    topic_a = df["topic_a"].iloc[i]
    topic_b = df["topic_b"].iloc[i]
#     print(topic_a, topic_b)
    score = df_prereq.at[topic_a, topic_b]
    df.at[i, "score"] = score
    ground_truth = df["relation"].iloc[i]
    tfidf_score = df["tfidf_score"].iloc[i]
    wiki_tfidf_score = df["wiki_tfidf_score"].iloc[i]
    if ground_truth == 1 and tfidf_score == 0:
        required_df = required_df.append(df.iloc[i])

# %%
required_df.reset_index(inplace = True)
required_df = required_df[["topic_a", "topic_b", "relation", "tfidf_score", "wiki_tfidf_score", "score"]]

# %%
required_df
# Out:
#                                   topic_a                          topic_b  \
# 0             Inertial frame of reference                            Speed
# 1                  Gravitational constant                            Force
# 2                 Insulator (electricity)                 Electric current
# 3            Series and parallel circuits                 Electric current
# 4                         Transverse wave                             Wave
# 5                          Work (physics)            Displacement (vector)
# 6                            Acceleration                            Force
# 7   Electrical resistance and conductance                        Ohm's law
# 8                          Work (physics)                 Euclidean vector
# 9                     Electromotive force                 Electric current
# 10                 Gravitational constant                          Gravity
# 11                           Normal force                    Contact force
# 12                         Electric field                    Coulomb's law
# 13                     Geometrical optics                            Light
# 14                     Electric potential                    Coulomb's law
# 15                     Geometrical optics                     Ray (optics)
# 16                         Work (physics)                           Energy
# 17                                  Hertz                        Frequency
# 18                      Emission spectrum                   Magnetic field
# 19           Series and parallel circuits                        Ohm's law
# 20                              Stiffness                            Force
# 21                              Magnetism                           Magnet
# 22              Electric potential energy                   Electric field
# 23                      Emission spectrum                    Coulomb's law
# 24                          Standing wave  Interference (wave propagation)
# 25                   Plasticity (physics)        Deformation (engineering)
# 26                               Hardness             Plasticity (physics)
# 27                               Hardness            Strength of materials
#
#     relation  tfidf_score  wiki_tfidf_score     score
# 0        1.0          0.0               0.0  0.090149
# 1        1.0          0.0               0.0  0.000000
# 2        1.0          0.0               0.0  0.041029
# 3        1.0          0.0               0.0  0.178421
# 4        1.0          0.0               0.0  0.452912
# 5        1.0          0.0               0.0  0.210576
# 6        1.0          0.0               0.0  0.040301
# 7        1.0          0.0               0.0  0.000000
# 8        1.0          0.0               0.0  0.064241
# 9        1.0          0.0               0.0  0.178421
# 10       1.0          0.0               0.0  0.000000
# 11       1.0          0.0               0.0  0.000000
# 12       1.0          0.0               0.0  0.000000
# 13       1.0          0.0               0.0  0.269498
# 14       1.0          0.0               0.0  0.000000
# 15       1.0          0.0               0.0  0.501367
# 16       1.0          0.0               0.0  0.041939
# 17       1.0          0.0               0.0  0.000000
# 18       1.0          0.0               0.0  0.000000
# 19       1.0          0.0               0.0  0.000000
# 20       1.0          0.0               0.0  0.000000
# 21       1.0          0.0               0.0  0.952940
# 22       1.0          0.0               0.0  0.232666
# 23       1.0          0.0               0.0  0.000000
# 24       1.0          0.0               0.0  0.000000
# 25       1.0          0.0               0.0  0.158686
# 26       1.0          0.0               0.0  0.000000
# 27       1.0          0.0               0.0  0.000000

# %% [markdown]
# 1. Problem with Data Normalisation, e.g., "Gravitational Constant" and "Gravity", "Magnetism"  and "Magnet"
# 2. We didn't get content for few conceptes in ToC, e.g., "Hardness", "Stiffness", "Hertz"
# 3. Ranking issue
# 4. Some ambiguous Rleationships
#     - Row - 4, 34
# 5. TFIDF value decreases while finding Implicit Relations
