# %%
import pandas as pd
import numpy as np

import sklearn

from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.svm import LinearSVC

from sklearn.linear_model import Lasso, LogisticRegression
from sklearn.feature_selection import SelectFromModel
from sklearn.preprocessing import StandardScaler

from sklearn.model_selection import train_test_split, KFold
from sklearn import metrics
from sklearn import preprocessing
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, roc_auc_score, average_precision_score
from sklearn.metrics import plot_precision_recall_curve, precision_recall_curve
import matplotlib.pyplot as plt

# %%
all_data = pd.read_csv("../output_files/physics_pairs_data.csv")
pred_tfidf_val = pd.read_csv("data/predicted_prereq.csv")
rank_val = pd.read_csv("data/concept_rank.csv")

# %%
all_data["tfidf"] = pred_tfidf_val["wiki_tfidf_score"].to_numpy().ravel()

# %%
concept_rank = {}

for i in range(rank_val.shape[0]):
    concept = rank_val[["concept"]].iloc[i].values[0]
    rank = rank_val[["rank"]].iloc[i].values[0]
    concept_rank[concept] = rank

# %%
def rank_score(c1, c2):
    r1 = int(concept_rank[c1])
    r2 = int(concept_rank[c2])
    if r1 <= r2:
        return 1
    else:
        return 0

# %%
pred_rank = []
for i in range(all_data.shape[0]):
    topic_a = all_data[["topic_a"]].iloc[i].values[0]
    topic_b = all_data[["topic_b"]].iloc[i].values[0]
    rank = rank_score(topic_a, topic_b)
    pred_rank.append(rank)

# %%
all_data["rank"] = pred_rank

# %%
all_data
# Out:
#       Unnamed: 0     f0     f1      f2      f3   f4   f5    f6   f7   f8  ...  \
# 0              0  321.0  190.0  1613.0   197.0  2.0  4.0  19.0  0.0  0.0  ...
# 1              1   36.0   77.0   109.0   101.0  3.0  2.0   4.0  0.0  0.0  ...
# 2              2  808.0  495.0  3104.0  2394.0  2.0  3.0  25.0  0.0  0.0  ...
# 3              3   99.0   48.0    96.0   212.0  2.0  4.0   5.0  0.0  0.0  ...
# 4              4  643.0  162.0  9935.0   129.0  1.0  5.0  21.0  0.0  0.0  ...
# ...          ...    ...    ...     ...     ...  ...  ...   ...  ...  ...  ...
# 1957        1957  350.0  203.0  4432.0    92.0  3.0  4.0  22.0  0.0  0.0  ...
# 1958        1958  321.0   59.0  1613.0   420.0  2.0  3.0   7.0  1.0  0.0  ...
# 1959        1959  127.0   48.0  1368.0   269.0  4.0  1.0  11.0  0.0  0.0  ...
# 1960        1960  643.0  147.0  9935.0   851.0  1.0  4.0  24.0  0.0  0.0  ...
# 1961        1961  321.0  149.0  1613.0   275.0  2.0  6.0  18.0  1.0  1.0  ...
#
#          f33    f34       f35       f36           f37  relation  \
# 0      504.0   87.0  0.000040  0.000086  1.118241e-05       0.0
# 1      161.0   21.0  0.000002  0.000002  9.914547e-08       1.0
# 2     1060.0  103.0 -0.000003 -0.000017  1.509753e-05       0.0
# 3      128.0   19.0  0.000007 -0.000004 -1.144610e-05       0.0
# 4      109.0   12.0  0.000095  0.000940  6.710326e-05       0.0
# ...      ...    ...       ...       ...           ...       ...
# 1957  1078.0  139.0  0.000010  0.000172  2.182559e-05       0.0
# 1958   104.0   30.0  0.000113  0.000062  7.647945e-06       0.0
# 1959   269.0   28.0  0.000062  0.000055  8.195897e-06       0.0
# 1960   224.0   37.0  0.000150  0.000904  5.851008e-05       0.0
# 1961   451.0   91.0  0.000055  0.000082  8.845842e-06       0.0
#
#                          topic_a                          topic_b     tfidf  \
# 0                 Magnetic field      Inertial frame of reference  0.000000
# 1     Gravitational acceleration                Position (vector)  0.000000
# 2                         Energy                           Planet  0.000000
# 3              Mechanical energy              Gravitational field  0.090940
# 4                        Physics        Electric potential energy  0.000000
# ...                          ...                              ...       ...
# 1957                        Mass  Le Sage's theory of gravitation  0.000000
# 1958              Magnetic field                           Length  0.511849
# 1959                     Voltage     Series and parallel circuits  0.000000
# 1960                     Physics                         Velocity  0.000000
# 1961              Magnetic field                   Work (physics)  0.000000
#
#       rank
# 0        0
# 1        0
# 2        0
# 3        0
# 4        1
# ...    ...
# 1957     1
# 1958     0
# 1959     0
# 1960     1
# 1961     0
#
# [1962 rows x 44 columns]

# %% [markdown]
# # Data Normalization

# %%
df = all_data[["relation", "tfidf", "rank", "f0", "f1", "f2", "f3", "f4", "f5", "f6", "f7", "f8", "f9",
            "f10", "f11", "f12", "f13", "f14", "f15", "f16", "f17", "f18", "f19",
            "f20", "f21", "f22", "f23", "f24", "f25", "f26", "f27", "f28", "f29",
            "f30", "f31", "f32", "f33", "f34", "f35", "f36", "f37"]]

# %%
df.corr()
# Out:
#           relation     tfidf      rank        f0        f1        f2  \
# relation  1.000000  0.437022 -0.394142 -0.274663  0.323858 -0.201647
# tfidf     0.437022  1.000000 -0.380882 -0.140150  0.373030 -0.096854
# rank     -0.394142 -0.380882  1.000000  0.262550 -0.263595  0.246231
# f0       -0.274663 -0.140150  0.262550  1.000000 -0.068297  0.540906
# f1        0.323858  0.373030 -0.263595 -0.068297  1.000000 -0.073316
# f2       -0.201647 -0.096854  0.246231  0.540906 -0.073316  1.000000
# f3        0.273093  0.390122 -0.240038 -0.078357  0.506576 -0.063400
# f4       -0.003634  0.019012 -0.038027  0.016583  0.072269 -0.050681
# f5       -0.105155 -0.158779  0.024653  0.047338 -0.032571  0.021698
# f6        0.049004 -0.000312  0.076180  0.163870  0.218096  0.009639
# f7        0.046393 -0.028526  0.069307 -0.169742 -0.145687 -0.101315
# f8        0.060338  0.026119  0.006117  0.015857  0.018388 -0.047171
# f9        0.009591 -0.041619  0.110378  0.017768  0.032748  0.024363
# f10       0.381923  0.311025 -0.336891 -0.500419  0.507336 -0.359198
# f11      -0.155892 -0.069513  0.231203  0.213659 -0.103455  0.190881
# f12       0.396251  0.337477 -0.193606 -0.119932  0.214081 -0.082422
# f13       0.206581  0.244332 -0.102138 -0.069917  0.140242 -0.048225
# f14      -0.047947 -0.013477 -0.051448 -0.064920 -0.061122 -0.019093
# f15       0.291827  0.173802 -0.105486 -0.261977  0.232876 -0.241072
# f16      -0.159745 -0.187810  0.260827  0.203280 -0.244997  0.176634
# f17      -0.027943  0.137118 -0.110908  0.252351  0.249504  0.250128
# f18      -0.102921 -0.022837 -0.077545  0.106674  0.091394  0.089123
# f19      -0.072697 -0.010530 -0.068432  0.002000  0.000106  0.037000
# f20      -0.022574  0.166446 -0.046512  0.172652  0.179428  0.194418
# f21       0.069408 -0.064238  0.093857 -0.118819 -0.119073 -0.179292
# f22      -0.056658 -0.014986  0.008080  0.069906 -0.017714  0.191927
# f23      -0.046149  0.095807 -0.047550 -0.005983  0.112622  0.024094
# f24      -0.001007 -0.003695  0.012035  0.032813 -0.042176  0.108823
# f25       0.003204 -0.006299  0.004765 -0.077897  0.029336 -0.055538
# f26      -0.206104 -0.107220  0.137331  0.744578 -0.026394  0.256139
# f27       0.153710  0.179534 -0.186922 -0.025074  0.743786 -0.053406
# f28       0.291870  0.193350 -0.184750  0.004098  0.207389 -0.060710
# f29      -0.135859 -0.060637  0.223924  0.212847  0.009823  0.073187
# f30       0.358678  0.267601 -0.199709 -0.182716  0.158203 -0.111598
# f31      -0.162340 -0.098862  0.271291  0.164810 -0.168357  0.051422
# f32      -0.217845 -0.112031  0.151837  0.816726 -0.033677  0.348096
# f33       0.195284  0.247097 -0.191057 -0.027999  0.814475 -0.052346
# f34       0.013843  0.025743  0.002943  0.400360  0.420446  0.093705
# f35      -0.138730 -0.194625  0.191626  0.339464 -0.412019  0.238469
#
#                f30       f31       f32       f33       f34       f35  \
# relation  0.358678 -0.162340 -0.217845  0.195284  0.013843 -0.138730
# tfidf     0.267601 -0.098862 -0.112031  0.247097  0.025743 -0.194625
# rank     -0.199709  0.271291  0.151837 -0.191057  0.002943  0.191626
# f0       -0.182716  0.164810  0.816726 -0.027999  0.400360  0.339464
# f1        0.158203 -0.168357 -0.033677  0.814475  0.420446 -0.412019
# f2       -0.111598  0.051422  0.348096 -0.052346  0.093705  0.238469
# f3        0.037333 -0.113562 -0.044151  0.316381  0.070732 -0.249888
# f4       -0.014453 -0.036761  0.179591  0.063716  0.152876 -0.034541
# f5       -0.010075  0.001170  0.045365  0.144542  0.139768  0.004345
# f6        0.102653  0.118482  0.110690  0.180274  0.481654 -0.018539
# f7        0.123893  0.124373 -0.147903 -0.105276  0.007540  0.020406
# f8        0.169382  0.230439  0.051241  0.017121  0.269578 -0.006937
# f9        0.212443  0.190180  0.020456  0.081838  0.302910 -0.017542
# f10       0.289947 -0.300998 -0.437034  0.437651 -0.000226 -0.396099
# f11      -0.050201  0.458953  0.153510 -0.085205  0.108941  0.117594
# f12       0.432155 -0.048669 -0.112729  0.160503  0.091449 -0.094606
# f13       0.405399 -0.018465 -0.074443  0.084337  0.013898 -0.067848
# f14      -0.035323 -0.053040 -0.044489 -0.050867 -0.117515  0.017900
# f15       0.266317 -0.065451 -0.255995  0.160392  0.123010 -0.160484
# f16      -0.081978  0.283316  0.120986 -0.232668  0.114853  0.197568
# f17      -0.190834 -0.195970  0.192398  0.194731 -0.035366 -0.094784
# f18      -0.307988 -0.323409  0.146275  0.118032 -0.059455 -0.006311
# f19      -0.185841 -0.191367 -0.002554  0.000418 -0.177699 -0.102985
# f20      -0.040875 -0.047550  0.138954  0.143183  0.048307 -0.024591
# f21       0.103328  0.123738 -0.119383 -0.106087  0.041758  0.019969
# f22      -0.042199  0.007090  0.086662 -0.015974  0.024727  0.033735
# f23       0.005783 -0.022981 -0.005089  0.136909  0.043024 -0.096597
# f24      -0.086110 -0.020492  0.024531 -0.026744 -0.094327  0.018010
# f25      -0.053968 -0.092452 -0.069246  0.035693 -0.123185 -0.074186
# f26      -0.171072  0.100499  0.976803 -0.003454  0.550474  0.295673
# f27       0.098292 -0.151259 -0.008027  0.978068  0.577915 -0.476389
# f28       0.661415 -0.003592  0.091826  0.136177  0.311135 -0.018974
# f29      -0.005683  0.658804  0.137881  0.098285  0.328641  0.012857
# f30       1.000000 -0.033279 -0.183426  0.096892  0.046643 -0.088761
# f31      -0.033279  1.000000  0.098625 -0.164217  0.063978  0.117224
# f32      -0.183426  0.098625  1.000000 -0.007086  0.533659  0.321604
# f33       0.096892 -0.164217 -0.007086  1.000000  0.564776 -0.472048
# f34       0.046643  0.063978  0.533659  0.564776  1.000000 -0.064171
# f35      -0.088761  0.117224  0.321604 -0.472048 -0.064171  1.000000
# f36      -0.074954  0.092483  0.181444 -0.187204  0.013355  0.283260
# f37      -0.133452  0.156454  0.370441 -0.376465  0.006051  0.415675
#
#                f36       f37
# relation -0.271796 -0.407061
# tfidf    -0.292722 -0.437032
# rank      0.274544  0.441246
# f0        0.318917  0.548772
# f1       -0.323748 -0.554653
# f2        0.660178  0.647199
# f3       -0.757114 -0.652273
# f4       -0.058944 -0.126162
# f5       -0.016644  0.096153
# f6        0.013969  0.003824
# f7       -0.012063  0.003304
# f8       -0.080165 -0.055672
# f9        0.067300  0.061436
# f10      -0.395249 -0.592101
# f11       0.165849  0.220180
# f12      -0.140538 -0.202214
# f13      -0.076873 -0.124569
# f14      -0.006790 -0.013812
# f15      -0.215109 -0.318848
# f16       0.243155  0.348019
# f17      -0.044485 -0.045143
# f18      -0.029166 -0.023457
# f19      -0.038666 -0.020462
# f20      -0.019209 -0.021622
# f21       0.039162  0.033820
# f22       0.107871  0.104161
# f23      -0.157239 -0.151627
# f24       0.114596  0.086523
# f25      -0.118329 -0.086761
# f26       0.125456  0.298383
# f27      -0.129279 -0.303210
# f28      -0.073393 -0.098200
# f29       0.078843  0.116140
# f30      -0.074954 -0.133452
# f31       0.092483  0.156454
# f32       0.181444  0.370441
# f33      -0.187204 -0.376465
# f34       0.013355  0.006051
# f35       0.283260  0.415675
# f36       1.000000  0.797969
# f37       0.797969  1.000000
#
# [41 rows x 41 columns]

# %%
columns = ["f0", "f1", "f2", "f3", "f4", "f5", "f6", "f7", "f8", "f9",
            "f10", "f11", "f12", "f13", "f14", "f15", "f16", "f17", "f18", "f19",
            "f20", "f21", "f22", "f23", "f24", "f25", "f26", "f27", "f28", "f29",
            "f30", "f31", "f32", "f33", "f34", "f35", "f36", "f37", "tfidf", "rank"]

def normalize_array(x):
    x = np.array(x)
    min_x = np.min(x)
    max_x = np.max(x)
    x = (x - min_x)/(max_x - min_x)
    return x


def normalized_df(df):
    X = [normalize_array([df[[col]].values[i][0] for i in range(len(df[[col]]))]) for col in columns]
    X = np.array(X)
    return X.T

# %%
X = all_data[["f0", "f1", "f2", "f3", "f4", "f5", "f6", "f7", "f8", "f9",
            "f10", "f11", "f12", "f13", "f14", "f15", "f16", "f17", "f18", "f19",
            "f20", "f21", "f22", "f23", "f24", "f25", "f26", "f27", "f28", "f29",
            "f30", "f31", "f32", "f33", "f34", "f35", "f36", "f37", "tfidf", "rank"]]
X = normalized_df(X)

# %%
y = all_data[["relation"]].to_numpy().ravel()

# %% [markdown]
# # Data Modeling along with our features

# %%
def random_forest(x_train, x_test, y_train, y_test):
    rand_forest = RandomForestClassifier(max_depth = 200, random_state=0)
    rand_forest.fit(x_train, y_train)
    y_predict = rand_forest.predict_proba(x_test)
    precision, recall, theta = precision_recall_curve(y_test, y_predict[:,1])
    disp = plot_precision_recall_curve(rand_forest, x_test, y_test)
    return 1

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 0)

# %%
X_train.shape, y_train.shape
# Out:
# ((1373, 40), (1373,))

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# %%
X1 = SelectKBest(chi2, k=10).fit_transform(X, y)
X_train, X_test, y_train, y_test = train_test_split(X1, y, test_size = 0.3, random_state = 0)

# %%
X1.shape
# Out:
# (1962, 10)

# %%
random_forest(X_train[:50,:], X_test, y_train[:50], y_test)
# Out:
# 1

# %%
random_forest(X_train[:600,:], X_test, y_train[:600], y_test)
# Out:
# 1

# %%
random_forest(X_train[:900,:], X_test, y_train[:900], y_test)
# Out:
# 1

# %%
random_forest(X_train, X_test, y_train, y_test)
# Out:
# 1

# %% [markdown]
# # Data Modelingonly  with their features

# %%
X_new = X[:,:-2]
X_new.shape
# Out:
# (1962, 38)

# %%
X2 = SelectKBest(chi2, k=10).fit_transform(X_new, y)
X_train, X_test, y_train, y_test = train_test_split(X2, y, test_size = 0.3, random_state = 0)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_new, y, test_size = 0.3, random_state = 0)

# %%
X_train.shape, y_train.shape
# Out:
# ((1373, 10), (1373,))

# %%
random_forest(X_train[:600,:], X_test, y_train[:600], y_test)
# Out:
# 1

# %%
random_forest(X_train[:900,:], X_test, y_train[:900], y_test)
# Out:
# 1

# %%
random_forest(X_train, X_test, y_train, y_test)
# Out:
# 1

# %%
random_forest(X_train[:50,:], X_test, y_train[:50], y_test)
# Out:
# 1

# %%
random_forest(X_train[:100,:], X_test, y_train[:100], y_test)
# Out:
# 1

# %% [markdown]
# ## Exclude our features and select top 10 features from data

# %%
random_forest(X_train[:50,:], X_test, y_train[:50], y_test)
# Out:
# 1

# %%
random_forest(X_train[:100,:], X_test, y_train[:100], y_test)
# Out:
# 1
