# %%
# For simulation time calculation

import timeit

start = timeit.default_timer()

# %%
# "Query" Search  within the given Dataset i.e. Stories

# Natural Language Toolkit, or more commonly NLTK, is a suite of libraries and programs for symbolic and 
# statistical natural language processing.

import nltk 
#-------------------------------------------------------------------------------

# OS module provides functions for interacting with the operating system. 

import os
#----------------------------------------------------------------------------------

# pandas for data manipulation and analysis.

import pandas as pd
#----------------------------------------------------------------------------------

# A RegEx, or Regular Expression, is a sequence of characters that forms a search pattern.
# RegEx can be used to check if a string contains the specified search pattern. 

import re
#------------------------------------------------------------------------------------

# Mathematical functions
# This module provides access to the mathematical functions.

import math
#------------------------------------------------------------------------------------

# NumPy is a Python package which stands for ‘Numerical Python’. 
#It is the core library for scientific computing, which contains a powerful n-dimensional array object, 
#provide tools for integrating C, C++ etc. It is also useful in linear algebra, random number capability etc.

import numpy as np
#-----------------------------------------------------------------------------------

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from collections import Counter
from num2words import num2words

# %%
# 1.  Taking all folders : loaded as... (in stories)
# 2.  Python method walk() generates the file names in a directory tree 
#     by walking the tree either top-down or bottom-up.

# folders[0]
# folders[1]
# folders[2]

# List comprehensions provide a concise way to create lists.
# For More details visit: https://www.pythonforbeginners.com/basics/list-comprehensions-in-python

folders = [x[0] for x in os.walk(str(os.getcwd())+'/'+"stories"+'/')]
folders
# Out:
# ['C:\\Users\\sumit/stories/',
#  'C:\\Users\\sumit/stories/FARNON',
#  'C:\\Users\\sumit/stories/SRE']

# %%
# we have code to retrieve the values from index, 
# we just need to iterate to all the folders and 
# get the title and file name from all the index.html files.

# 1. Help: file.read() reads entire file's contents, unless you specify max length.
# 2.  (Help: The strip() method removes any leading (spaces at the beginning) and 
#    trailing (spaces at the end) characters (space is the default leading character to remove))
# 3. Re.findall() module is used when you want to iterate over the lines of the file, 
#    it will return a list of all the matches in a single step. 

dataset = [] # start an empty list
c = False
for i in folders:
    file = open(i+   "/index.html", 'r')
    text = file.read().strip() 
    file.close()
    file_name = re.findall('><A HREF="(.*)">', text)
    file_title = re.findall('<BR><TD> (.*)\n', text)
    if c == False:
        file_name = file_name[2:]
        c = True
    print(len(file_name), len(file_title))

    for j in range(len(file_name)):
        dataset.append((str(i) +"/"+ str(file_name[j]), file_title[j]))
# Out:
# 452 452
# 0 0
# 15 15

# %%
file_name
# Out:
# ['sre01.txt',
#  'sre02.txt',
#  'sre03.txt',
#  'sre04.txt',
#  'sre05.txt',
#  'sre06.txt',
#  'sre07.txt',
#  'sre08.txt',
#  'sre09.txt',
#  'sre10.txt',
#  'sre_feqh.txt',
#  'sre_finl.txt',
#  'sre_sei.txt',
#  'sretrade.txt',
#  'srex.txt']

# %%
# Random view inside the dataset
dataset[400][1]
# Out:
# 'The Dark Sucker, by Quantum Mechanic'

# %%
# View dataset as fie_name and file_title
dataset
# Out:
# [('C:\\Users\\sumit/stories//100west.txt',
#   'Going 100 West by 53 North by Jim Prentice (1990)'),
#  ('C:\\Users\\sumit/stories//13chil.txt', 'The Story of the Sly Fox'),
#  ('C:\\Users\\sumit/stories//14.lws', 'A Smart Bomb with a Language Parser'),
#  ('C:\\Users\\sumit/stories//16.lws', 'Two Guys in a Garage, by M. Pshota'),
#  ('C:\\Users\\sumit/stories//17.lws',
#   'The Early Days of a High-Tech Start-up are Magic (November 18, 1991) by M. Peshota'),
#  ('C:\\Users\\sumit/stories//18.lws',
#   'The Couch, the File Cabinet, and the Calendar, by M. Peshota (December 9, 1991)'),
#  ('C:\\Users\\sumit/stories//19.lws',
#   'Engineering the Future of American Technology by M. Peshota (January 5, 1992)'),
#  ('C:\\Users\\sumit/stories//20.lws',
#   'What Research and Development Was Always Meant to Be, by M. Peshota'),
#  ('C:\\Users\\sumit/stories//3gables.txt',
#   'The Adventure of the Three Gables'),
#  ('C:\\Users\\sumit/stories//3lpigs.txt', 'The Story of the 3 Little Pigs'),
#  ('C:\\Users\\sumit/stories//3sonnets.vrs',
#   'A Collection of Sonnets by Staeorra Rokraven (March 9, 1989)'),
#  ('C:\\Users\\sumit/stories//3student.txt',
#   'The Adventure of the Three Students'),
#  ('C:\\Users\\sumit/stories//3wishes.txt', 'The Story of the Three Wishes'),
#  ('C:\\Users\\sumit/stories//4moons.txt', 'Fiction: The 4 Moons of Death'),
#  ('C:\\Users\\sumit/stories//5orange.txt',
#   'The Story of the Five Orange Pips'),
#  ('C:\\Users\\sumit/stories//6ablemen.txt', 'The Story of the Six Able Men'),
#  ('C:\\Users\\sumit/stories//6napolen.txt',
#   'The Adventure of the Six Napoleons'),
#  ('C:\\Users\\sumit/stories//7oldsamr.txt', 'The Seven Old Samurai'),
#  ('C:\\Users\\sumit/stories//7voysinb.txt',
#   'The Seven Voyages of Sinbad the Sailor'),
#  ('C:\\Users\\sumit/stories//ab40thv.txt',
#   'The Story of Ali Baba and the 40 Thieves'),
#  ('C:\\Users\\sumit/stories//abbey.txt',
#   'The Adventure of the Abbey Grange (RP Story)'),
#  ('C:\\Users\\sumit/stories//abyss.txt',
#   'How life goes on at the edge of Abyss'),
#  ('C:\\Users\\sumit/stories//adler.txt',
#   'The Chronicles of Astrus II: Father Adler by Ben Blumenberg'),
#  ('C:\\Users\\sumit/stories//adv_alad.txt', 'The Adventures of Aladdin'),
#  ('C:\\Users\\sumit/stories//advsayed.txt', "Sayed's Adventures"),
#  ('C:\\Users\\sumit/stories//advtthum.txt', 'The Adventures of Tom Thumb'),
#  ('C:\\Users\\sumit/stories//aesop11.txt',
#   "Aesop's Fables Translated by George Fyler Townsend"),
#  ('C:\\Users\\sumit/stories//aesopa10.txt',
#   "Aesop's Fables (84 of Them) from The PaperLess Readers Club"),
#  ('C:\\Users\\sumit/stories//aircon.txt', 'The Air Conditioning Story'),
#  ('C:\\Users\\sumit/stories//aisle.six', 'Aisle Six, by Morpheous of LOM'),
#  ('C:\\Users\\sumit/stories//aislesix.txt',
#   'Aisle Six, by Morpheous, an LOM Release'),
#  ('C:\\Users\\sumit/stories//alad10.txt', 'Aladdin and the Wonderful Lamp'),
#  ('C:\\Users\\sumit/stories//alissadl.txt',
#   "The Fable of Ali and the Sultan's Saddle"),
#  ('C:\\Users\\sumit/stories//altside.hum',
#   'Alternate Side of the Street; Screenplay by Jeff Massie'),
#  ('C:\\Users\\sumit/stories//aluminum.hum',
#   'An Aluminum Can A Day, by Carl Mitchell'),
#  ('C:\\Users\\sumit/stories//aminegg.txt', 'The Fable of Amin and the Eggs'),
#  ('C:\\Users\\sumit/stories//angelfur.hum', "Angel's Fur, by Piper Sickles"),
#  ('C:\\Users\\sumit/stories//angry_ca.txt', 'Cliff-Hanger, a Poem'),
#  ('C:\\Users\\sumit/stories//antcrick.txt',
#   'The Fable of the Ant and the Cricket'),
#  ('C:\\Users\\sumit/stories//aquith.txt',
#   'My Lord Aquith: Novella by Yves Barbero'),
#  ('C:\\Users\\sumit/stories//arcadia.sty', 'Arcadia, a Story'),
#  ('C:\\Users\\sumit/stories//archive',
#   ' A Collection of Various Good Stories'),
#  ('C:\\Users\\sumit/stories//arctic.txt',
#   'The Arctic Circle and Beyond, by Jim Prentice (1990)'),
#  ('C:\\Users\\sumit/stories//asop',
#   'Updating Aesop, or The Old Lady and the Crypt or Blood'),
#  ('C:\\Users\\sumit/stories//assorted.txt',
#   'FICTION: Yahoo! The Ohio VOW has The Bomb by Gregory S. Swann (1986)'),
#  ('C:\\Users\\sumit/stories//bagel.man',
#   'Bagel Man, by Aldebaran of 11th Hour Productions'),
#  ('C:\\Users\\sumit/stories//bagelman.txt',
#   'Bagel-Man, by Aldebaran of 11th Hour Productions'),
#  ('C:\\Users\\sumit/stories//batlslau.txt',
#   'Collection of Additional Rules for Battletech, by Matt Murphy'),
#  ('C:\\Users\\sumit/stories//beast.asc',
#   'A Collection of Fiction about The Beast'),
#  ('C:\\Users\\sumit/stories//beautbst.txt',
#   'The Story of Beauty and the Beast'),
#  ('C:\\Users\\sumit/stories//beggars.txt',
#   "The Beggar's Opera, by John Gay, 1728"),
#  ('C:\\Users\\sumit/stories//bern',
#   'The Adventures of Bert and Bernece, by  Francis U. Kaltenbaugh'),
#  ('C:\\Users\\sumit/stories//berternie.txt',
#   'How Ernie and Bert Came to Be, by 11th Hour Productions'),
#  ('C:\\Users\\sumit/stories//bestwish', 'FICTION: My Best Wish'),
#  ('C:\\Users\\sumit/stories//beyond.hum',
#   'Before the Beyond, by Dallas Vordahl'),
#  ('C:\\Users\\sumit/stories//bgb.txt',
#   'Beaver Gone Bad! A mini-manuscript by Pete Stocton and Baron Von Crash'),
#  ('C:\\Users\\sumit/stories//bgcspoof.txt',
#   'Mega-Yonkers 2038 : The Story of Knight Foils: Bubble Gum Cards, by Ryan Mathews, January 1992'),
#  ('C:\\Users\\sumit/stories//bigred.hum', 'Big Red Riding Cape'),
#  ('C:\\Users\\sumit/stories//bishop00.txt',
#   'Pyramid Scheme, by Douglas M. Warren, 1993'),
#  ('C:\\Users\\sumit/stories//blabnove.hum',
#   'The Super Blab Novel, from Datanet'),
#  ('C:\\Users\\sumit/stories//blabnove.txt',
#   'Super Blabnovel-A continuing saga on DATANET'),
#  ('C:\\Users\\sumit/stories//blackp.txt', 'The Adventure of Black Peter'),
#  ('C:\\Users\\sumit/stories//blackrdr',
#   'A Few Words About The Black Rider (German Literature)'),
#  ('C:\\Users\\sumit/stories//blak',
#   'Lunch in the Park, by Francis U. Kaltenbaugh'),
#  ('C:\\Users\\sumit/stories//blasters.fic',
#   'Blasters to the Ready! By William E. Collins'),
#  ('C:\\Users\\sumit/stories//blh.txt',
#   "The Birdlover's Holiday, by Andrew P. Varga"),
#  ('C:\\Users\\sumit/stories//blind.txt',
#   'Blind Sight, by Lyn Nichols, August 1993'),
#  ('C:\\Users\\sumit/stories//blossom.pom',
#   'Little Quaint list of Funny Names to Tell a story.'),
#  ('C:\\Users\\sumit/stories//blue', 'Soldier Blue, by Rick Arnold'),
#  ('C:\\Users\\sumit/stories//bluebrd.txt', 'Bluebeard'),
#  ('C:\\Users\\sumit/stories//bookem.1', "Boom 'Em Issue #1 (1995)"),
#  ('C:\\Users\\sumit/stories//bookem2', "Book 'Em Issue #2 (1995)"),
#  ('C:\\Users\\sumit/stories//bookem3', "Book 'Em Issue #3 (1995)"),
#  ('C:\\Users\\sumit/stories//brain.damage',
#   'Brain Damage, by Howard I Cannon, 1979'),
#  ('C:\\Users\\sumit/stories//bram', 'Brambles, by Gordon Chapman'),
#  ('C:\\Users\\sumit/stories//bran', 'Branded, by John R. Hillman, Jr.'),
#  ('C:\\Users\\sumit/stories//breaks1.asc',
#   'Breaks: The Adventures of Richard Nixon in the 21st Century, by Philip H. Farber (1992-1993)'),
#  ('C:\\Users\\sumit/stories//breaks2.asc',
#   'Breaks: The Adventures of Richard Nixon in the 21st Century, by Philip H. Farber (1992-1993)'),
#  ('C:\\Users\\sumit/stories//breaks3.asc',
#   'Breaks: The Adventures of Richard Nixon in the 21st Century, by Philip H. Farber (1992-1993)'),
#  ('C:\\Users\\sumit/stories//bruce-p.txt',
#   'The Adventure of the Bruce-Partington Plans'),
#  ('C:\\Users\\sumit/stories//buggy.txt', 'Buggy, by Andrew P. Varga (1991)'),
#  ('C:\\Users\\sumit/stories//buldetal.txt', 'Details, a story by The Martyr'),
#  ('C:\\Users\\sumit/stories//buldream.txt',
#   'Dreamworld, by Zaphod Beeblebrox'),
#  ('C:\\Users\\sumit/stories//bulfelis.txt', 'A Story for Cat Lovers'),
#  ('C:\\Users\\sumit/stories//bulhuntr.txt',
#   'The Hunter, the Hunted, a story by G. Daniel Flower'),
#  ('C:\\Users\\sumit/stories//bulironb.txt', 'Story: Iron Man'),
#  ('C:\\Users\\sumit/stories//bullove.txt',
#   'Three Paragraphs: Excertps from Something'),
#  ('C:\\Users\\sumit/stories//bulmrx.txt',
#   "They Don't Come Any Larger: The Continuing Adventures of Mr. X."),
#  ('C:\\Users\\sumit/stories//bulnland.txt', 'A New Land, by Vengeance'),
#  ('C:\\Users\\sumit/stories//bulnoopt.txt',
#   'No Options Left, by G. Daniel Flower'),
#  ('C:\\Users\\sumit/stories//bulolli1.txt',
#   "The Ill-Fated Voyages of Cap'n Roger, by Julius M. Brown (1989)"),
#  ('C:\\Users\\sumit/stories//bulolli2.txt',
#   "The Adventures of Cap'n Roger (Part 2)"),
#  ('C:\\Users\\sumit/stories//bulphrek.txt', 'A Phreak Encounter (Story)'),
#  ('C:\\Users\\sumit/stories//bulprint.txt',
#   'Prints of the City, by G. Daniel Flower'),
#  ('C:\\Users\\sumit/stories//bulwer.lytton',
#   'It was a dark and stormy night (The Best of the Bulwer-Lytton Contest)'),
#  ('C:\\Users\\sumit/stories//bulzork1.txt', "The Zorker's Story (Story)"),
#  ('C:\\Users\\sumit/stories//bumm', 'Bummers by Thomas Nevin Huber'),
#  ('C:\\Users\\sumit/stories//bureau.txt', 'The Bureau of Procuration (Story)'),
#  ('C:\\Users\\sumit/stories//burintrv.66',
#   'Interview with William S. Burroughs (1966)'),
#  ('C:\\Users\\sumit/stories//burintrv.78',
#   'William S. Burroughs: A Sketch (July 1978)'),
#  ('C:\\Users\\sumit/stories//burintrv.92',
#   'Which is the Fly and Which is the Human? (Interview with William S. Burroughs and David Cronenberg 1992, Equire Magazine'),
#  ('C:\\Users\\sumit/stories//burltrs',
#   'The Letters of William S. Burroughs (1945-1959) by Oliver Harris'),
#  ('C:\\Users\\sumit/stories//burn',
#   'The Burn: A Synopsis by Michael C. McPherson'),
#  ('C:\\Users\\sumit/stories//cabin.txt', 'The Cabin, by Adam Poszar (1991)'),
#  ('C:\\Users\\sumit/stories//cameloto.hum',
#   'Some aborted attempt at a screenplay, maybe'),
#  ('C:\\Users\\sumit/stories//campfire.txt',
#   'The Best Campire Story of the Week: Do you have a B.C.?'),
#  ('C:\\Users\\sumit/stories//candle.hum',
#   'The Wind, The Cold, The Candle, by Walter Hawn'),
#  ('C:\\Users\\sumit/stories//cardcnt.txt',
#   'Accounting for the Cards by H. R. Valimaa'),
#  ('C:\\Users\\sumit/stories//ccm.txt',
#   'The Fable of the Cock, the Cat, and the Mouse'),
#  ('C:\\Users\\sumit/stories//charlie.txt', 'Cosmic Charlie by Colin Campbell'),
#  ('C:\\Users\\sumit/stories//chik', 'City Chicken, by D. M. Hanna'),
#  ('C:\\Users\\sumit/stories//clevdonk.txt',
#   'The Donkey that Thought He Was Clever'),
#  ('C:\\Users\\sumit/stories//clon', 'Clones to us! By Thomas Nevin Huber'),
#  ('C:\\Users\\sumit/stories//cmoutmou.txt',
#   'The Story of The Country Mouse and the Town Mouse'),
#  ('C:\\Users\\sumit/stories//comp', "Computers N' Me, by Rich Griebel"),
#  ('C:\\Users\\sumit/stories//confilct.fun', 'Conflict, by Jason Scott'),
#  ('C:\\Users\\sumit/stories//consumdr.hum',
#   'Consumated Dreams, by Melanie Martin Vessels'),
#  ('C:\\Users\\sumit/stories//contrad1.hum', 'Contradiction 1, by Rick Brunet'),
#  ('C:\\Users\\sumit/stories//cooldark.sto',
#   'Cool Darkness: A Cyberpunk Novel by Matthew Carpenter'),
#  ('C:\\Users\\sumit/stories//cooldark.txt',
#   'STORY: Cool Darkness, by Matthew Carpenter'),
#  ('C:\\Users\\sumit/stories//corcor.hum', 'Corcoran, by Bruce Drake'),
#  ('C:\\Users\\sumit/stories//cow.exploder',
#   'The Story of the Cow Exploder by CKE Enterprises (1984)'),
#  ('C:\\Users\\sumit/stories//crabhern.txt',
#   'The Story of the Crab and the Heron'),
#  ('C:\\Users\\sumit/stories//crazy.hum', 'Crazy Glue, a Novel by Jerry Slaff'),
#  ('C:\\Users\\sumit/stories//cum', 'Come Into my World by Thomas NEvin Huber'),
#  ('C:\\Users\\sumit/stories//curious.george',
#   'Curious Georgie by The Penguin of SubZero AE'),
#  ('C:\\Users\\sumit/stories//cybersla.txt',
#   'Book: Revolt of the Cyberslaves, by Lawrence Dworin (1991)'),
#  ('C:\\Users\\sumit/stories//dakota.txt',
#   'Rifts World Book: North Dakota by Sean Satterlee'),
#  ('C:\\Users\\sumit/stories//dan', 'Made for Dancing, by Charles Bell'),
#  ('C:\\Users\\sumit/stories//darkness.txt',
#   'The Heart of Darkness by Joseph Conrad'),
#  ('C:\\Users\\sumit/stories//day.in.mcdonald',
#   'A Day in McDonaldland by G.I. Joe of DETAC (June 10, 1986)'),
#  ('C:\\Users\\sumit/stories//deal', 'Dealer, by Robbie D. Whiting'),
#  ('C:\\Users\\sumit/stories//deathmrs.d',
#   'The Death of Ms. D, by William S. Burroughs'),
#  ('C:\\Users\\sumit/stories//deer.txt', 'The Deer, by Andrew P. Varga (1992)'),
#  ('C:\\Users\\sumit/stories//descent.poe', 'A Descent into the Maelstrom'),
#  ('C:\\Users\\sumit/stories//diaryflf.txt', 'The Diary of the Swarves'),
#  ('C:\\Users\\sumit/stories//dicegame.txt',
#   'Guide to Dice Games of Dungeons and Dragons by Reid Bluebaugh'),
#  ('C:\\Users\\sumit/stories//dicksong.txt',
#   'A Manly Wager by Lucillus and a Heaping of Testosterone'),
#  ('C:\\Users\\sumit/stories//disco.be.fun',
#   'Disco Can By Fun, by Aldebaran of 11th Hour Productions'),
#  ('C:\\Users\\sumit/stories//discocanbefun.txt',
#   'Disco Can Be Fun by Aldebaran of 11th Hour Productions'),
#  ('C:\\Users\\sumit/stories//domain.poe', 'The Domain of Arnheim'),
#  ('C:\\Users\\sumit/stories//dopedenn.txt', 'The Story of Dopey Dennis'),
#  ('C:\\Users\\sumit/stories//dskool.txt', 'Dream School: A Novella'),
#  ('C:\\Users\\sumit/stories//dtruck.txt', "Dad's Pickup, by Andrew P. Varga"),
#  ('C:\\Users\\sumit/stories//dwar', 'Dwarf, by Jeroen Van Drie'),
#  ('C:\\Users\\sumit/stories//elite.app', 'Fiction: Alex'),
#  ('C:\\Users\\sumit/stories//elveshoe.txt', 'The Elves and the Shoemaker'),
#  ('C:\\Users\\sumit/stories//emperor3.txt',
#   "The Emperor's Three Questions by Leo Tolstoy"),
#  ('C:\\Users\\sumit/stories//empnclot.txt', "The Emperor's New Clothes"),
#  ('C:\\Users\\sumit/stories//empsjowk.txt', 'The Empress Jowka'),
#  ('C:\\Users\\sumit/stories//empty.txt', 'The Adventure of the Empty House'),
#  ('C:\\Users\\sumit/stories//enc', 'Encoded in Strands, by Gay Bost'),
#  ('C:\\Users\\sumit/stories//encamp01.txt',
#   'Saturday Night at the Shindar Encampment by Lucillus'),
#  ('C:\\Users\\sumit/stories//enchdup.hum',
#   'The Enchanted Duplicator, by Walt Willis and Bob Shaw'),
#  ('C:\\Users\\sumit/stories//enginer.txt',
#   "The Adventure of the Engineer's Thumb"),
#  ('C:\\Users\\sumit/stories//enya_trn.txt',
#   'English Translations of _The Celts_, _Watermark_, and _Shepherd Moons_, by Enya'),
#  ('C:\\Users\\sumit/stories//excerpt.hum',
#   'The Snarkout Boys and the Avocado of Death'),
#  ('C:\\Users\\sumit/stories//excerpt.txt',
#   'A Relevant Excerpt from "The Snarkout Boys and the Avocado of Death", by Daniel Manus Pinkwater.'),
#  ('C:\\Users\\sumit/stories//eyeargon.hum', 'The Eye of Argon, by Jim Theis'),
#  ('C:\\Users\\sumit/stories//ezoff', 'EZ Work, by Gay Bost'),
#  ('C:\\Users\\sumit/stories//fable.txt', 'The Fable, by Ben Blumenberg'),
#  ('C:\\Users\\sumit/stories//fantas.hum',
#   'Pricilla, the Trout Princess, by Gerald E. Gregg'),
#  ('C:\\Users\\sumit/stories//fantasy.hum', 'The Blab Fantasy Novel'),
#  ('C:\\Users\\sumit/stories//fantasy.txt',
#   'The Blab Fantasy novel-Ripped off and edited by The Slipped Disk'),
#  ('C:\\Users\\sumit/stories//fea1',
#   'Hula Hoops and Tinker Toys by Nancy VanWormer (1995)'),
#  ('C:\\Users\\sumit/stories//fea2',
#   'Waterlogged Klingons by L. Shawn Aiken (1994)'),
#  ('C:\\Users\\sumit/stories//fea3', 'Survey Results, by Joe DeRouen (1994)'),
#  ('C:\\Users\\sumit/stories//fear.hum', 'Fear of Growing Old'),
#  ('C:\\Users\\sumit/stories//fearmnky',
#   'Fear and the Monkey (A Ouija Board Poem) by William S. Burroughs (1984)'),
#  ('C:\\Users\\sumit/stories//fgoose.txt', 'A List of Father Good Stories'),
#  ('C:\\Users\\sumit/stories//fic1',
#   'Beacons of Light, by L. Shawn Aiken (1995)'),
#  ('C:\\Users\\sumit/stories//fic2', 'Experiment, by Ed Davis (1993)'),
#  ('C:\\Users\\sumit/stories//fic3', 'Ouija Warning, by Ed Davis (1993)'),
#  ('C:\\Users\\sumit/stories//fic4',
#   'A Close Encounter of a Different Kind, by Sylvia L. Ramsey (1993)'),
#  ('C:\\Users\\sumit/stories//fic5', 'The Imp, by Ed Davis (1993)'),
#  ('C:\\Users\\sumit/stories//fic7',
#   'A Chance Meeting in the Park, by Joe DeRouen'),
#  ('C:\\Users\\sumit/stories//fish.txt',
#   'Once There Was a Fish by Doug Rosentrater'),
#  ('C:\\Users\\sumit/stories//fleas.txt',
#   'Fleas: A Story, by Adam Poszar (1991)'),
#  ('C:\\Users\\sumit/stories//flktrp.txt',
#   'Flak Trap (Story) by Brendan Meara (Juanry 18, 1995)'),
#  ('C:\\Users\\sumit/stories//floc', 'Matriarchal Shepherd by Marc Edwards'),
#  ('C:\\Users\\sumit/stories//floobs.txt',
#   'The Cube of Shalube...By Dr. Muess (June 24, 1989)'),
#  ('C:\\Users\\sumit/stories//flute.txt',
#   'The Spirit and the Flute (How Flutes Relate to History)'),
#  ('C:\\Users\\sumit/stories//flytrunk.txt', 'The Story of the Flying Trunk'),
#  ('C:\\Users\\sumit/stories//forgotte', 'Forgotten Souls by CAC/The Stinker'),
#  ('C:\\Users\\sumit/stories//fourth.fic',
#   'Another Fourth of July, by Jeff Epstein'),
#  ('C:\\Users\\sumit/stories//fowl.death',
#   'Fowl Death by Nuclear Deth (April 7, 1987)'),
#  ('C:\\Users\\sumit/stories//foxncrow.txt',
#   'The Story of the Fox and the Crow'),
#  ('C:\\Users\\sumit/stories//foxngrap.txt',
#   'The Story of the Fox and the Grapes'),
#  ('C:\\Users\\sumit/stories//foxnstrk.txt',
#   'The Story of the Fox and the Stork'),
#  ('C:\\Users\\sumit/stories//fran',
#   'Cheese or These? By Francis U. Kaltenbaugh'),
#  ('C:\\Users\\sumit/stories//fred.txt', 'The Story of Fred.'),
#  ('C:\\Users\\sumit/stories//freeman.fil',
#   'The Last Free Man, by Francis W. Porretto'),
#  ('C:\\Users\\sumit/stories//friend.s', "Man's Best Friend, by Marty Weiss"),
#  ('C:\\Users\\sumit/stories//friends.txt', 'Friends: A Story'),
#  ('C:\\Users\\sumit/stories//frogp.txt',
#   'The Story of the Frog Prince, by Andrew Varga'),
#  ('C:\\Users\\sumit/stories//frum',
#   'The Story of Ronald Frump, by Dave Bealer'),
#  ('C:\\Users\\sumit/stories//game.txt', 'The Game, by Suki'),
#  ('C:\\Users\\sumit/stories//gatherng.txt',
#   'Collection of Poetry by David Fox (1990)'),
#  ('C:\\Users\\sumit/stories//gay',
#   'A Collection of Poetry by Gay Bost (1994)'),
#  ('C:\\Users\\sumit/stories//gemdra.txt', 'The Story of the Dragons of Gems'),
#  ('C:\\Users\\sumit/stories//ghost', 'Time for Flowers, by Gay Bost'),
#  ('C:\\Users\\sumit/stories//girl', 'Dream Girl by Melina Huddy'),
#  ('C:\\Users\\sumit/stories//girlclub.txt',
#   'The Girl of the Month Club by Colin Campbell'),
#  ('C:\\Users\\sumit/stories//glimpse1.txt',
#   'A Glimpse Into My Mind at 12:45pm, by Sean M. Gomez (1993)'),
#  ('C:\\Users\\sumit/stories//gloves.txt',
#   'Oops! There was a little messup with the christmas gift!'),
#  ('C:\\Users\\sumit/stories//gold3ber.txt',
#   'The Story of Goldilocks and the Three Bears'),
#  ('C:\\Users\\sumit/stories//goldbug.poe', 'The Gold Bug, by Poe'),
#  ('C:\\Users\\sumit/stories//goldenp.txt',
#   'The Adventure of the Golden Pince-Nez'),
#  ('C:\\Users\\sumit/stories//goldfish.txt', 'The Little Gold Fish'),
#  ('C:\\Users\\sumit/stories//goldgoos.txt', 'The Tale of the Golden Goose'),
#  ('C:\\Users\\sumit/stories//grav', 'Memory Cemetery, by Gay Bost'),
#  ('C:\\Users\\sumit/stories//graymare.txt',
#   'Nightmare in Grey by Fredric Brown'),
#  ('C:\\Users\\sumit/stories//greatlrn.leg',
#   'The Great Learning: The Text of Confucious'),
#  ('C:\\Users\\sumit/stories//greedog.txt', 'The Parable of the Greedy Dog'),
#  ('C:\\Users\\sumit/stories//gulliver.txt',
#   "Gulliver's Travels, by Johnathan Swift (1726)"),
#  ('C:\\Users\\sumit/stories//hansgrtl.txt', 'The Fable of Hansel and Gretel'),
#  ('C:\\Users\\sumit/stories//hareleph.txt',
#   'The Fable of the Hare and the Elephant'),
#  ('C:\\Users\\sumit/stories//hareporc.txt',
#   'The Fable of the Hare and the Porcupine'),
#  ('C:\\Users\\sumit/stories//haretort.txt',
#   'The Fable of the Hare and the Tortoise'),
#  ('C:\\Users\\sumit/stories//healer.txt',
#   'The Soul Healer: A Story by Ben Blumenberg'),
#  ('C:\\Users\\sumit/stories//hell4.txt',
#   'Donatien Alphonse Francois de Sade (A Story)'),
#  ('C:\\Users\\sumit/stories//hellmach.txt',
#   'The Hell Machine, by James C. Lynn (1990)'),
#  ('C:\\Users\\sumit/stories//helmfuse.txt',
#   'Ashtray and Gherkin (Helmet Fusion Specialists)'),
#  ('C:\\Users\\sumit/stories//hils',
#   'The Hills of Commerce, by Marilyn Hutchings'),
#  ('C:\\Users\\sumit/stories//history5.txt', 'The Slopes of Te Aroha'),
#  ('C:\\Users\\sumit/stories//hitch2.txt',
#   'Complete Transcription of Douglas Adams\' "Restaurant at the End of the Universe"'),
#  ('C:\\Users\\sumit/stories//hitch3.txt',
#   'Complete Transcription of Douglas Adams\' "Life, the Universe and Everything"'),
#  ('C:\\Users\\sumit/stories//hole2nar.txt', 'The Hole THat Was Too Narrow'),
#  ('C:\\Users\\sumit/stories//holmesbk.txt',
#   'The Holmes List: A List of Books That Reference or Discuss Sherlock Holmes'),
#  ('C:\\Users\\sumit/stories//home.fil',
#   'The Homecoming, by Francis W. Porretto of Horse Feathers BBS'),
#  ('C:\\Users\\sumit/stories//hop-frog.poe', 'The Story of Hop Frog'),
#  ('C:\\Users\\sumit/stories//horsdonk.txt', 'The Horse and the Donkey'),
#  ('C:\\Users\\sumit/stories//horswolf.txt', 'The Horse and the Wolf'),
#  ('C:\\Users\\sumit/stories//hotline1.txt', 'Hotline! by James Zachary'),
#  ('C:\\Users\\sumit/stories//hotline3.txt',
#   'Hotline! Part III, by James Zachary'),
#  ('C:\\Users\\sumit/stories//hotline4.txt',
#   'Hotline! Part IV, by James Zachary'),
#  ('C:\\Users\\sumit/stories//hound-b.txt',
#   'The Hound of the Baskervilles, by Sir Arthur Conan Doyle'),
#  ('C:\\Users\\sumit/stories//how.ernie.bert',
#   'how Ernie and Bert Came to Be by 11th Hour Productions'),
#  ('C:\\Users\\sumit/stories//idi.hum', 'The First Adventures of IDI'),
#  ('C:\\Users\\sumit/stories//igiv', 'I Give Up, by Thomas Nevin Huber'),
#  ('C:\\Users\\sumit/stories//imagin.hum', 'Just Imagine: A Story'),
#  ('C:\\Users\\sumit/stories//immortal', 'Immortality by William S. Burroughs'),
#  ('C:\\Users\\sumit/stories//immorti.hum', 'Immorti, by Todd Rich'),
#  ('C:\\Users\\sumit/stories//imonly17.txt',
#   "Please, God, I'm Only 17... by the Elite Executives"),
#  ('C:\\Users\\sumit/stories//inter', 'Submerged Interface, by Gay Bost'),
#  ('C:\\Users\\sumit/stories//island.poe', 'The Island of the Fay'),
#  ('C:\\Users\\sumit/stories//jackbstl.txt',
#   'The Story of Jack and the Beanstalk'),
#  ('C:\\Users\\sumit/stories//jackmac.fic',
#   "Jackmac's Discovery by Jeff Epstein"),
#  ('C:\\Users\\sumit/stories//jaynejob.asc', 'Be a Clerk All My Life? Not Me!'),
#  ('C:\\Users\\sumit/stories//jerichms.hum',
#   'Bricks In The Wall, by M.D. Roccatani'),
#  ('C:\\Users\\sumit/stories//jim.asc', 'The Book of Jim'),
#  ('C:\\Users\\sumit/stories//keeping.insanit',
#   'Keeping Insanity in the Closet, by The Weatherman (April 13th, 1988)'),
#  ('C:\\Users\\sumit/stories//keepmodu.txt',
#   'Odnaar Keep by David M. Millstein'),
#  ('C:\\Users\\sumit/stories//kharian.txt', 'The Legends of the Kharianians'),
#  ('C:\\Users\\sumit/stories//kneeslapper',
#   'Kneeslapper by Slafathor (July 23, 1991)'),
#  ('C:\\Users\\sumit/stories//kneeslapper.txt',
#   'Kneeslapper by Slagathor (July 23, 1991)'),
#  ('C:\\Users\\sumit/stories//knuckle.txt', 'The Story of Knucklebones'),
#  ('C:\\Users\\sumit/stories//korea.s', 'The Furry Orphan of War'),
#  ('C:\\Users\\sumit/stories//kzap.txt', "KZAP's Psychedelic Sunday"),
#  ('C:\\Users\\sumit/stories//ladylust.hum',
#   "I have no idea where this came from or where it's going."),
#  ('C:\\Users\\sumit/stories//lament.txt', "Offender E477439's Lament"),
#  ('C:\\Users\\sumit/stories//lgoldbrd.txt',
#   'The Fable of the Little Golden Bird'),
#  ('C:\\Users\\sumit/stories//life.txt', 'Notes towards a story'),
#  ('C:\\Users\\sumit/stories//lil', 'A Letter to Lillian by Gay Bost'),
#  ('C:\\Users\\sumit/stories//lionbird', 'Lionbirds, by MArtin R. Crim (1994)'),
#  ('C:\\Users\\sumit/stories//lionmane.txt',
#   "The Adventure of the Lion's Mane"),
#  ('C:\\Users\\sumit/stories//lionmosq.txt',
#   'The Fable of the Lion and the Mosquito'),
#  ('C:\\Users\\sumit/stories//lionwar.txt', 'The Lion Goes to War (Fable)'),
#  ('C:\\Users\\sumit/stories//lmermaid.txt', 'The Fable of the Little Mermaid'),
#  ('C:\\Users\\sumit/stories//lmtchgrl.txt', 'The Little Matchgirl'),
#  ('C:\\Users\\sumit/stories//long1-3.txt',
#   'The Longest Distance by D.W. Boynton (1992)'),
#  ('C:\\Users\\sumit/stories//lpeargrl.txt', 'The Little Pear Girl: A Story'),
#  ('C:\\Users\\sumit/stories//lrrhood.txt',
#   'The Story of Little Red Riding Hood'),
#  ('C:\\Users\\sumit/stories//ltp',
#   'Liberty Tree Pub: Her Honour, by D. M. Hanna'),
#  ('C:\\Users\\sumit/stories//luf', 'Luffing, by Ron Fleshman'),
#  ('C:\\Users\\sumit/stories//lure.txt',
#   'The Lure of the Temptress (Soft Documentation)'),
#  ('C:\\Users\\sumit/stories//mario.txt',
#   'MARIO, by Archer Blue: A Short History of Mario'),
#  ('C:\\Users\\sumit/stories//mattress.txt',
#   'Once Upon a Mattress, by Nikolai Kingsley, 1995'),
#  ('C:\\Users\\sumit/stories//mazarin.txt',
#   'The Adventure of the Mazarin Stone'),
#  ('C:\\Users\\sumit/stories//mcdonaldl.txt',
#   'A Day in McDonaldland by G.I. Joe (June 10, 1986)'),
#  ('C:\\Users\\sumit/stories//melissa.txt', 'Melissa and the Green Dragon'),
#  ('C:\\Users\\sumit/stories//mike.txt', 'An Ode to Mike, by Alien'),
#  ('C:\\Users\\sumit/stories//mindprob.txt', 'Mind Probe, by Michael Abbot'),
#  ('C:\\Users\\sumit/stories//mindwar', 'Mind War by William S. Burroughs'),
#  ('C:\\Users\\sumit/stories//missing.txt',
#   'The Adventure of the Missing Three-Quarter (A story)'),
#  ('C:\\Users\\sumit/stories//modemhippy.txt',
#   'Modem Hippy: A Poem by Morpheous of LOM'),
#  ('C:\\Users\\sumit/stories//monkking.txt', 'The Story of the Monkey King'),
#  ('C:\\Users\\sumit/stories//monksol.txt',
#   'The Secret of Monkey Island Unvield by SYNDICATE'),
#  ('C:\\Users\\sumit/stories//mouslion.txt',
#   'The Story of the Mouse and the Lion'),
#  ('C:\\Users\\sumit/stories//mtinder.txt', 'The Story of the Magic Tinderbox'),
#  ('C:\\Users\\sumit/stories//musgrave.txt', 'The Musgrave Ritual (Story)'),
#  ('C:\\Users\\sumit/stories//musibrem.txt', 'The Musicians of Bremen'),
#  ('C:\\Users\\sumit/stories//mydream.txt',
#   'Someone Talks About Some Weird Dreams He Has'),
#  ('C:\\Users\\sumit/stories//myeyes', 'Poem: Through My Eyes'),
#  ('C:\\Users\\sumit/stories//narciss.txt', 'The Story of Narcissus'),
#  ('C:\\Users\\sumit/stories//nigel.1', 'The Saga of Nigel the Hedgehog'),
#  ('C:\\Users\\sumit/stories//nigel.10',
#   'The Saga of Nigel the Hedgehog 10 (July 6, 1989)'),
#  ('C:\\Users\\sumit/stories//nigel.2',
#   'The Saga of Nigel the Hedgehog 2 (May 25, 1989)'),
#  ('C:\\Users\\sumit/stories//nigel.3',
#   'The Saga of Nigel the Hedgehog 3 (June 2, 1989)'),
#  ('C:\\Users\\sumit/stories//nigel.4',
#   'The Saga of Nigel the Hedgehog 4 (June 2, 1989)'),
#  ('C:\\Users\\sumit/stories//nigel.5',
#   'The Saga of Nigel the Hedgehog 5 (June 12, 1989)'),
#  ('C:\\Users\\sumit/stories//nigel.6',
#   'The Saga of Nigel the Hedgehog 6 (June 12, 1989)'),
#  ('C:\\Users\\sumit/stories//nigel.7',
#   'The Saga of Nigel the Hedgehog 7 (june 17, 1989)'),
#  ('C:\\Users\\sumit/stories//nihgel_8.9',
#   'The Saga of Nigel the Hedgehog 8 and 9'),
#  ('C:\\Users\\sumit/stories//nitepeek.sto',
#   '"Peek in the Night" by Night Words'),
#  ('C:\\Users\\sumit/stories//non2', 'Musings by Joe DeRouen (1993)'),
#  ('C:\\Users\\sumit/stories//non3',
#   'If I Had One Wish... by L.J. Herbert (1993)'),
#  ('C:\\Users\\sumit/stories//non4',
#   'A Panacea for Cheezy Movies by L. Shawn Aiken'),
#  ('C:\\Users\\sumit/stories//obstgoat.txt', 'The Tale of the Obstinate Goats'),
#  ('C:\\Users\\sumit/stories//omarsheh.txt',
#   'The Fable of Prince Omar and Princess Sheherazade'),
#  ('C:\\Users\\sumit/stories//outcast.dos',
#   'The Outcast, by Winwood Reade, 1933'),
#  ('C:\\Users\\sumit/stories//oxfrog.txt', 'The Fable of the Ox and the Frog'),
#  ('C:\\Users\\sumit/stories//paink-ws.txt', 'Painkiller, by William Slattery'),
#  ('C:\\Users\\sumit/stories//panama.txt',
#   'An Author Argues with his Main Character'),
#  ('C:\\Users\\sumit/stories//parotsha.txt', 'The Story of the Parrot Shah'),
#  ('C:\\Users\\sumit/stories//partya.txt',
#   'What happened on the Friday last October'),
#  ('C:\\Users\\sumit/stories//paul_har.sto',
#   "Paul Harvey's List of True Real Stories"),
#  ('C:\\Users\\sumit/stories//peace.fun', 'Vision of Peace on Earth'),
#  ('C:\\Users\\sumit/stories//pepdegener.txt',
#   'Pepsi Degeneration by Morpheous of LOM'),
#  ('C:\\Users\\sumit/stories//pepsi.degenerat',
#   'Pepsi Degeneration by Morpheous of LOM'),
#  ('C:\\Users\\sumit/stories//perf', 'Picture Perfect, by Roberta Belinda'),
#  ('C:\\Users\\sumit/stories//pinocch.txt', 'The Story of Pinocchio'),
#  ('C:\\Users\\sumit/stories//piracy.sto', 'Arrr! The Pirates have arrived!'),
#  ('C:\\Users\\sumit/stories//plescopm.txt', 'Asleep by Craig Plesco'),
#  ('C:\\Users\\sumit/stories//poem-1.txt',
#   'Poetry: A Song of Love (October 25, 1993)'),
#  ('C:\\Users\\sumit/stories//poem-2.txt',
#   'Poetry: Broken Heats, by Kylis Noren (October 19, 1993)'),
#  ('C:\\Users\\sumit/stories//poem-4.txt',
#   'Poetry: "An Ode to Death" - By Us! (October 19, 1993)'),
#  ('C:\\Users\\sumit/stories//poplstrm.txt',
#   'The Fable of the Poplar and the Stream'),
#  ('C:\\Users\\sumit/stories//pphamlin.txt', 'The Pied Piper of Hamelin'),
#  ('C:\\Users\\sumit/stories//pregn.txt', 'Pregnant Pause by Dorothy Lindman'),
#  ('C:\\Users\\sumit/stories//prince.art',
#   'The Princess vs. the Principal, by Marc Perkel'),
#  ('C:\\Users\\sumit/stories//progx', 'Programmer X, by Greg Borek'),
#  ('C:\\Users\\sumit/stories//psf.txt', 'The Peasant, the Snake, and the Fox'),
#  ('C:\\Users\\sumit/stories//psi', 'Psicop, by Jack Hillman'),
#  ('C:\\Users\\sumit/stories//psyc',
#   'Psyche and Cupid: A Theory, by Dr. Harold Levdahed'),
#  ('C:\\Users\\sumit/stories//pussboot.txt', 'The Story of Puss in Boots'),
#  ('C:\\Users\\sumit/stories//qcarroll', 'How Sailor Ted Got Out of It'),
#  ('C:\\Users\\sumit/stories//quarter.c1',
#   'The Plan, by Shannon Carraher (Part 1)'),
#  ('C:\\Users\\sumit/stories//quarter.c10',
#   'Tea Time with the Devil, by Brant Swancer'),
#  ('C:\\Users\\sumit/stories//quarter.c11',
#   'I Spoke with the Sun, by Caroline Kennedy (And Other Poems)'),
#  ('C:\\Users\\sumit/stories//quarter.c12',
#   'Welcome to the Planet of Kampf, by Jim Zachary'),
#  ('C:\\Users\\sumit/stories//quarter.c13', 'The Mission, by Jon Lang'),
#  ('C:\\Users\\sumit/stories//quarter.c14', 'Leftover Stew, by Patrick Barnes'),
#  ('C:\\Users\\sumit/stories//quarter.c15',
#   'My Father and Me, by Mike Russello'),
#  ('C:\\Users\\sumit/stories//quarter.c16',
#   'Under the Weeping Willow Tree, by Patrick Miner'),
#  ('C:\\Users\\sumit/stories//quarter.c17', 'Blind Fate, by Toby Bradley'),
#  ('C:\\Users\\sumit/stories//quarter.c18', 'Bearing Down, by John Dudley'),
#  ('C:\\Users\\sumit/stories//quarter.c19', 'Hometown Ways, by Amy Slavin'),
#  ('C:\\Users\\sumit/stories//quarter.c2', 'Remembering, by Kristin Feyen'),
#  ('C:\\Users\\sumit/stories//quarter.c3', 'The Quarantine, by Moses Domingo'),
#  ('C:\\Users\\sumit/stories//quarter.c4',
#   'A Savage Projectile, by Steve Gaines'),
#  ('C:\\Users\\sumit/stories//quarter.c5', 'Peel Me Away, by Bill DeClercq'),
#  ('C:\\Users\\sumit/stories//quarter.c6',
#   'Little White Lines, by Joe Raymundo'),
#  ('C:\\Users\\sumit/stories//quarter.c7', 'At Midnight, by Karin Johnson'),
#  ('C:\\Users\\sumit/stories//quarter.c8',
#   'The Singer in the Depths by Steven Myers'),
#  ('C:\\Users\\sumit/stories//quarter.c9', 'The Rose, by Suzy Edmonson'),
#  ('C:\\Users\\sumit/stories//quest',
#   'The Quest for Axe of the Dwarven Lords by Bruce RW. Reisman'),
#  ('C:\\Users\\sumit/stories//quickfix', 'Quick Fix, by William S. Burroughs'),
#  ('C:\\Users\\sumit/stories//quot',
#   'A Collection of Quotes by Poets about Poetry'),
#  ('C:\\Users\\sumit/stories//radar_ra.txt',
#   'Interview with the Radar Ranger: A Work of Fiction by D. Railleur'),
#  ('C:\\Users\\sumit/stories//rainda.txt',
#   'Rain Dance (Mechwarrior Fan Fiction) by Douglas M. Warren'),
#  ('C:\\Users\\sumit/stories//reality.txt',
#   'The Reality of Our Situation by Kortron'),
#  ('C:\\Users\\sumit/stories//reap', 'The Reaper, by Gay Bost'),
#  ('C:\\Users\\sumit/stories//redragon.txt', 'The Fable of the Red Dragon'),
#  ('C:\\Users\\sumit/stories//retrib.txt',
#   'Retribution by Andrew Varga (1991)'),
#  ('C:\\Users\\sumit/stories//rid.txt', 'Getting Rid of the Riddler, by Alien'),
#  ('C:\\Users\\sumit/stories//robotech',
#   'Book Excerpt: Protoculture and the Children of the Shadow (Robotech)'),
#  ('C:\\Users\\sumit/stories//rock', 'Rock, by D.M. Hanna'),
#  ('C:\\Users\\sumit/stories//rocket.sf',
#   'The Space Saga of "Rocket" Roger Robinson (Story)'),
#  ('C:\\Users\\sumit/stories//roger1.txt', 'In Residence by KaRylin'),
#  ('C:\\Users\\sumit/stories//running.txt', 'Story: Running'),
#  ('C:\\Users\\sumit/stories//s&m_plot',
#   "The Plot Thickens: A Writer's Dream, by Cecilio Morales"),
#  ('C:\\Users\\sumit/stories//s&m_that',
#   "John's Diner: Who Was The Guy? By Lucia Chambers"),
#  ('C:\\Users\\sumit/stories//safe',
#   'Safe Place: A Synopsis, by Michael C. McPherson'),
#  ('C:\\Users\\sumit/stories//sanpedr2.txt',
#   'The Fruit of the Gods: Trichoserus Pachanoi'),
#  ('C:\\Users\\sumit/stories//shoscomb.txt',
#   'The Adventure of Shoscombe Old Place'),
#  ('C:\\Users\\sumit/stories//shrdfarm.txt', "A Shrewd Farmer's Story (Fable)"),
#  ('C:\\Users\\sumit/stories//shulk.txt',
#   'The Fable of the Hunter and the Hunted'),
#  ('C:\\Users\\sumit/stories//sick-kid.txt',
#   'The Sick Kids: Story by Roger M. Wilcox'),
#  ('C:\\Users\\sumit/stories//sight.txt', 'Story about Jamie, badly formatted'),
#  ('C:\\Users\\sumit/stories//silverb.txt', 'Silver Blaze (Story)'),
#  ('C:\\Users\\sumit/stories//sis', 'Sister Mary Agnes by Gay Bost'),
#  ('C:\\Users\\sumit/stories//sleprncs.txt', 'The Sleeping Princess (Fable)'),
#  ('C:\\Users\\sumit/stories//snow.txt',
#   'Story about Ed, again badly formatted'),
#  ('C:\\Users\\sumit/stories//snowmaid.txt', 'The Fable of the Snow Maiden'),
#  ('C:\\Users\\sumit/stories//snowqn1.txt', 'The Fable of the Snow Queen'),
#  ('C:\\Users\\sumit/stories//social.vikings',
#   'Social Vikings by Flat Tire (August 5, 1988)'),
#  ('C:\\Users\\sumit/stories//socialvikings.txt',
#   'Social Vikings by The Flat Tire (August, 1988)'),
#  ('C:\\Users\\sumit/stories//solitary.txt',
#   'The Adventure of the Solitary Cyclist'),
#  ('C:\\Users\\sumit/stories//space.txt', 'Space Travel by Adam Poszar (1990)'),
#  ('C:\\Users\\sumit/stories//spam.key',
#   'The Key and I, or, My Travels in the Sky, and What I Found There, by Padre Martini, Archdukebishop of West Texas'),
#  ('C:\\Users\\sumit/stories//spectacl.poe',
#   'The Spectacles, by Edgar Allen Poe'),
#  ('C:\\Users\\sumit/stories//spider.txt',
#   "The World's Fastest Spider, by Andrew Varga (1991)"),
#  ('C:\\Users\\sumit/stories//spiders.txt', 'Story about Harvey and Spiders'),
#  ('C:\\Users\\sumit/stories//sqzply.txt',
#   'Squeeze Play, by Michael A. Stackpole (1989)'),
#  ('C:\\Users\\sumit/stories//sre-dark.txt',
#   "SRE's Darker Half, by Chris Trendle, Paul Gerth and Robert Chapman"),
#  ('C:\\Users\\sumit/stories//stainles.ana',
#   'A Cool 3.7 Million, by The Stainless Steal Rat'),
#  ('C:\\Users\\sumit/stories//stairdre.txt',
#   'The Stiarway Dram, by Satinka Istari'),
#  ('C:\\Users\\sumit/stories//startrek.txt', 'Startrek, The Ultimate Story!'),
#  ('C:\\Users\\sumit/stories//stsgreek',
#   "It's All Greek to uncle Thaddeus, by Joe DeRouen (1993)"),
#  ('C:\\Users\\sumit/stories//sucker.txt',
#   'The Dark Sucker, by Quantum Mechanic'),
#  ('C:\\Users\\sumit/stories//sunday.txt',
#   'Sunday, by Nanci (February 20, 1993)'),
#  ('C:\\Users\\sumit/stories//superg1', 'The Story of SUPERGUY!!'),
#  ('C:\\Users\\sumit/stories//szechuan', 'The Szechuan Taxi, by Dave Bealer'),
#  ('C:\\Users\\sumit/stories//t_zone.jok',
#   'Story: Mission Impossible Meets the Twilight Zone'),
#  ('C:\\Users\\sumit/stories//tailbear.txt', 'The Tail of the Bear: A Fable'),
#  ('C:\\Users\\sumit/stories//tao3.dos',
#   'The Tao Te Ching, translated by James Legge'),
#  ('C:\\Users\\sumit/stories//taxnovel.txt',
#   'Back Taxes, a Novel by Paul Mahler (1991-1992)'),
#  ('C:\\Users\\sumit/stories//tcoa.txt',
#   'The Cask of Amontilado, by Edgar Allan Poe'),
#  ('C:\\Users\\sumit/stories//tctac.txt',
#   'The Cockroach that Ate Cincinatti (Poem)'),
#  ('C:\\Users\\sumit/stories//tearglas.txt',
#   'Tears of Glass by Kimberly Ann Carter (1992)'),
#  ('C:\\Users\\sumit/stories//telefone.txt', 'The Telephone Rape Story'),
#  ('C:\\Users\\sumit/stories//terrorbears.txt',
#   'The Terror Bears on the Rampage by Darkside 414'),
#  ('C:\\Users\\sumit/stories//testpilo.hum',
#   'Test Pilot, Story by John Vornholt'),
#  ('C:\\Users\\sumit/stories//textfile.primer',
#   "The Ramsacker's Textfile Primer by The Ramsacker of Pieces of Eight (July 27, 1989)"),
#  ('C:\\Users\\sumit/stories//thanksg',
#   'A Thanksgiving Prayer, by William S. Burroughs'),
#  ('C:\\Users\\sumit/stories//the-tree.txt', 'The Tree: A Poem'),
#  ('C:\\Users\\sumit/stories//thewave',
#   'The Navajo and the Bhuddist (October 19, 1992)'),
#  ('C:\\Users\\sumit/stories//timem.hac',
#   'The Time Machine, by H.G. Wells (1898)'),
#  ('C:\\Users\\sumit/stories//times.fic',
#   'Times Doubles Defect; Publisher Possibly Plinked by Jean Blevins'),
#  ('C:\\Users\\sumit/stories//timetrav.txt',
#   'The Problem with Time Travel (Story)'),
#  ('C:\\Users\\sumit/stories//tin', 'Tinned Warmth by Gordon Chapman'),
#  ('C:\\Users\\sumit/stories//tinsoldr.txt', 'The Tin Soldier (Story)'),
#  ('C:\\Users\\sumit/stories//toilet.s',
#   'My Toilet, my Kingdom, by Bill Luby (1994)'),
#  ('C:\\Users\\sumit/stories//traitor.txt',
#   'Treason, by Marcus Tullius Cicero'),
#  ('C:\\Users\\sumit/stories//tree.txt', 'Kevin and the Tree'),
#  ('C:\\Users\\sumit/stories//tuc_mees',
#   'The Ed Meese Commission presents Pornography Masquerading as Literature, by Tess Truehard and Gurn Blanston'),
#  ('C:\\Users\\sumit/stories//uglyduck.txt', 'The Fable of the Ugly Duckling'),
#  ('C:\\Users\\sumit/stories//unluckwr.txt',
#   'The Fable of the Unlucky Warrior'),
#  ('C:\\Users\\sumit/stories//vaincrow.txt', 'The Parable of the Vain Crow'),
#  ('C:\\Users\\sumit/stories//vainsong.txt',
#   'A Manly Wager, a Song by Lucillus'),
#  ('C:\\Users\\sumit/stories//valen', 'Valentine, Story by George Willard'),
#  ('C:\\Users\\sumit/stories//vampword.txt', "A Vampyre's Words: Poem"),
#  ('C:\\Users\\sumit/stories//vday.hum',
#   "The Valentine's Day Blues, by B.A. Nilsson"),
#  ('C:\\Users\\sumit/stories//veiledl.txt',
#   'The Adventure of the Veiled Lodger'),
#  ('C:\\Users\\sumit/stories//vgilante.txt', 'The Vigilante'),
#  ('C:\\Users\\sumit/stories//wall.art',
#   'The Wall, from Karl L. Sandwell-Weiss'),
#  ('C:\\Users\\sumit/stories//wanderer.fun',
#   'Poem by David Redish, The Wanderer'),
#  ('C:\\Users\\sumit/stories//weaver.txt', 'Infromation about Spellweavers'),
#  ('C:\\Users\\sumit/stories//weeprncs.txt', 'The Weeping Princess'),
#  ('C:\\Users\\sumit/stories//whgdsreg.reg',
#   'Introduction to the Neolithic Great Goddess, by Ben Blumenberg (February 12, 1992)'),
#  ('C:\\Users\\sumit/stories//wisteria.txt', 'The Adventure of Wisteria Lodge'),
#  ('C:\\Users\\sumit/stories//withdraw.cyb',
#   'My Living Semi-Hell Type Experience Thing, by Urethris, 1992'),
#  ('C:\\Users\\sumit/stories//wlgirl.txt', 'The Story of the Wise Little Girl'),
#  ('C:\\Users\\sumit/stories//wolf7kid.txt', 'The Wolf and the Seven Kids'),
#  ('C:\\Users\\sumit/stories//wolfcran.txt', 'The Wolf and the Crane'),
#  ('C:\\Users\\sumit/stories//wolflamb.txt', 'The Wolf and the Lamb'),
#  ('C:\\Users\\sumit/stories//wombat.und',
#   'The Story of the Wombat, from Floyd Gecko'),
#  ('C:\\Users\\sumit/stories//write',
#   'The Three Golden Rules of Poetry by Michael Howard'),
#  ('C:\\Users\\sumit/stories//wrt', 'The Writer by Thomas Nevin Huber'),
#  ('C:\\Users\\sumit/stories//yukon.txt',
#   'The Spell of the Yukon and Other Verses by Robert W. Service'),
#  ('C:\\Users\\sumit/stories//zombies.txt',
#   'Zombies by Suzanne L. McAllister (Spoof/Tribute of George Romero Living Dead Movies)'),
#  ('C:\\Users\\sumit/stories/SRE/sre01.txt',
#   'SRE: The Saga Of The Best SRE Game Ever Played! By Josh Renaud'),
#  ('C:\\Users\\sumit/stories/SRE/sre02.txt',
#   'Solar Realms Elite: The True Story of the Unsung Heroes, by Josh Renaud'),
#  ('C:\\Users\\sumit/stories/SRE/sre03.txt',
#   "Solar Realms Elite: Ultra's Untold Story by Josh Renaud"),
#  ('C:\\Users\\sumit/stories/SRE/sre04.txt',
#   'Solar Realms Elite IV: The Confrontation, by Josh Renaud'),
#  ('C:\\Users\\sumit/stories/SRE/sre05.txt',
#   'Solar Realms Elite V: The Underground, by Josh Renaud'),
#  ('C:\\Users\\sumit/stories/SRE/sre06.txt',
#   'Solar Realms Elite VI: The Alliance Restored, by Josh Renaud'),
#  ('C:\\Users\\sumit/stories/SRE/sre07.txt',
#   'Solar Realms Elite 7: Petros, by Josh Renaud'),
#  ('C:\\Users\\sumit/stories/SRE/sre08.txt',
#   'Solar Realms Elite VIII: Kazik, by Josh Renaud'),
#  ('C:\\Users\\sumit/stories/SRE/sre09.txt',
#   'Solar Realms Elite IX: Survival of the Fittest, by Josh Renaud'),
#  ('C:\\Users\\sumit/stories/SRE/sre10.txt',
#   'Solar Realms Elite X: Legacies, by Josh Renaud'),
#  ('C:\\Users\\sumit/stories/SRE/sre_feqh.txt',
#   'Solar Realms Elite: The Feqh Galaxy, by Josh Renaud'),
#  ('C:\\Users\\sumit/stories/SRE/sre_finl.txt',
#   'Solar Realms Elite: The Finale by Josh Renaud'),
#  ('C:\\Users\\sumit/stories/SRE/sre_sei.txt',
#   'Solar Realms Elite: Galaxy Sei, by Josh Renaud'),
#  ('C:\\Users\\sumit/stories/SRE/sretrade.txt',
#   'The SRE Commerce and Trade Theories, by Josh Renaud'),
#  ('C:\\Users\\sumit/stories/SRE/srex.txt',
#   'Solar Realms Elite: X1 and X2, by Josh Renaud')]

# %%
# Calculate the length of the dataset
len(dataset)
# Out:
# 467

# %%
N = len (dataset)

# %%
def convert_lower_case(data):
    return np.char.lower(data)

# %%
def remove_stop_words(data):
    stop_words = stopwords.words('english')
    words = word_tokenize(str(data))
    new_text = ""
    for w in words:
        if w not in stop_words and len(w) > 1:
            new_text = new_text + " " + w
    return new_text

# %%
def remove_punctuation(data):
    symbols = "!\"#$%&()*+-./:;<=>?@[\]^_`{|}~\n"
    for i in range(len(symbols)):
        data = np.char.replace(data, symbols[i], ' ')
        data = np.char.replace(data, "  ", " ")
    data = np.char.replace(data, ',', '')
    return data

# %%
def remove_apostrophe(data):
    return np.char.replace(data, "'", "")

# %%
def stemming(data):
    stemmer= PorterStemmer()
    
    tokens = word_tokenize(str(data))
    new_text = ""
    for w in tokens:
        new_text = new_text + " " + stemmer.stem(w)
    return new_text

# %%
def convert_numbers(data):
    tokens = word_tokenize(str(data))
    new_text = ""
    for w in tokens:
        try:
            w = num2words(int(w))
        except:
            a = 0
        new_text = new_text + " " + w
    new_text = np.char.replace(new_text, "-", " ")
    return new_text

# %%
# The process of converting data to something a computer can understand is referred to as pre-processing.
# Preprocessing

def preprocess(data):
    data = convert_lower_case(data)
    data = remove_stop_words(data)
    data = remove_punctuation(data) #remove comma seperately
    data = remove_apostrophe(data)
    data = stemming(data)
    data = convert_numbers(data)
    return data

# %%
# Extracting Data
processed_text = []
processed_title = []

for i in dataset[:N]:
    file = open(i[0], 'r', encoding="utf8", errors='ignore')
    text = file.read().strip()
    file.close()

    processed_text.append(word_tokenize(str(preprocess(text))))
    processed_title.append(word_tokenize(str(preprocess(i[1]))))

# %%
# Calculating DF for all words
DF = {}

for i in range(N):
    tokens = processed_text[i]
    for w in tokens:
        try:
            DF[w].add(i)
        except:
            DF[w] = {i}

    tokens = processed_title[i]
    for w in tokens:
        try:
            DF[w].add(i)
        except:
            DF[w] = {i}
for i in DF:
    DF[i] = len(DF[i])

# %%
len(DF)
# Out:
# 32533

# %%
# DF
total_vocab_size = len(DF)

# %%
total_vocab_size
# Out:
# 32533

# %%
# List comprehensions provide a concise way to create lists.
# For More details visit: https://www.pythonforbeginners.com/basics/list-comprehensions-in-python

total_vocab = [x for x in DF]

# %%
print(total_vocab[:])
# Out:
# ['sharewar', 'trial', 'project', 'freewar', 'need', 'support', 'continu', 'one', 'hundred', 'west', 'fifty', 'three', 'north', 'jim', 'prentic', 'copyright', 'thousand', ',', 'nine', 'and', 'ninety', 'brandon', 'manitoba', 'canada', 'magic', 'phrase', 'spoken', 'mumbl', 'thought', 'inwardli', 'soul', 'ventur', 'northward', 'imaginari', 'line', 'shown', 'map', 'label', 'degre', 's', 'presenc', 'indic', 'highway', 'travel', 'road', 'side', 'sign', 'divis', 'territori', 'distinct', 'mind', 'intern', 'border', 'writer', 'poet', 'pilot', 'contribut', 'lore', 'rigor', 'life', 'bush', 'told', 'tale', 'man', 'eat', 'mosquito', 'murder', 'hord', 'black', 'fli', 'lump', 'flesh', 'carri', 'away', 'giant', 'bull', 'dog', 'stori', 'record', 'break', 'trout', 'walley', 'pike', 'legion', 'sight', 'sound', 'heard', 'deep', 'spruce', 'forest', 'crash', 'moos', 'tear', 'brush', 'tree', 'drum', 'grous', 'incess', 'hum', 'insect', 'cackl', 'quackeri', 'duck', 'feed', 'quiet', 'pond', 'placid', 'bay', 'intermitt', 'song', 'loon', 'never', 'forgotten', 'voic', 'signatur', 'authent', 'northern', 'scene', 'wildlif', 'land', 'seem', 'differ', 'found', 'elsewher', 'take', 'special', 'breed', 'person', 'live', 'farther', 'becom', 'appar', 'southern', 'whether', 'first', 'fiftieth', 'trip', 'realli', 'awar', 'implic', 'gener', 'owner', 'cottag', 'lake', 'amen', 'hand', 'weekend', 'rough', 'dweller', 'year', 'round', 'basi', 'modern', 'cabin', 'shore', 'near', 'larg', 'metropolitan', 'center', 'equip', 'electr', 'servic', 'telephon', 'pave', 'natur', 'ga', 'pipelin', 'cabl', 'televis', 'nearbi', 'provid', 'food', 'fuel', 'repair', 'entertain', 'drivein', 'theater', 'fast', 'chain', 'abound', 'waterfront', 'busi', 'dock', 'built', 'arriv', 'boat', 'shop', 'laundri', 'transfer', 'suitcas', 'famili', 'car', 'local', 'merchant', 'deliv', 'good', 'water', 'entrepreneur', 'make', 'businesss', 'maintain', 'absenc', 'season', 'locat', 'five', 'well', 'street', 'rival', 'home', 'mani', 'citi', 'commun', 'although', 'littl', 'urban', 'offer', 'escap', 'look', 'averag', 'studi', 'compar', 'standard', 'area', 'retreat', 'bu', 'start', 'either', 'walk', 'call', 'taxi', 'ye', 'kind', 'anoth', 'even', 'ride', 'back', 'pick', 'truck', 'mail', 'deliveri', 'unknown', 'pleasant', 'stroll', 'midsumm', 'contrast', 'ordeal', 'threaten', 'condit', 'winter', 'hous', 'milk', 'bread', 'nonexist', 'perhap', 'newspap', 'requir', 'effort', 'especi', 'rail', 'schedul', 'air', 'settlement', 'sever', 'restrict', 'avail', 'small', 'compani', 'exist', 'fare', 'collect', 'transport', 'nativ', 'reserv', 'diminish', 'recent', 'bushpilot', 'charter', 'aircraft', 'still', 'play', 'role', 'learn', 'would', 'keep', 'colleagu', 'ground', 'summer', 'float', 'haul', 'trapper', 'fishermen', 'freight', 'fish', 'fur', 'suppli', 'camp', 'traplin', 'log', 'fall', 'ice', 'thin', 'ski', 'yet', 'thick', 'chang', 'wheel', 'permit', 'present', 'problem', 'hear', 'temperatur', 'exceed', 'forty', 'zero', 'blow', 'snow', 'crystal', 'whiteout', 'challeng', 'daili', 'work', 'preheat', 'engin', 'coax', 'congeal', 'oil', 'propel', 'pitch', 'mechan', 'super', 'cool', 'gasolin', 'regular', 'chore', 'must', 'tie', 'rope', 'frozen', 'hole', 'four', 'foot', 'lift', 'run', 'onto', 'board', 'pole', 'prevent', 'freez', 'passeng', 'wear', 'heavi', 'arctic', 'cloth', 'heat', 'system', 'capabl', 'cope', 'cold', 'batteri', 'remov', 'end', 'day', 'ensur', 'maximum', 'effici', 'next', 'wing', 'cover', 'stop', 'ingress', 'build', 'frost', 'flight', 'surfac', 'pot', 'often', 'get', 'minu', 'turn', 'done', 'chin', 'up', 'coldsoak', 'cessna', 'flew', 'airport', 'lack', 'comparison', 'south', 'usual', 'oper', 'larger', 'may', 'pay', 'airstrip', 'normal', 'procedur', 'buzz', 'town', 'let', 'peopl', 'know', 'someon', 'head', 'strip', 'meet', 'unless', 'custom', 'transact', 'cash', 'chequ', 'nearli', 'useless', 'villag', 'without', 'bank', 'credit', 'stranger', 'foolhardi', 'grip', 'snowmobil', 'major', 'mode', 'largest', 'place', 'vehi ...

# %%
def doc_freq(word):
    c = 0
    try:
        c = DF[word]
    except:
        pass
    return c

# %%
# Calculating TF-IDF for body, we will consider this as the actual tf-idf as we will add the title weight to this.
doc = 0

tf_idf = {}

for i in range(N):
    
    tokens = processed_text[i]
    
    counter = Counter(tokens + processed_title[i])
    words_count = len(tokens + processed_title[i])
    
    for token in np.unique(tokens):
        
        tf = counter[token]/words_count
        df = doc_freq(token)
        idf
#  (0, 'wheel'): 0.001066496819677096,
#  (0, 'whether'): 0.00271868476691132,
#  (0, 'whistl'): 0.0012459305239495826,
#  (0, 'white'): 0.0005170543013032434,
#  (0, 'whitefish'): 0.0028132902547351184,
#  (0, 'whiteout'): 0.0030391761088343744,
#  (0, 'wild'): 0.0017767035145594494,
#  (0, 'wildlif'): 0.0045337345451117676,
#  (0, 'willow'): 0.002341258020536119,
#  (0, 'wind'): 0.0006723263918152326,
#  (0, 'windflow'): 0.0030391761088343744,
#  (0, 'wing'): 0.002252182630498669,
#  (0, 'winter'): 0.011260913152493345,
#  (0, 'within'): 0.0005807926585053294,
#  (0, 'without'): 0.0003628412649718356,
#  (0, 'wolv'): 0.0020409814184566277,
#  (0, 'wonder'): 0.0004411599004153952,
#  (0, 'wood'): 0.0008117662471802245,
#  (0, 'woodburn'): 0.0030391761088343744,
#  (0, 'work'): 0.000852557593176436,
#  (0, 'would'): 0.00012193824653356674,
#  (0, 'writer'): 0.002365589532236766,
#  (0, 'ye'): 0.0004281732269510792,
#  (0, 'year'): 0.0023859172792404524,
#  (0, 'yet'): 0.0004598653575371802,
#  (0, 'zero'): 0.005630456576246673,
#  (1, 'across'): 0.004251914335035176,
#  (1, 'agre'): 0.0034699504853148684,
#  (1, 'ah'): 0.001933362797806221,
#  (1, 'air'): 0.001050569374930165,
#  (1, 'alarm'): 0.0020955983285348037,
#  (1, 'allow'): 0.0015642149541971685,
#  (1, 'among'): 0.0037432321440623475,
#  (1, 'answer'): 0.0023070814326197195,
#  (1, 'appl'): 0.006302086873369869,
#  (1, 'around'): 0.0005753018266591884,
#  (1, 'art'): 0.002217030557818136,
#  (1, 'ask'): 0.0012446221743968873,
#  (1, 'away'): 0.00047471365250303417,
#  (1, 'back'): 0.00034643764002991405,
#  (1, 'bag'): 0.0020670272447949178,
#  (1, 'bake'): 0.00845311571207724,
#  (1, 'bark'): 0.002961669137142848,
#  (1, 'bay'): 0.0057538226195266015,
#  (1, 'beat'): 0.0017136094653701255,
#  (1, 'becam'): 0.0025318783378400285,
#  (1, 'bedroom'): 0.0025031872625851785,
#  (1, 'began'): 0.002602152034628451,
#  (1, 'begun'): 0.0025031872625851785,
#  (1, 'behav'): 0.0036491578201101977,
#  (1, 'besid'): 0.0013654983949680805,
#  (1, 'beulah'): 0.006701868692085628,
#  (1, 'big'): 0.0019111308790908698,
#  (1, 'bird'): 0.001985096809292863,
#  (1, 'boat'): 0.002772294837600762,
#  (1, 'boot'): 0.0022995112738348786,
#  (1, 'bother'): 0.004309629339668815,
#  ...}

# %%
len(tf_idf)
# Out:
# 347644

# %%
# TF-IDF Matching Score Ranking

# Note: put "reverse = True" to make it sort highest to lowest 
# Note: #mylist = [[7, 8], [4, 2, 3], [9, 5, 6]]
# list(map(lambda x: x[1], mylist)) returns [8, 2 ,5]
#mylistSort = sorted(mylist, key = lambda x: x[1], reverse=True)
# will sort the nested list based on the result of the lambda function 

def matching_score(k, query):
    preprocessed_query = preprocess(query)
    tokens = word_tokenize(str(preprocessed_query))

    print("Matching Score")
    print("\nQuery:", query)
    print("")
    print(tokens)
    
    query_weights = {}

    for key in tf_idf:
        
        if key[1] in tokens:
            try:
                query_weights[key[0]] = query_weights[key[0]] + tf_idf[key]
            except:
                query_weights[key[0]] = tf_idf[key]
    
    query_weights = sorted(query_weights.items(), key=lambda x: x[1], reverse=True)
    
    return query_weights[:10]
    print("")

# %%
# Document print by assigned id - used in end of the program

def print_doc(id):
    print(dataset[id])
    file = open(dataset[id][0], 'r', encoding='cp1250')
    text = file.read().strip()
    file.close()
    print(text)

# %%
query = "what is capital of india"
result = matching_score(10, query)
file_score = []
result_file_name = [(dataset[a][1], b) for (a, b) in result]
# Out:
# Matching Score
#
# Query: what is capital of india
#
# ['capit', 'india']

# %%
result_file_name
# Out:
# [('The Spirit and the Flute (How Flutes Relate to History)',
#   0.009844832248505797),
#  ('Introduction to the Neolithic Great Goddess, by Ben Blumenberg (February 12, 1992)',
#   0.009568808914435541),
#  ("The World's Fastest Spider, by Andrew Varga (1991)", 0.008338007184656698),
#  ('FICTION: Yahoo! The Ohio VOW has The Bomb by Gregory S. Swann (1986)',
#   0.0049611559621561),
#  ('The Story of Hop Frog', 0.0043170703125886235),
#  ('Branded, by John R. Hillman, Jr.', 0.004189208779367098),
#  ('The Story of the Six Able Men', 0.004007913809008088),
#  ('The Empress Jowka', 0.0037257474632589557),
#  ('The SRE Commerce and Trade Theories, by Josh Renaud', 0.003185651393646478),
#  ('The Early Days of a High-Tech Start-up are Magic (November 18, 1991) by M. Peshota',
#   0.0026379656504865036)]

# %%
result
# Out:
# [(182, 0.00960626668079936),
#  (199, 0.004611008006783693),
#  (4, 0.0037526006158972065),
#  (307, 0.0036704541347531883),
#  (439, 0.003666805571994984),
#  (264, 0.002665322547273811),
#  (303, 0.002632981017435371),
#  (116, 0.0024857186020397267),
#  (309, 0.0023170894506450716),
#  (398, 0.0021957180984684254)]

# %%
# For simulation time calculation

stop = timeit.default_timer()

print('Time (seconds): ', stop - start)
# Out:
# Time (seconds):  220.4733851

# %%
print_doc(117)
# Out:
# ('C:\\Users\\sumit/stories//contrad1.hum', 'Contradiction 1, by Rick Brunet')
# Contradiction 1
# by Rick Brunet
#
#
# There once was a man.  He was a good man.
#
# In his middle years, the man was considered by all who knew him Friend.  He had
# no enemies, no evil inside him, no "debts to society".  Only good came from
# him, and only good came back to him.  A full circle of light.
#
# The man had a woman, a woman he had known half his life, who loved and
# cherished him, and that he loved and cherished in kind.  He was her knight in
# shining armour, and she was his his Guinivere.	Together they shared a
# happiness, a contentment in their own little Garden of Eden.
#
# All was good in this man's life.  This man died at the ripe old age of
# forty-nine.
#
# Did God "call him home"?  Was this man's purity and shining strength so solid
# that it could no longer be kept apart from His Paradise?  Did the very
# "foundation of heaven" scream for this man's Soul?  No.
#
# You see, he had a particular fondness for eggs as his breakfast meal.  By the
# time he hit forty, the cholestorol levels in his body had built up to dangerous
# levels.  What do Saints know of doctors?  But then again, what does Life know
# of Saints.
#
# And so, the man died of a heart attack at the ripe old age of forty-nine.  Only
# sick minds would think he was condemned to Hell for being a fool.
#
# God is not that human.
